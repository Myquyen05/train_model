# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['VNM']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2006-01-26          2.31        53.5              18750         1003125
# 1     2006-02-07          2.33        54.0             138720         7490880
# 2     2006-02-08          2.37        55.0             159300         8761500
# 3     2006-02-27          2.82        65.5             162140        10599680
# 4     2006-03-08          2.93        68.0             163660        11193980
# ...          ...           ...         ...                ...             ...
# 4716  2024-12-17         64.60        64.6            1204000     77859000000
# 4717  2024-12-13         64.20        64.2            1396700     89780000000
# 4718  2024-12-18         64.70        64.7            1614100    104789000000
# 4719  2024-12-19         63.90        63.9            2626900    168508000000
# 4720  2024-12-20         65.00        65.0            3799600    246349000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0      53.5        53.5         53.5
# 1          207000     11160000      54.0        54.0         54.0
# 2               0            0      55.0        55.0         55.0
# 3               0            0      65.0        65.5         65.0
# 4               0            0      69.0        69.0         68.0
# ...           ...          ...       ...         ...          ...
# 4716            0            0      64.9        65.0         64.5
# 4717            0            0      64.3        64.5         64.1
# 4718            0            0      65.0        65.1         64.7
# 4719        20000   1294000000      64.4        64.5         63.9
# 4720            0            0      64.0        65.0         64.0
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0                0.5              0.94
# 1                0.0              0.00
# 2                0.0              0.00
# 3                0.0              0.00
# 4                0.0              0.00
# ...              ...               ...
# 4716            -0.4             -0.62
# 4717            -0.4             -0.62
# 4718             0.1              0.15
# 4719            -0.8             -1.24
# 4720             1.1              1.72
#
# [4721 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4721 entries, 0 to 4720
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               4721 non-null   object
#  1   GiaDieuChinh       4721 non-null   float64
#  2   GiaDongCua         4721 non-null   float64
#  3   KhoiLuongKhopLenh  4721 non-null   int64
#  4   GiaTriKhopLenh     4721 non-null   int64
#  5   KLThoaThuan        4721 non-null   int64
#  6   GtThoaThuan        4721 non-null   int64
#  7   GiaMoCua           4721 non-null   float64
#  8   GiaCaoNhat         4721 non-null   float64
#  9   GiaThapNhat        4721 non-null   float64
#  10  ThayDoi_GiaTri     4721 non-null   float64
#  11  ThayDoi_PhanTram   4721 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 442.7+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   4721.000000  4721.000000       4.721000e+03    4.721000e+03
# mean      43.804429   112.028003       9.820127e+05    9.469248e+10
# std       31.302805    33.598442       1.384946e+06    1.178250e+11
# min        2.240000    52.000000       0.000000e+00    0.000000e+00
# 25%        9.080000    85.900000       1.172600e+05    1.083752e+10
# 50%       37.480000   107.000000       3.986200e+05    4.960200e+10
# 75%       72.140000   135.000000       1.310670e+06    1.416440e+11
# max      109.830000   214.800000       2.114490e+07    1.580914e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  4.721000e+03  4.721000e+03  4721.000000  4721.000000  4721.000000
# mean   2.161472e+05  2.726914e+10   112.041538   113.031625   111.027431
# std    9.295512e+05  1.508098e+11    33.595834    33.927245    33.256735
# min    0.000000e+00  0.000000e+00    52.000000    18.300000    52.000000
# 25%    0.000000e+00  0.000000e+00    86.000000    86.500000    85.000000
# 50%    2.000000e+04  1.468450e+09   107.000000   108.000000   106.000000
# 75%    1.680000e+05  1.894508e+10   135.000000   136.000000   133.500000
# max    3.601420e+07  6.685384e+12   214.000000   215.000000   213.100000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     4721.000000       4721.000000
# mean         0.017445          0.021735
# std          1.219251          1.159921
# min        -19.100000        -14.890000
# 25%          0.000000          0.000000
# 50%          0.000000          0.000000
# 75%          0.000000          0.000000
# max         11.300000          6.970000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2006-01-19        53.0
# 2006-01-20        54.0
# 2006-01-23        52.5
# 2006-01-24        52.0
# 2006-01-25        53.0
# ...                ...
# 2024-12-16        65.0
# 2024-12-17        64.6
# 2024-12-18        64.7
# 2024-12-19        63.9
# 2024-12-20        65.0
#
# [4721 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[53. ],
#        [54. ],
#        [52.5],
#        ...,
#        [64.7],
#        [63.9],
#        [65. ]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/VNM_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.19036, saving model to save_models/VNM_model.keras
# 59/59 - 13s - 214ms/step - loss: 0.1904 - val_loss: 0.1088
# Epoch 2/100
#
# Epoch 2: loss improved from 0.19036 to 0.10293, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 96ms/step - loss: 0.1029 - val_loss: 0.0701
# Epoch 3/100
#
# Epoch 3: loss improved from 0.10293 to 0.07983, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 106ms/step - loss: 0.0798 - val_loss: 0.0565
# Epoch 4/100
#
# Epoch 4: loss improved from 0.07983 to 0.07045, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 98ms/step - loss: 0.0705 - val_loss: 0.0517
# Epoch 5/100
#
# Epoch 5: loss improved from 0.07045 to 0.06179, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 94ms/step - loss: 0.0618 - val_loss: 0.0468
# Epoch 6/100
#
# Epoch 6: loss improved from 0.06179 to 0.05694, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 94ms/step - loss: 0.0569 - val_loss: 0.0465
# Epoch 7/100
#
# Epoch 7: loss improved from 0.05694 to 0.05412, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 94ms/step - loss: 0.0541 - val_loss: 0.0421
# Epoch 8/100
#
# Epoch 8: loss improved from 0.05412 to 0.04992, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 96ms/step - loss: 0.0499 - val_loss: 0.0394
# Epoch 9/100
#
# Epoch 9: loss improved from 0.04992 to 0.04670, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 96ms/step - loss: 0.0467 - val_loss: 0.0384
# Epoch 10/100
#
# Epoch 10: loss improved from 0.04670 to 0.04548, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 98ms/step - loss: 0.0455 - val_loss: 0.0381
# Epoch 11/100
#
# Epoch 11: loss improved from 0.04548 to 0.04205, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 95ms/step - loss: 0.0420 - val_loss: 0.0345
# Epoch 12/100
#
# Epoch 12: loss improved from 0.04205 to 0.03981, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 91ms/step - loss: 0.0398 - val_loss: 0.0343
# Epoch 13/100
#
# Epoch 13: loss improved from 0.03981 to 0.03828, saving model to save_models/VNM_model.keras
# 59/59 - 4s - 73ms/step - loss: 0.0383 - val_loss: 0.0359
# Epoch 14/100
#
# Epoch 14: loss improved from 0.03828 to 0.03622, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 78ms/step - loss: 0.0362 - val_loss: 0.0344
# Epoch 15/100
#
# Epoch 15: loss improved from 0.03622 to 0.03619, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 78ms/step - loss: 0.0362 - val_loss: 0.0317
# Epoch 16/100
#
# Epoch 16: loss improved from 0.03619 to 0.03519, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 83ms/step - loss: 0.0352 - val_loss: 0.0352
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.03519
# 59/59 - 5s - 91ms/step - loss: 0.0354 - val_loss: 0.0307
# Epoch 18/100
#
# Epoch 18: loss improved from 0.03519 to 0.03306, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 88ms/step - loss: 0.0331 - val_loss: 0.0331
# Epoch 19/100
#
# Epoch 19: loss improved from 0.03306 to 0.03129, saving model to save_models/VNM_model.keras
# 59/59 - 4s - 76ms/step - loss: 0.0313 - val_loss: 0.0297
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.03129
# 59/59 - 5s - 82ms/step - loss: 0.0316 - val_loss: 0.0317
# Epoch 21/100
#
# Epoch 21: loss improved from 0.03129 to 0.03058, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 81ms/step - loss: 0.0306 - val_loss: 0.0309
# Epoch 22/100
#
# Epoch 22: loss improved from 0.03058 to 0.03045, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 90ms/step - loss: 0.0304 - val_loss: 0.0282
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.03045
# 59/59 - 5s - 85ms/step - loss: 0.0308 - val_loss: 0.0330
# Epoch 24/100
#
# Epoch 24: loss improved from 0.03045 to 0.02967, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 86ms/step - loss: 0.0297 - val_loss: 0.0300
# Epoch 25/100
#
# Epoch 25: loss improved from 0.02967 to 0.02934, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 87ms/step - loss: 0.0293 - val_loss: 0.0277
# Epoch 26/100
#
# Epoch 26: loss improved from 0.02934 to 0.02928, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 86ms/step - loss: 0.0293 - val_loss: 0.0294
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.02928
# 59/59 - 6s - 94ms/step - loss: 0.0295 - val_loss: 0.0299
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.02928
# 59/59 - 5s - 93ms/step - loss: 0.0299 - val_loss: 0.0304
# Epoch 29/100
#
# Epoch 29: loss improved from 0.02928 to 0.02867, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 100ms/step - loss: 0.0287 - val_loss: 0.0271
# Epoch 30/100
#
# Epoch 30: loss improved from 0.02867 to 0.02866, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 96ms/step - loss: 0.0287 - val_loss: 0.0282
# Epoch 31/100
#
# Epoch 31: loss improved from 0.02866 to 0.02813, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 100ms/step - loss: 0.0281 - val_loss: 0.0271
# Epoch 32/100
#
# Epoch 32: loss improved from 0.02813 to 0.02782, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 101ms/step - loss: 0.0278 - val_loss: 0.0307
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.02782
# 59/59 - 6s - 99ms/step - loss: 0.0283 - val_loss: 0.0297
# Epoch 34/100
#
# Epoch 34: loss improved from 0.02782 to 0.02773, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 107ms/step - loss: 0.0277 - val_loss: 0.0284
# Epoch 35/100
#
# Epoch 35: loss improved from 0.02773 to 0.02703, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 102ms/step - loss: 0.0270 - val_loss: 0.0264
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.02703
# 59/59 - 6s - 101ms/step - loss: 0.0279 - val_loss: 0.0270
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.02703
# 59/59 - 6s - 99ms/step - loss: 0.0282 - val_loss: 0.0257
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.02703
# 59/59 - 6s - 101ms/step - loss: 0.0276 - val_loss: 0.0257
# Epoch 39/100
#
# Epoch 39: loss improved from 0.02703 to 0.02684, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 102ms/step - loss: 0.0268 - val_loss: 0.0253
# Epoch 40/100
#
# Epoch 40: loss improved from 0.02684 to 0.02629, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 102ms/step - loss: 0.0263 - val_loss: 0.0252
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.02629
# 59/59 - 10s - 170ms/step - loss: 0.0269 - val_loss: 0.0276
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.02629
# 59/59 - 6s - 100ms/step - loss: 0.0267 - val_loss: 0.0252
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.02629
# 59/59 - 6s - 98ms/step - loss: 0.0266 - val_loss: 0.0249
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.02629
# 59/59 - 6s - 101ms/step - loss: 0.0265 - val_loss: 0.0251
# Epoch 45/100
#
# Epoch 45: loss improved from 0.02629 to 0.02627, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 109ms/step - loss: 0.0263 - val_loss: 0.0246
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.02627
# 59/59 - 6s - 101ms/step - loss: 0.0264 - val_loss: 0.0290
# Epoch 47/100
#
# Epoch 47: loss improved from 0.02627 to 0.02623, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 98ms/step - loss: 0.0262 - val_loss: 0.0259
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.02623
# 59/59 - 6s - 96ms/step - loss: 0.0265 - val_loss: 0.0279
# Epoch 49/100
#
# Epoch 49: loss improved from 0.02623 to 0.02612, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 97ms/step - loss: 0.0261 - val_loss: 0.0247
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.02612
# 59/59 - 5s - 84ms/step - loss: 0.0267 - val_loss: 0.0244
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.02612
# 59/59 - 5s - 80ms/step - loss: 0.0263 - val_loss: 0.0241
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.02612
# 59/59 - 5s - 84ms/step - loss: 0.0264 - val_loss: 0.0247
# Epoch 53/100
#
# Epoch 53: loss improved from 0.02612 to 0.02587, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 83ms/step - loss: 0.0259 - val_loss: 0.0246
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.02587
# 59/59 - 5s - 84ms/step - loss: 0.0260 - val_loss: 0.0262
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.02587
# 59/59 - 5s - 83ms/step - loss: 0.0260 - val_loss: 0.0239
# Epoch 56/100
#
# Epoch 56: loss improved from 0.02587 to 0.02528, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 85ms/step - loss: 0.0253 - val_loss: 0.0260
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.02528
# 59/59 - 5s - 83ms/step - loss: 0.0257 - val_loss: 0.0241
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.02528
# 59/59 - 5s - 81ms/step - loss: 0.0253 - val_loss: 0.0250
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.02528
# 59/59 - 5s - 80ms/step - loss: 0.0262 - val_loss: 0.0276
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.02528
# 59/59 - 5s - 82ms/step - loss: 0.0260 - val_loss: 0.0261
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.02528
# 59/59 - 5s - 80ms/step - loss: 0.0261 - val_loss: 0.0271
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.02528
# 59/59 - 5s - 79ms/step - loss: 0.0259 - val_loss: 0.0251
# Epoch 63/100
#
# Epoch 63: loss improved from 0.02528 to 0.02521, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 79ms/step - loss: 0.0252 - val_loss: 0.0239
# Epoch 64/100
#
# Epoch 64: loss improved from 0.02521 to 0.02452, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 83ms/step - loss: 0.0245 - val_loss: 0.0242
# Epoch 65/100
#
# Epoch 65: loss improved from 0.02452 to 0.02438, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 82ms/step - loss: 0.0244 - val_loss: 0.0285
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.02438
# 59/59 - 5s - 81ms/step - loss: 0.0262 - val_loss: 0.0240
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.02438
# 59/59 - 5s - 82ms/step - loss: 0.0247 - val_loss: 0.0248
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.02438
# 59/59 - 5s - 90ms/step - loss: 0.0249 - val_loss: 0.0234
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.02438
# 59/59 - 5s - 86ms/step - loss: 0.0249 - val_loss: 0.0230
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.02438
# 59/59 - 5s - 85ms/step - loss: 0.0251 - val_loss: 0.0231
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02438
# 59/59 - 5s - 82ms/step - loss: 0.0254 - val_loss: 0.0241
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.02438
# 59/59 - 5s - 86ms/step - loss: 0.0249 - val_loss: 0.0241
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.02438
# 59/59 - 5s - 86ms/step - loss: 0.0249 - val_loss: 0.0230
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.02438
# 59/59 - 5s - 77ms/step - loss: 0.0249 - val_loss: 0.0253
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.02438
# 59/59 - 5s - 78ms/step - loss: 0.0254 - val_loss: 0.0277
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02438
# 59/59 - 5s - 82ms/step - loss: 0.0245 - val_loss: 0.0227
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.02438
# 59/59 - 5s - 81ms/step - loss: 0.0244 - val_loss: 0.0227
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.02438
# 59/59 - 5s - 84ms/step - loss: 0.0252 - val_loss: 0.0229
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.02438
# 59/59 - 5s - 79ms/step - loss: 0.0251 - val_loss: 0.0241
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.02438
# 59/59 - 5s - 87ms/step - loss: 0.0248 - val_loss: 0.0241
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.02438
# 59/59 - 5s - 79ms/step - loss: 0.0252 - val_loss: 0.0238
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.02438
# 59/59 - 5s - 81ms/step - loss: 0.0247 - val_loss: 0.0247
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.02438
# 59/59 - 5s - 83ms/step - loss: 0.0256 - val_loss: 0.0238
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.02438
# 59/59 - 5s - 84ms/step - loss: 0.0247 - val_loss: 0.0234
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.02438
# 59/59 - 5s - 85ms/step - loss: 0.0248 - val_loss: 0.0226
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.02438
# 59/59 - 6s - 95ms/step - loss: 0.0246 - val_loss: 0.0229
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.02438
# 59/59 - 6s - 94ms/step - loss: 0.0246 - val_loss: 0.0266
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.02438
# 59/59 - 6s - 97ms/step - loss: 0.0247 - val_loss: 0.0266
# Epoch 89/100
#
# Epoch 89: loss improved from 0.02438 to 0.02425, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 96ms/step - loss: 0.0243 - val_loss: 0.0261
# Epoch 90/100
#
# Epoch 90: loss improved from 0.02425 to 0.02419, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 95ms/step - loss: 0.0242 - val_loss: 0.0223
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.02419
# 59/59 - 6s - 96ms/step - loss: 0.0249 - val_loss: 0.0222
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.02419
# 59/59 - 6s - 94ms/step - loss: 0.0246 - val_loss: 0.0222
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.02419
# 59/59 - 6s - 96ms/step - loss: 0.0243 - val_loss: 0.0252
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.02419
# 59/59 - 6s - 95ms/step - loss: 0.0244 - val_loss: 0.0223
# Epoch 95/100
#
# Epoch 95: loss improved from 0.02419 to 0.02413, saving model to save_models/VNM_model.keras
# 59/59 - 10s - 172ms/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.02413
# 59/59 - 6s - 95ms/step - loss: 0.0246 - val_loss: 0.0224
# Epoch 97/100
#
# Epoch 97: loss improved from 0.02413 to 0.02412, saving model to save_models/VNM_model.keras
# 59/59 - 6s - 97ms/step - loss: 0.0241 - val_loss: 0.0232
# Epoch 98/100
#
# Epoch 98: loss improved from 0.02412 to 0.02405, saving model to save_models/VNM_model.keras
# 59/59 - 5s - 93ms/step - loss: 0.0241 - val_loss: 0.0221
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.02405
# 59/59 - 6s - 94ms/step - loss: 0.0247 - val_loss: 0.0251
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.02405
# 59/59 - 5s - 92ms/step - loss: 0.0241 - val_loss: 0.0232
# Restoring model weights from the end of the best epoch: 98.

# %%
# Hàm xây dựng mô hình
def build_model():
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(units=64))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# Huấn luyện mô hình
model = build_model()
save_model_path = f"save_models/{collection}_model.keras"
best_model = ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.01953, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 9s - 127ms/step - loss: 0.0195
# Epoch 2/100
#
# Epoch 2: loss improved from 0.01953 to 0.01390, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 67ms/step - loss: 0.0139
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01390 to 0.01147, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 69ms/step - loss: 0.0115
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.01147
# 72/72 - 5s - 64ms/step - loss: 0.0124
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01147 to 0.01087, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0109
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01087 to 0.01084, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 64ms/step - loss: 0.0108
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.01084
# 72/72 - 5s - 66ms/step - loss: 0.0114
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.01084
# 72/72 - 5s - 68ms/step - loss: 0.0109
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01084 to 0.01023, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0102
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01023 to 0.00967, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 68ms/step - loss: 0.0097
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00967
# 72/72 - 5s - 66ms/step - loss: 0.0104
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00967
# 72/72 - 5s - 69ms/step - loss: 0.0098
# Epoch 13/100
#
# Epoch 13: loss improved from 0.00967 to 0.00954, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 65ms/step - loss: 0.0095
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00954
# 72/72 - 4s - 62ms/step - loss: 0.0099
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.00954
# 72/72 - 5s - 64ms/step - loss: 0.0098
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.00954
# 72/72 - 5s - 63ms/step - loss: 0.0100
# Epoch 17/100
#
# Epoch 17: loss improved from 0.00954 to 0.00887, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00887
# 72/72 - 4s - 57ms/step - loss: 0.0096
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0095
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0102
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00887
# 72/72 - 4s - 58ms/step - loss: 0.0138
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00887
# 72/72 - 4s - 59ms/step - loss: 0.0094
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00887
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0089
# Epoch 28/100
#
# Epoch 28: loss improved from 0.00887 to 0.00879, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00879 to 0.00859, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00859
# 72/72 - 5s - 75ms/step - loss: 0.0094
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00859
# 72/72 - 4s - 58ms/step - loss: 0.0090
# Epoch 32/100
#
# Epoch 32: loss improved from 0.00859 to 0.00851, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0114
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0091
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0091
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00851
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00851
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0089
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 41/100
#
# Epoch 41: loss improved from 0.00851 to 0.00840, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00840 to 0.00836, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00836
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00836
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 45/100
#
# Epoch 45: loss improved from 0.00836 to 0.00829, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0083
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00829
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00829 to 0.00812, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0086
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0082
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00812
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0093
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00812
# 72/72 - 5s - 63ms/step - loss: 0.0083
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00812 to 0.00806, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00806
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00806 to 0.00791, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0084
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0079
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0108
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0091
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0081
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0085
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00791
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0086
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0081
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00791 to 0.00789, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0079
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0112
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0094
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00789
# 72/72 - 4s - 59ms/step - loss: 0.0095
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00789
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00789
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0080
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 89/100
#
# Epoch 89: loss improved from 0.00789 to 0.00785, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0079
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00785 to 0.00780, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0078
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0080
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0083
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00780
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00780
# 72/72 - 5s - 63ms/step - loss: 0.0084
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00780 to 0.00772, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0077

# %%
save_model_path = "save_models/VNM_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[1500:] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9856984638235973
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 2.1170425877798906
# Phần trăm sai số tuyệt đối trung bình trên tập train: 1.7651125255600024
# RMSE trên tập train (VNĐ): 3.7021995356263755
# Độ chính xác trên tập train (%): 97.54496052014167
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9789034581018216
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.9940205359080484
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.316814642801473
# RMSE trên tập test (VNĐ): 1.2894273388532456
# Độ chính xác trên tập test (%): 96.75207219432433
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
