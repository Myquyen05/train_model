# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['BCM']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2018-02-21         22.86        25.0              81200      2063370000
# 1     2018-03-05         19.48        21.3              35500       755520000
# 2     2018-03-08         19.20        21.0               2100        44100000
# 3     2018-03-20         18.29        20.0             101100      2027930000
# 4     2018-03-23         21.49        23.5              97700      2180840000
# ...          ...           ...         ...                ...             ...
# 1697  2024-12-17         67.80        67.8             124200      8412000000
# 1698  2024-12-13         67.70        67.7             145300      9795000000
# 1699  2024-12-18         67.80        67.8              92600      6260000000
# 1700  2024-12-19         66.50        66.5             142600      9527000000
# 1701  2024-12-20         67.70        67.7             163900     11000000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0      29.6        29.6         25.0
# 1               0            0      21.2        21.5         21.0
# 2               0            0      21.0        21.0         21.0
# 3               0            0      20.0        20.9         19.1
# 4               0            0      22.3        23.8         22.0
# ...           ...          ...       ...         ...          ...
# 1697            0            0      68.0        68.0         67.4
# 1698            0            0      67.5        67.7         66.7
# 1699            0            0      67.8        67.8         67.2
# 1700            0            0      67.0        67.5         66.5
# 1701            0            0      66.5        67.7         66.3
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0                0.0              0.00
# 1                0.0              0.00
# 2                0.7              3.45
# 3                0.0              0.00
# 4                2.5             11.90
# ...              ...               ...
# 1697            -0.2             -0.29
# 1698             0.2              0.30
# 1699             0.0              0.00
# 1700            -1.3             -1.92
# 1701             1.2              1.80
#
# [1702 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1702 entries, 0 to 1701
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               1702 non-null   object
#  1   GiaDieuChinh       1702 non-null   float64
#  2   GiaDongCua         1702 non-null   float64
#  3   KhoiLuongKhopLenh  1702 non-null   int64
#  4   GiaTriKhopLenh     1702 non-null   int64
#  5   KLThoaThuan        1702 non-null   int64
#  6   GtThoaThuan        1702 non-null   int64
#  7   GiaMoCua           1702 non-null   float64
#  8   GiaCaoNhat         1702 non-null   float64
#  9   GiaThapNhat        1702 non-null   float64
#  10  ThayDoi_GiaTri     1702 non-null   float64
#  11  ThayDoi_PhanTram   1702 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 159.7+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   1702.000000  1702.000000       1.702000e+03    1.702000e+03
# mean      48.234289    50.183461       2.230673e+05    1.420368e+10
# std       22.639394    22.784501       3.329545e+05    2.233279e+10
# min       12.800000    14.000000       0.000000e+00    0.000000e+00
# 25%       24.550000    26.300000       2.220000e+04    6.946585e+08
# 50%       51.590000    54.000000       8.725000e+04    4.550000e+09
# 75%       68.015000    69.475000       2.957750e+05    1.925350e+10
# max       94.470000    98.000000       2.520900e+06    1.729090e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  1.702000e+03  1.702000e+03  1702.000000  1702.000000  1702.000000
# mean   2.664773e+04  1.701383e+09    50.039072    50.808549    49.098825
# std    1.726381e+05  1.164108e+10    22.737363    23.001637    22.487259
# min    0.000000e+00  0.000000e+00    14.000000    14.500000    12.900000
# 25%    0.000000e+00  0.000000e+00    26.100000    26.625000    25.600000
# 50%    0.000000e+00  0.000000e+00    53.500000    54.650000    53.000000
# 75%    0.000000e+00  0.000000e+00    69.400000    70.850000    68.000000
# max    3.430000e+06  2.795842e+11    99.000000   101.800000    97.500000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     1702.000000       1702.000000
# mean         0.075499          0.309148
# std          1.203953          2.791980
# min        -10.100000        -18.500000
# 25%         -0.300000         -0.697500
# 50%          0.000000          0.000000
# 75%          0.400000          0.980000
# max          6.400000         20.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2018-02-21        25.0
# 2018-02-22        25.0
# 2018-02-23        23.0
# 2018-02-26        22.9
# 2018-02-27        24.0
# ...                ...
# 2024-12-16        68.0
# 2024-12-17        67.8
# 2024-12-18        67.8
# 2024-12-19        66.5
# 2024-12-20        67.7
#
# [1702 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[25. ],
#        [25. ],
#        [23. ],
#        ...,
#        [67.8],
#        [66.5],
#        [67.7]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # Giảm số đơn vị trong LSTM và tăng regularization
    model.add(LSTM(units=64, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.3))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001))
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/BCM_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=15, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.22326, saving model to save_models/BCM_model.keras
# 21/21 - 5s - 254ms/step - loss: 0.2233 - val_loss: 0.1010
# Epoch 2/100
#
# Epoch 2: loss improved from 0.22326 to 0.12777, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.1278 - val_loss: 0.0739
# Epoch 3/100
#
# Epoch 3: loss improved from 0.12777 to 0.10968, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.1097 - val_loss: 0.0633
# Epoch 4/100
#
# Epoch 4: loss improved from 0.10968 to 0.09673, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0967 - val_loss: 0.0569
# Epoch 5/100
#
# Epoch 5: loss improved from 0.09673 to 0.08983, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0898 - val_loss: 0.0486
# Epoch 6/100
#
# Epoch 6: loss improved from 0.08983 to 0.08175, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0818 - val_loss: 0.0439
# Epoch 7/100
#
# Epoch 7: loss improved from 0.08175 to 0.07641, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 45ms/step - loss: 0.0764 - val_loss: 0.0397
# Epoch 8/100
#
# Epoch 8: loss improved from 0.07641 to 0.07347, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0735 - val_loss: 0.0393
# Epoch 9/100
#
# Epoch 9: loss improved from 0.07347 to 0.06771, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0677 - val_loss: 0.0341
# Epoch 10/100
#
# Epoch 10: loss improved from 0.06771 to 0.06566, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0657 - val_loss: 0.0329
# Epoch 11/100
#
# Epoch 11: loss improved from 0.06566 to 0.06355, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 50ms/step - loss: 0.0636 - val_loss: 0.0308
# Epoch 12/100
#
# Epoch 12: loss improved from 0.06355 to 0.05989, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0599 - val_loss: 0.0314
# Epoch 13/100
#
# Epoch 13: loss improved from 0.05989 to 0.05876, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 50ms/step - loss: 0.0588 - val_loss: 0.0284
# Epoch 14/100
#
# Epoch 14: loss improved from 0.05876 to 0.05601, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0560 - val_loss: 0.0272
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.05601
# 21/21 - 1s - 48ms/step - loss: 0.0567 - val_loss: 0.0269
# Epoch 16/100
#
# Epoch 16: loss improved from 0.05601 to 0.05585, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 50ms/step - loss: 0.0558 - val_loss: 0.0257
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.05585
# 21/21 - 1s - 46ms/step - loss: 0.0567 - val_loss: 0.0281
# Epoch 18/100
#
# Epoch 18: loss improved from 0.05585 to 0.05340, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 50ms/step - loss: 0.0534 - val_loss: 0.0238
# Epoch 19/100
#
# Epoch 19: loss improved from 0.05340 to 0.05212, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0521 - val_loss: 0.0241
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.05212
# 21/21 - 1s - 46ms/step - loss: 0.0527 - val_loss: 0.0233
# Epoch 21/100
#
# Epoch 21: loss improved from 0.05212 to 0.04973, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0497 - val_loss: 0.0225
# Epoch 22/100
#
# Epoch 22: loss improved from 0.04973 to 0.04692, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0469 - val_loss: 0.0223
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.04692
# 21/21 - 1s - 47ms/step - loss: 0.0506 - val_loss: 0.0217
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.04692
# 21/21 - 1s - 48ms/step - loss: 0.0499 - val_loss: 0.0227
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.04692
# 21/21 - 1s - 47ms/step - loss: 0.0476 - val_loss: 0.0227
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.04692
# 21/21 - 1s - 47ms/step - loss: 0.0476 - val_loss: 0.0207
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.04692
# 21/21 - 1s - 45ms/step - loss: 0.0471 - val_loss: 0.0200
# Epoch 28/100
#
# Epoch 28: loss improved from 0.04692 to 0.04660, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0466 - val_loss: 0.0227
# Epoch 29/100
#
# Epoch 29: loss improved from 0.04660 to 0.04372, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0437 - val_loss: 0.0199
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.04372
# 21/21 - 1s - 48ms/step - loss: 0.0445 - val_loss: 0.0191
# Epoch 31/100
#
# Epoch 31: loss improved from 0.04372 to 0.04367, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0437 - val_loss: 0.0193
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.04367
# 21/21 - 1s - 48ms/step - loss: 0.0439 - val_loss: 0.0239
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.04367
# 21/21 - 1s - 48ms/step - loss: 0.0441 - val_loss: 0.0189
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.04367
# 21/21 - 1s - 48ms/step - loss: 0.0443 - val_loss: 0.0208
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.04367
# 21/21 - 1s - 46ms/step - loss: 0.0438 - val_loss: 0.0176
# Epoch 36/100
#
# Epoch 36: loss improved from 0.04367 to 0.04342, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 47ms/step - loss: 0.0434 - val_loss: 0.0176
# Epoch 37/100
#
# Epoch 37: loss improved from 0.04342 to 0.04197, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0420 - val_loss: 0.0221
# Epoch 38/100
#
# Epoch 38: loss improved from 0.04197 to 0.04143, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 46ms/step - loss: 0.0414 - val_loss: 0.0212
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.04143
# 21/21 - 1s - 41ms/step - loss: 0.0416 - val_loss: 0.0204
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.04143
# 21/21 - 1s - 42ms/step - loss: 0.0424 - val_loss: 0.0166
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.04143
# 21/21 - 1s - 45ms/step - loss: 0.0417 - val_loss: 0.0192
# Epoch 42/100
#
# Epoch 42: loss improved from 0.04143 to 0.04042, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 47ms/step - loss: 0.0404 - val_loss: 0.0163
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.04042
# 21/21 - 1s - 40ms/step - loss: 0.0412 - val_loss: 0.0163
# Epoch 44/100
#
# Epoch 44: loss improved from 0.04042 to 0.03905, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 47ms/step - loss: 0.0391 - val_loss: 0.0169
# Epoch 45/100
#
# Epoch 45: loss improved from 0.03905 to 0.03853, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 47ms/step - loss: 0.0385 - val_loss: 0.0159
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.03853
# 21/21 - 1s - 44ms/step - loss: 0.0401 - val_loss: 0.0158
# Epoch 47/100
#
# Epoch 47: loss improved from 0.03853 to 0.03799, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 47ms/step - loss: 0.0380 - val_loss: 0.0164
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.03799
# 21/21 - 1s - 45ms/step - loss: 0.0385 - val_loss: 0.0162
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.03799
# 21/21 - 1s - 47ms/step - loss: 0.0384 - val_loss: 0.0154
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.03799
# 21/21 - 1s - 53ms/step - loss: 0.0399 - val_loss: 0.0152
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.03799
# 21/21 - 1s - 47ms/step - loss: 0.0416 - val_loss: 0.0151
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.03799
# 21/21 - 1s - 47ms/step - loss: 0.0403 - val_loss: 0.0179
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.03799
# 21/21 - 1s - 47ms/step - loss: 0.0383 - val_loss: 0.0148
# Epoch 54/100
#
# Epoch 54: loss improved from 0.03799 to 0.03798, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 47ms/step - loss: 0.0380 - val_loss: 0.0166
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.03798
# 21/21 - 1s - 46ms/step - loss: 0.0394 - val_loss: 0.0151
# Epoch 56/100
#
# Epoch 56: loss improved from 0.03798 to 0.03744, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0374 - val_loss: 0.0146
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.03744
# 21/21 - 1s - 47ms/step - loss: 0.0392 - val_loss: 0.0144
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.03744
# 21/21 - 1s - 47ms/step - loss: 0.0376 - val_loss: 0.0143
# Epoch 59/100
#
# Epoch 59: loss improved from 0.03744 to 0.03712, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0371 - val_loss: 0.0158
# Epoch 60/100
#
# Epoch 60: loss improved from 0.03712 to 0.03638, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0364 - val_loss: 0.0146
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.03638
# 21/21 - 1s - 47ms/step - loss: 0.0378 - val_loss: 0.0167
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.03638
# 21/21 - 1s - 46ms/step - loss: 0.0372 - val_loss: 0.0141
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.03638
# 21/21 - 1s - 47ms/step - loss: 0.0365 - val_loss: 0.0140
# Epoch 64/100
#
# Epoch 64: loss improved from 0.03638 to 0.03574, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0357 - val_loss: 0.0140
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.03574
# 21/21 - 1s - 47ms/step - loss: 0.0365 - val_loss: 0.0136
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.03574
# 21/21 - 1s - 48ms/step - loss: 0.0361 - val_loss: 0.0164
# Epoch 67/100
#
# Epoch 67: loss improved from 0.03574 to 0.03565, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 47ms/step - loss: 0.0357 - val_loss: 0.0134
# Epoch 68/100
#
# Epoch 68: loss improved from 0.03565 to 0.03561, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0356 - val_loss: 0.0133
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.03561
# 21/21 - 1s - 46ms/step - loss: 0.0359 - val_loss: 0.0135
# Epoch 70/100
#
# Epoch 70: loss improved from 0.03561 to 0.03468, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0347 - val_loss: 0.0132
# Epoch 71/100
#
# Epoch 71: loss improved from 0.03468 to 0.03402, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0340 - val_loss: 0.0134
# Epoch 72/100
#
# Epoch 72: loss improved from 0.03402 to 0.03354, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 48ms/step - loss: 0.0335 - val_loss: 0.0130
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.03354
# 21/21 - 1s - 44ms/step - loss: 0.0353 - val_loss: 0.0139
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.03354
# 21/21 - 1s - 47ms/step - loss: 0.0344 - val_loss: 0.0140
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.03354
# 21/21 - 1s - 47ms/step - loss: 0.0350 - val_loss: 0.0134
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.03354
# 21/21 - 1s - 48ms/step - loss: 0.0353 - val_loss: 0.0152
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.03354
# 21/21 - 1s - 47ms/step - loss: 0.0343 - val_loss: 0.0137
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.03354
# 21/21 - 1s - 47ms/step - loss: 0.0362 - val_loss: 0.0127
# Epoch 79/100
#
# Epoch 79: loss improved from 0.03354 to 0.03300, saving model to save_models/BCM_model.keras
# 21/21 - 1s - 49ms/step - loss: 0.0330 - val_loss: 0.0139
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0356 - val_loss: 0.0154
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0346 - val_loss: 0.0125
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.03300
# 21/21 - 1s - 46ms/step - loss: 0.0348 - val_loss: 0.0123
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.03300
# 21/21 - 1s - 46ms/step - loss: 0.0336 - val_loss: 0.0136
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0368 - val_loss: 0.0131
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0359 - val_loss: 0.0150
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0335 - val_loss: 0.0123
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.03300
# 21/21 - 1s - 46ms/step - loss: 0.0344 - val_loss: 0.0130
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0345 - val_loss: 0.0122
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0338 - val_loss: 0.0127
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.03300
# 21/21 - 1s - 44ms/step - loss: 0.0358 - val_loss: 0.0263
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.03300
# 21/21 - 1s - 47ms/step - loss: 0.0360 - val_loss: 0.0159
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.03300
# 21/21 - 1s - 48ms/step - loss: 0.0357 - val_loss: 0.0166
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.03300
# 21/21 - 1s - 48ms/step - loss: 0.0342 - val_loss: 0.0119
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.03300
# 21/21 - 1s - 48ms/step - loss: 0.0352 - val_loss: 0.0128
# Epoch 94: early stopping
# Restoring model weights from the end of the best epoch: 79.

# %%
save_model_path = "models/BCM_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9962291338802837
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 0.9544524298288912
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.2453199394743204
# RMSE trên tập train (VNĐ): 1.4710352232868844
# Độ chính xác trên tập train (%): 98.24876759132513
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.91085958976541
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.035262493234226
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.6024358748853558
# RMSE trên tập test (VNĐ): 1.3837645946558121
# Độ chính xác trên tập test (%): 93.98363219714865
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
