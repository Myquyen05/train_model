# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['VHM']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2018-05-23         64.25      110.30            4839580    536081000000
# 1     2018-05-24         66.69      114.50            1937240    217951000000
# 2     2018-05-28         68.15      117.00            2944740    341683000000
# 3     2018-06-04         68.67      117.90            1762630    206081000000
# 4     2018-06-13         68.73      118.00             289590     34157000000
# ...          ...           ...         ...                ...             ...
# 1649  2024-12-17         41.30       41.30            3708600    152799000000
# 1650  2024-12-13         40.65       40.65            3126900    127153000000
# 1651  2024-12-18         40.90       40.90            2431900    100305000000
# 1652  2024-12-19         40.20       40.20            5724800    231609000000
# 1653  2024-12-20         40.35       40.35            3475300    140194000000
#
#       KLThoaThuan   GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0          484300   53273000000     114.5      114.50        110.0
# 1          650000   73117500000     110.8      114.80        110.1
# 2          109220   12779832200     111.0      118.00        111.0
# 3           96000   11223360000     116.0      117.90        115.5
# 4               0             0     118.0      118.40        117.6
# ...           ...           ...       ...         ...          ...
# 1649      4460000  182637000000      41.0       41.40         40.8
# 1650            0             0      40.7       40.80         40.5
# 1651      1205700   49373415000      41.3       41.60         40.9
# 1652            0             0      40.6       40.75         40.2
# 1653            0             0      40.4       40.45         40.2
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0              -7.90             -6.68
# 1               4.20              3.81
# 2              -0.50             -0.43
# 3               1.40              1.20
# 4               0.00              0.00
# ...              ...               ...
# 1649            0.35              0.85
# 1650           -0.10             -0.25
# 1651           -0.40             -0.97
# 1652           -0.70             -1.71
# 1653            0.15              0.37
#
# [1654 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1654 entries, 0 to 1653
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               1654 non-null   object
#  1   GiaDieuChinh       1654 non-null   float64
#  2   GiaDongCua         1654 non-null   float64
#  3   KhoiLuongKhopLenh  1654 non-null   int64
#  4   GiaTriKhopLenh     1654 non-null   int64
#  5   KLThoaThuan        1654 non-null   int64
#  6   GtThoaThuan        1654 non-null   int64
#  7   GiaMoCua           1654 non-null   float64
#  8   GiaCaoNhat         1654 non-null   float64
#  9   GiaThapNhat        1654 non-null   float64
#  10  ThayDoi_GiaTri     1654 non-null   float64
#  11  ThayDoi_PhanTram   1654 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 155.2+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   1654.000000  1654.000000       1.654000e+03    1.654000e+03
# mean      58.795846    72.053386       3.883376e+06    2.455558e+11
# std       12.423815    22.622608       4.390494e+06    2.755857e+11
# min       34.500000    34.500000       0.000000e+00    0.000000e+00
# 25%       48.962500    50.000000       1.025952e+06    7.328825e+10
# 50%       58.950000    76.500000       2.554550e+06    1.689665e+11
# 75%       66.750000    86.900000       5.105508e+06    3.109408e+11
# max       88.420000   120.000000       3.673270e+07    2.566484e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  1.654000e+03  1.654000e+03  1654.000000  1654.000000  1654.000000
# mean   1.196090e+06  8.516079e+10    72.087817    72.950272    71.121252
# std    9.139026e+06  8.759744e+11    22.631573    22.880139    22.363377
# min    0.000000e+00  0.000000e+00    34.800000    34.800000    34.000000
# 25%    0.000000e+00  0.000000e+00    50.025000    50.700000    49.012500
# 50%    6.500000e+04  4.841250e+09    76.550000    77.400000    75.750000
# 75%    4.000000e+05  2.954520e+10    86.800000    87.900000    86.000000
# max    2.678000e+08  3.071666e+13   122.000000   122.000000   119.000000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     1654.000000       1654.000000
# mean        -0.003192         -0.006119
# std          1.440277          1.931130
# min         -8.200000         -7.080000
# 25%         -0.500000         -0.740000
# 50%          0.000000          0.000000
# 75%          0.400000          0.610000
# max         18.400000         19.980000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2018-05-17      110.50
# 2018-05-18      110.50
# 2018-05-21      110.50
# 2018-05-22      118.20
# 2018-05-23      110.30
# ...                ...
# 2024-12-16       40.95
# 2024-12-17       41.30
# 2024-12-18       40.90
# 2024-12-19       40.20
# 2024-12-20       40.35
#
# [1654 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[110.5 ],
#        [110.5 ],
#        [110.5 ],
#        ...,
#        [ 40.9 ],
#        [ 40.2 ],
#        [ 40.35]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # Giảm số đơn vị trong LSTM và tăng regularization
    model.add(LSTM(units=64, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.35))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/VHM_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=15, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.28316, saving model to save_models/VHM_model.keras
# 20/20 - 6s - 286ms/step - loss: 0.2832 - val_loss: 0.1552
# Epoch 2/100
#
# Epoch 2: loss improved from 0.28316 to 0.17160, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 51ms/step - loss: 0.1716 - val_loss: 0.1314
# Epoch 3/100
#
# Epoch 3: loss improved from 0.17160 to 0.15295, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.1529 - val_loss: 0.1132
# Epoch 4/100
#
# Epoch 4: loss improved from 0.15295 to 0.13866, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.1387 - val_loss: 0.1071
# Epoch 5/100
#
# Epoch 5: loss improved from 0.13866 to 0.13189, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 51ms/step - loss: 0.1319 - val_loss: 0.0972
# Epoch 6/100
#
# Epoch 6: loss improved from 0.13189 to 0.12642, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.1264 - val_loss: 0.0899
# Epoch 7/100
#
# Epoch 7: loss improved from 0.12642 to 0.11758, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.1176 - val_loss: 0.0921
# Epoch 8/100
#
# Epoch 8: loss improved from 0.11758 to 0.11234, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.1123 - val_loss: 0.0872
# Epoch 9/100
#
# Epoch 9: loss improved from 0.11234 to 0.10962, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.1096 - val_loss: 0.0888
# Epoch 10/100
#
# Epoch 10: loss improved from 0.10962 to 0.10567, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.1057 - val_loss: 0.0753
# Epoch 11/100
#
# Epoch 11: loss improved from 0.10567 to 0.10001, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.1000 - val_loss: 0.0818
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.10001
# 20/20 - 1s - 46ms/step - loss: 0.1003 - val_loss: 0.0687
# Epoch 13/100
#
# Epoch 13: loss improved from 0.10001 to 0.09690, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0969 - val_loss: 0.0788
# Epoch 14/100
#
# Epoch 14: loss improved from 0.09690 to 0.09619, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0962 - val_loss: 0.0637
# Epoch 15/100
#
# Epoch 15: loss improved from 0.09619 to 0.09385, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0938 - val_loss: 0.0616
# Epoch 16/100
#
# Epoch 16: loss improved from 0.09385 to 0.09148, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0915 - val_loss: 0.0614
# Epoch 17/100
#
# Epoch 17: loss improved from 0.09148 to 0.08826, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0883 - val_loss: 0.0651
# Epoch 18/100
#
# Epoch 18: loss improved from 0.08826 to 0.08218, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0822 - val_loss: 0.0563
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.08218
# 20/20 - 1s - 44ms/step - loss: 0.0850 - val_loss: 0.0573
# Epoch 20/100
#
# Epoch 20: loss improved from 0.08218 to 0.08210, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 54ms/step - loss: 0.0821 - val_loss: 0.0646
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.08210
# 20/20 - 1s - 45ms/step - loss: 0.0841 - val_loss: 0.0554
# Epoch 22/100
#
# Epoch 22: loss improved from 0.08210 to 0.08083, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 53ms/step - loss: 0.0808 - val_loss: 0.0610
# Epoch 23/100
#
# Epoch 23: loss improved from 0.08083 to 0.08011, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0801 - val_loss: 0.0548
# Epoch 24/100
#
# Epoch 24: loss improved from 0.08011 to 0.07546, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0755 - val_loss: 0.0576
# Epoch 25/100
#
# Epoch 25: loss improved from 0.07546 to 0.07487, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0749 - val_loss: 0.0503
# Epoch 26/100
#
# Epoch 26: loss improved from 0.07487 to 0.07419, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 52ms/step - loss: 0.0742 - val_loss: 0.0511
# Epoch 27/100
#
# Epoch 27: loss improved from 0.07419 to 0.07346, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 50ms/step - loss: 0.0735 - val_loss: 0.0473
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.07346
# 20/20 - 1s - 46ms/step - loss: 0.0741 - val_loss: 0.0523
# Epoch 29/100
#
# Epoch 29: loss improved from 0.07346 to 0.07289, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0729 - val_loss: 0.0483
# Epoch 30/100
#
# Epoch 30: loss improved from 0.07289 to 0.07003, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0700 - val_loss: 0.0529
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.07003
# 20/20 - 1s - 46ms/step - loss: 0.0705 - val_loss: 0.0587
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.07003
# 20/20 - 1s - 45ms/step - loss: 0.0707 - val_loss: 0.0599
# Epoch 33/100
#
# Epoch 33: loss improved from 0.07003 to 0.06930, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0693 - val_loss: 0.0466
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.06930
# 20/20 - 1s - 45ms/step - loss: 0.0698 - val_loss: 0.0543
# Epoch 35/100
#
# Epoch 35: loss improved from 0.06930 to 0.06899, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0690 - val_loss: 0.0445
# Epoch 36/100
#
# Epoch 36: loss improved from 0.06899 to 0.06628, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0663 - val_loss: 0.0563
# Epoch 37/100
#
# Epoch 37: loss improved from 0.06628 to 0.06572, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0657 - val_loss: 0.0425
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.06572
# 20/20 - 1s - 45ms/step - loss: 0.0672 - val_loss: 0.0431
# Epoch 39/100
#
# Epoch 39: loss improved from 0.06572 to 0.06422, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0642 - val_loss: 0.0476
# Epoch 40/100
#
# Epoch 40: loss improved from 0.06422 to 0.06411, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0641 - val_loss: 0.0428
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.06411
# 20/20 - 1s - 44ms/step - loss: 0.0660 - val_loss: 0.0485
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.06411
# 20/20 - 1s - 47ms/step - loss: 0.0643 - val_loss: 0.0493
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.06411
# 20/20 - 1s - 45ms/step - loss: 0.0643 - val_loss: 0.0588
# Epoch 44/100
#
# Epoch 44: loss improved from 0.06411 to 0.06265, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0627 - val_loss: 0.0402
# Epoch 45/100
#
# Epoch 45: loss improved from 0.06265 to 0.06236, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0624 - val_loss: 0.0444
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.06236
# 20/20 - 1s - 45ms/step - loss: 0.0627 - val_loss: 0.0397
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.06236
# 20/20 - 1s - 45ms/step - loss: 0.0646 - val_loss: 0.0428
# Epoch 48/100
#
# Epoch 48: loss improved from 0.06236 to 0.05862, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0586 - val_loss: 0.0437
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.05862
# 20/20 - 1s - 45ms/step - loss: 0.0600 - val_loss: 0.0422
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.05862
# 20/20 - 1s - 44ms/step - loss: 0.0605 - val_loss: 0.0385
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.05862
# 20/20 - 1s - 46ms/step - loss: 0.0595 - val_loss: 0.0444
# Epoch 52/100
#
# Epoch 52: loss improved from 0.05862 to 0.05660, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0566 - val_loss: 0.0412
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.05660
# 20/20 - 1s - 47ms/step - loss: 0.0612 - val_loss: 0.0423
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.05660
# 20/20 - 1s - 45ms/step - loss: 0.0583 - val_loss: 0.0400
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.05660
# 20/20 - 1s - 47ms/step - loss: 0.0580 - val_loss: 0.0460
# Epoch 56/100
#
# Epoch 56: loss improved from 0.05660 to 0.05653, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0565 - val_loss: 0.0497
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.05653
# 20/20 - 1s - 45ms/step - loss: 0.0567 - val_loss: 0.0367
# Epoch 58/100
#
# Epoch 58: loss improved from 0.05653 to 0.05630, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0563 - val_loss: 0.0406
# Epoch 59/100
#
# Epoch 59: loss improved from 0.05630 to 0.05414, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0541 - val_loss: 0.0369
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.05414
# 20/20 - 1s - 45ms/step - loss: 0.0552 - val_loss: 0.0404
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.05414
# 20/20 - 1s - 44ms/step - loss: 0.0558 - val_loss: 0.0430
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.05414
# 20/20 - 1s - 47ms/step - loss: 0.0549 - val_loss: 0.0457
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.05414
# 20/20 - 1s - 44ms/step - loss: 0.0544 - val_loss: 0.0468
# Epoch 64/100
#
# Epoch 64: loss improved from 0.05414 to 0.05394, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0539 - val_loss: 0.0355
# Epoch 65/100
#
# Epoch 65: loss improved from 0.05394 to 0.05379, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0538 - val_loss: 0.0352
# Epoch 66/100
#
# Epoch 66: loss improved from 0.05379 to 0.05214, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0521 - val_loss: 0.0422
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.05214
# 20/20 - 1s - 44ms/step - loss: 0.0530 - val_loss: 0.0355
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.05214
# 20/20 - 1s - 47ms/step - loss: 0.0533 - val_loss: 0.0471
# Epoch 69/100
#
# Epoch 69: loss improved from 0.05214 to 0.05145, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0514 - val_loss: 0.0416
# Epoch 70/100
#
# Epoch 70: loss improved from 0.05145 to 0.05103, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0510 - val_loss: 0.0366
# Epoch 71/100
#
# Epoch 71: loss improved from 0.05103 to 0.05023, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0502 - val_loss: 0.0383
# Epoch 72/100
#
# Epoch 72: loss improved from 0.05023 to 0.04934, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0493 - val_loss: 0.0364
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.04934
# 20/20 - 1s - 44ms/step - loss: 0.0502 - val_loss: 0.0343
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.04934
# 20/20 - 1s - 48ms/step - loss: 0.0494 - val_loss: 0.0350
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.04934
# 20/20 - 1s - 44ms/step - loss: 0.0515 - val_loss: 0.0402
# Epoch 76/100
#
# Epoch 76: loss improved from 0.04934 to 0.04907, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0491 - val_loss: 0.0343
# Epoch 77/100
#
# Epoch 77: loss improved from 0.04907 to 0.04887, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 47ms/step - loss: 0.0489 - val_loss: 0.0355
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.04887
# 20/20 - 1s - 46ms/step - loss: 0.0491 - val_loss: 0.0337
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.04887
# 20/20 - 1s - 49ms/step - loss: 0.0494 - val_loss: 0.0342
# Epoch 80/100
#
# Epoch 80: loss improved from 0.04887 to 0.04813, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0481 - val_loss: 0.0352
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.04813
# 20/20 - 1s - 46ms/step - loss: 0.0481 - val_loss: 0.0377
# Epoch 82/100
#
# Epoch 82: loss improved from 0.04813 to 0.04750, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0475 - val_loss: 0.0331
# Epoch 83/100
#
# Epoch 83: loss improved from 0.04750 to 0.04642, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0464 - val_loss: 0.0380
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.04642
# 20/20 - 1s - 44ms/step - loss: 0.0479 - val_loss: 0.0344
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.04642
# 20/20 - 1s - 45ms/step - loss: 0.0482 - val_loss: 0.0407
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.04642
# 20/20 - 1s - 45ms/step - loss: 0.0466 - val_loss: 0.0326
# Epoch 87/100
#
# Epoch 87: loss improved from 0.04642 to 0.04600, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 48ms/step - loss: 0.0460 - val_loss: 0.0349
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.04600
# 20/20 - 1s - 44ms/step - loss: 0.0462 - val_loss: 0.0325
# Epoch 89/100
#
# Epoch 89: loss improved from 0.04600 to 0.04516, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0452 - val_loss: 0.0341
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.04516
# 20/20 - 1s - 45ms/step - loss: 0.0465 - val_loss: 0.0335
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.04516
# 20/20 - 1s - 45ms/step - loss: 0.0455 - val_loss: 0.0329
# Epoch 92/100
#
# Epoch 92: loss improved from 0.04516 to 0.04466, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 45ms/step - loss: 0.0447 - val_loss: 0.0364
# Epoch 93/100
#
# Epoch 93: loss improved from 0.04466 to 0.04456, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 45ms/step - loss: 0.0446 - val_loss: 0.0320
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.04456
# 20/20 - 1s - 46ms/step - loss: 0.0450 - val_loss: 0.0334
# Epoch 95/100
#
# Epoch 95: loss improved from 0.04456 to 0.04378, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 46ms/step - loss: 0.0438 - val_loss: 0.0315
# Epoch 96/100
#
# Epoch 96: loss improved from 0.04378 to 0.04362, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 49ms/step - loss: 0.0436 - val_loss: 0.0397
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.04362
# 20/20 - 1s - 45ms/step - loss: 0.0451 - val_loss: 0.0349
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.04362
# 20/20 - 1s - 68ms/step - loss: 0.0439 - val_loss: 0.0311
# Epoch 99/100
#
# Epoch 99: loss improved from 0.04362 to 0.04353, saving model to save_models/VHM_model.keras
# 20/20 - 1s - 45ms/step - loss: 0.0435 - val_loss: 0.0322
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.04353
# 20/20 - 1s - 45ms/step - loss: 0.0436 - val_loss: 0.0333
# Restoring model weights from the end of the best epoch: 99.

# %%
save_model_path = "models/VHM_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9740727583859426
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 1.903504865935536
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.5262357490065415
# RMSE trên tập train (VNĐ): 2.885824120788228
# Độ chính xác trên tập train (%): 96.351676206336
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.7883399710880739
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.2921160579808166
# Phần trăm sai số tuyệt đối trung bình trên tập test: 3.1001868235341163
# RMSE trên tập test (VNĐ): 1.616524512160092
# Độ chính xác trên tập test (%): 92.44614713943882
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
