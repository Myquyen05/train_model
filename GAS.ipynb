# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['GAS']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2012-05-23         17.65        40.9            1055780     44104759000
# 1     2012-05-31         16.05        37.2             269030      9986408000
# 2     2012-06-04         15.36        35.6             383250     13869717000
# 3     2012-06-06         15.45        35.8             101300      3611519000
# 4     2012-06-08         16.18        37.5             300060     11452653000
# ...          ...           ...         ...                ...             ...
# 3141  2024-12-17         68.00        68.0             412900     28122000000
# 3142  2024-12-13         68.40        68.4             348000     23800000000
# 3143  2024-12-18         68.50        68.5             504100     34546000000
# 3144  2024-12-19         68.50        68.5             721400     49262000000
# 3145  2024-12-20         68.60        68.6             341700     23461000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0      42.9        43.0         40.9
# 1               0            0      37.2        37.8         36.7
# 2               0            0      36.8        36.8         35.6
# 3               0            0      35.6        36.0         35.3
# 4          150000   5737500000      37.8        39.3         37.4
# ...           ...          ...       ...         ...          ...
# 3141            0            0      68.1        68.5         68.0
# 3142            0            0      68.5        68.6         68.2
# 3143            0            0      68.4        68.7         68.3
# 3144            0            0      68.2        68.6         68.0
# 3145            0            0      68.5        68.8         68.4
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               -2.1             -4.88
# 1               -0.6             -1.59
# 2               -1.6             -4.30
# 3                0.2              0.56
# 4                0.0              0.00
# ...              ...               ...
# 3141            -0.1             -0.15
# 3142            -0.1             -0.15
# 3143             0.5              0.74
# 3144             0.0              0.00
# 3145             0.1              0.15
#
# [3146 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3146 entries, 0 to 3145
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               3146 non-null   object
#  1   GiaDieuChinh       3146 non-null   float64
#  2   GiaDongCua         3146 non-null   float64
#  3   KhoiLuongKhopLenh  3146 non-null   int64
#  4   GiaTriKhopLenh     3146 non-null   int64
#  5   KLThoaThuan        3146 non-null   int64
#  6   GtThoaThuan        3146 non-null   int64
#  7   GiaMoCua           3146 non-null   float64
#  8   GiaCaoNhat         3146 non-null   float64
#  9   GiaThapNhat        3146 non-null   float64
#  10  ThayDoi_GiaTri     3146 non-null   float64
#  11  ThayDoi_PhanTram   3146 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 295.1+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   3146.000000  3146.000000       3.146000e+03    3.146000e+03
# mean      51.747168    80.306008       6.224505e+05    5.146884e+10
# std       20.149549    23.216036       4.929867e+05    4.712806e+10
# min       15.360000    30.000000       2.760000e+03    1.065690e+08
# 25%       33.110000    63.500000       2.871525e+05    2.224825e+10
# 50%       54.500000    79.500000       5.046850e+05    3.887900e+10
# 75%       69.437500   100.400000       8.067275e+05    6.506825e+10
# max       95.470000   136.100000       4.515800e+06    4.974170e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  3.146000e+03  3.146000e+03  3146.000000  3146.000000  3146.000000
# mean   2.699240e+04  1.937365e+09    80.379085    81.433471    79.342753
# std    1.916604e+05  1.167304e+10    23.240442    23.656514    22.824763
# min    0.000000e+00  0.000000e+00    30.100000    30.700000    29.800000
# 25%    0.000000e+00  0.000000e+00    63.500000    64.000000    62.500000
# 50%    0.000000e+00  0.000000e+00    79.500000    80.000000    78.500000
# 75%    0.000000e+00  0.000000e+00   100.700000   101.800000    99.500000
# max    7.850000e+06  4.239000e+11   136.100000   136.400000   133.000000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     3146.000000       3146.000000
# mean         0.014644          0.043849
# std          1.612988          1.856610
# min         -9.300000         -7.000000
# 25%         -0.500000         -0.640000
# 50%          0.000000          0.000000
# 75%          0.500000          0.680000
# max          8.100000          7.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2012-05-21        41.0
# 2012-05-22        43.0
# 2012-05-23        40.9
# 2012-05-24        38.9
# 2012-05-25        39.0
# ...                ...
# 2024-12-16        68.1
# 2024-12-17        68.0
# 2024-12-18        68.5
# 2024-12-19        68.5
# 2024-12-20        68.6
#
# [3146 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[41. ],
#        [43. ],
#        [40.9],
#        ...,
#        [68.5],
#        [68.5],
#        [68.6]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/GAS_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.26308, saving model to save_models/GAS_model.keras
# 39/39 - 7s - 174ms/step - loss: 0.2631 - val_loss: 0.1615
# Epoch 2/100
#
# Epoch 2: loss improved from 0.26308 to 0.17610, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 85ms/step - loss: 0.1761 - val_loss: 0.1250
# Epoch 3/100
#
# Epoch 3: loss improved from 0.17610 to 0.14224, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 82ms/step - loss: 0.1422 - val_loss: 0.0916
# Epoch 4/100
#
# Epoch 4: loss improved from 0.14224 to 0.12158, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 81ms/step - loss: 0.1216 - val_loss: 0.0757
# Epoch 5/100
#
# Epoch 5: loss improved from 0.12158 to 0.10833, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 81ms/step - loss: 0.1083 - val_loss: 0.0641
# Epoch 6/100
#
# Epoch 6: loss improved from 0.10833 to 0.09746, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 79ms/step - loss: 0.0975 - val_loss: 0.0641
# Epoch 7/100
#
# Epoch 7: loss improved from 0.09746 to 0.08890, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 83ms/step - loss: 0.0889 - val_loss: 0.0623
# Epoch 8/100
#
# Epoch 8: loss improved from 0.08890 to 0.08404, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 78ms/step - loss: 0.0840 - val_loss: 0.0511
# Epoch 9/100
#
# Epoch 9: loss improved from 0.08404 to 0.08035, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 79ms/step - loss: 0.0803 - val_loss: 0.0459
# Epoch 10/100
#
# Epoch 10: loss improved from 0.08035 to 0.07458, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 81ms/step - loss: 0.0746 - val_loss: 0.0407
# Epoch 11/100
#
# Epoch 11: loss improved from 0.07458 to 0.07269, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 83ms/step - loss: 0.0727 - val_loss: 0.0417
# Epoch 12/100
#
# Epoch 12: loss improved from 0.07269 to 0.06962, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 80ms/step - loss: 0.0696 - val_loss: 0.0371
# Epoch 13/100
#
# Epoch 13: loss improved from 0.06962 to 0.06569, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 82ms/step - loss: 0.0657 - val_loss: 0.0414
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.06569
# 39/39 - 3s - 79ms/step - loss: 0.0667 - val_loss: 0.0382
# Epoch 15/100
#
# Epoch 15: loss improved from 0.06569 to 0.06344, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 85ms/step - loss: 0.0634 - val_loss: 0.0330
# Epoch 16/100
#
# Epoch 16: loss improved from 0.06344 to 0.06290, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 96ms/step - loss: 0.0629 - val_loss: 0.0346
# Epoch 17/100
#
# Epoch 17: loss improved from 0.06290 to 0.06158, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 93ms/step - loss: 0.0616 - val_loss: 0.0413
# Epoch 18/100
#
# Epoch 18: loss improved from 0.06158 to 0.06088, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 97ms/step - loss: 0.0609 - val_loss: 0.0303
# Epoch 19/100
#
# Epoch 19: loss improved from 0.06088 to 0.05623, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 97ms/step - loss: 0.0562 - val_loss: 0.0333
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.05623
# 39/39 - 4s - 93ms/step - loss: 0.0579 - val_loss: 0.0299
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.05623
# 39/39 - 4s - 95ms/step - loss: 0.0583 - val_loss: 0.0425
# Epoch 22/100
#
# Epoch 22: loss improved from 0.05623 to 0.05454, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 95ms/step - loss: 0.0545 - val_loss: 0.0270
# Epoch 23/100
#
# Epoch 23: loss improved from 0.05454 to 0.05382, saving model to save_models/GAS_model.keras
# 39/39 - 5s - 133ms/step - loss: 0.0538 - val_loss: 0.0283
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.05382
# 39/39 - 4s - 90ms/step - loss: 0.0541 - val_loss: 0.0306
# Epoch 25/100
#
# Epoch 25: loss improved from 0.05382 to 0.05072, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 102ms/step - loss: 0.0507 - val_loss: 0.0263
# Epoch 26/100
#
# Epoch 26: loss improved from 0.05072 to 0.05028, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 93ms/step - loss: 0.0503 - val_loss: 0.0312
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.05028
# 39/39 - 4s - 95ms/step - loss: 0.0506 - val_loss: 0.0327
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.05028
# 39/39 - 3s - 90ms/step - loss: 0.0506 - val_loss: 0.0359
# Epoch 29/100
#
# Epoch 29: loss improved from 0.05028 to 0.04873, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 91ms/step - loss: 0.0487 - val_loss: 0.0291
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.04873
# 39/39 - 4s - 93ms/step - loss: 0.0489 - val_loss: 0.0271
# Epoch 31/100
#
# Epoch 31: loss improved from 0.04873 to 0.04725, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 94ms/step - loss: 0.0473 - val_loss: 0.0242
# Epoch 32/100
#
# Epoch 32: loss improved from 0.04725 to 0.04533, saving model to save_models/GAS_model.keras
# 39/39 - 5s - 135ms/step - loss: 0.0453 - val_loss: 0.0230
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.04533
# 39/39 - 4s - 93ms/step - loss: 0.0466 - val_loss: 0.0220
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.04533
# 39/39 - 5s - 136ms/step - loss: 0.0460 - val_loss: 0.0243
# Epoch 35/100
#
# Epoch 35: loss improved from 0.04533 to 0.04466, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 100ms/step - loss: 0.0447 - val_loss: 0.0217
# Epoch 36/100
#
# Epoch 36: loss improved from 0.04466 to 0.04437, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 101ms/step - loss: 0.0444 - val_loss: 0.0224
# Epoch 37/100
#
# Epoch 37: loss improved from 0.04437 to 0.04273, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 100ms/step - loss: 0.0427 - val_loss: 0.0229
# Epoch 38/100
#
# Epoch 38: loss improved from 0.04273 to 0.04249, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 98ms/step - loss: 0.0425 - val_loss: 0.0243
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.04249
# 39/39 - 4s - 99ms/step - loss: 0.0435 - val_loss: 0.0230
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.04249
# 39/39 - 4s - 98ms/step - loss: 0.0426 - val_loss: 0.0207
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.04249
# 39/39 - 3s - 87ms/step - loss: 0.0427 - val_loss: 0.0220
# Epoch 42/100
#
# Epoch 42: loss improved from 0.04249 to 0.04239, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 87ms/step - loss: 0.0424 - val_loss: 0.0207
# Epoch 43/100
#
# Epoch 43: loss improved from 0.04239 to 0.03991, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 89ms/step - loss: 0.0399 - val_loss: 0.0219
# Epoch 44/100
#
# Epoch 44: loss improved from 0.03991 to 0.03977, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 81ms/step - loss: 0.0398 - val_loss: 0.0203
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.03977
# 39/39 - 3s - 77ms/step - loss: 0.0400 - val_loss: 0.0213
# Epoch 46/100
#
# Epoch 46: loss improved from 0.03977 to 0.03944, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 83ms/step - loss: 0.0394 - val_loss: 0.0207
# Epoch 47/100
#
# Epoch 47: loss improved from 0.03944 to 0.03851, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 82ms/step - loss: 0.0385 - val_loss: 0.0213
# Epoch 48/100
#
# Epoch 48: loss improved from 0.03851 to 0.03830, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 77ms/step - loss: 0.0383 - val_loss: 0.0205
# Epoch 49/100
#
# Epoch 49: loss improved from 0.03830 to 0.03796, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 84ms/step - loss: 0.0380 - val_loss: 0.0192
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.03796
# 39/39 - 3s - 76ms/step - loss: 0.0394 - val_loss: 0.0193
# Epoch 51/100
#
# Epoch 51: loss improved from 0.03796 to 0.03785, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 80ms/step - loss: 0.0379 - val_loss: 0.0282
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.03785
# 39/39 - 3s - 76ms/step - loss: 0.0387 - val_loss: 0.0198
# Epoch 53/100
#
# Epoch 53: loss improved from 0.03785 to 0.03713, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 85ms/step - loss: 0.0371 - val_loss: 0.0189
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.03713
# 39/39 - 3s - 80ms/step - loss: 0.0378 - val_loss: 0.0195
# Epoch 55/100
#
# Epoch 55: loss improved from 0.03713 to 0.03593, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 84ms/step - loss: 0.0359 - val_loss: 0.0176
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.03593
# 39/39 - 3s - 79ms/step - loss: 0.0368 - val_loss: 0.0182
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.03593
# 39/39 - 3s - 85ms/step - loss: 0.0363 - val_loss: 0.0202
# Epoch 58/100
#
# Epoch 58: loss improved from 0.03593 to 0.03590, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 85ms/step - loss: 0.0359 - val_loss: 0.0174
# Epoch 59/100
#
# Epoch 59: loss improved from 0.03590 to 0.03512, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 86ms/step - loss: 0.0351 - val_loss: 0.0177
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.03512
# 39/39 - 3s - 82ms/step - loss: 0.0352 - val_loss: 0.0174
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.03512
# 39/39 - 3s - 79ms/step - loss: 0.0352 - val_loss: 0.0179
# Epoch 62/100
#
# Epoch 62: loss improved from 0.03512 to 0.03435, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 85ms/step - loss: 0.0344 - val_loss: 0.0170
# Epoch 63/100
#
# Epoch 63: loss improved from 0.03435 to 0.03429, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 85ms/step - loss: 0.0343 - val_loss: 0.0171
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.03429
# 39/39 - 3s - 83ms/step - loss: 0.0343 - val_loss: 0.0176
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.03429
# 39/39 - 3s - 86ms/step - loss: 0.0349 - val_loss: 0.0174
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.03429
# 39/39 - 3s - 77ms/step - loss: 0.0345 - val_loss: 0.0168
# Epoch 67/100
#
# Epoch 67: loss improved from 0.03429 to 0.03323, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 83ms/step - loss: 0.0332 - val_loss: 0.0178
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.03323
# 39/39 - 3s - 81ms/step - loss: 0.0347 - val_loss: 0.0200
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.03323
# 39/39 - 3s - 79ms/step - loss: 0.0339 - val_loss: 0.0188
# Epoch 70/100
#
# Epoch 70: loss improved from 0.03323 to 0.03297, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 77ms/step - loss: 0.0330 - val_loss: 0.0176
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.03297
# 39/39 - 3s - 80ms/step - loss: 0.0348 - val_loss: 0.0205
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.03297
# 39/39 - 3s - 83ms/step - loss: 0.0342 - val_loss: 0.0176
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.03297
# 39/39 - 4s - 99ms/step - loss: 0.0340 - val_loss: 0.0181
# Epoch 74/100
#
# Epoch 74: loss improved from 0.03297 to 0.03258, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 86ms/step - loss: 0.0326 - val_loss: 0.0169
# Epoch 75/100
#
# Epoch 75: loss improved from 0.03258 to 0.03230, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 87ms/step - loss: 0.0323 - val_loss: 0.0193
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.03230
# 39/39 - 3s - 79ms/step - loss: 0.0335 - val_loss: 0.0188
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.03230
# 39/39 - 5s - 120ms/step - loss: 0.0332 - val_loss: 0.0175
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.03230
# 39/39 - 4s - 106ms/step - loss: 0.0328 - val_loss: 0.0203
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.03230
# 39/39 - 3s - 85ms/step - loss: 0.0328 - val_loss: 0.0178
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.03230
# 39/39 - 4s - 91ms/step - loss: 0.0329 - val_loss: 0.0202
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.03230
# 39/39 - 3s - 85ms/step - loss: 0.0331 - val_loss: 0.0165
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.03230
# 39/39 - 3s - 89ms/step - loss: 0.0326 - val_loss: 0.0189
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.03230
# 39/39 - 3s - 84ms/step - loss: 0.0324 - val_loss: 0.0168
# Epoch 84/100
#
# Epoch 84: loss improved from 0.03230 to 0.03198, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 88ms/step - loss: 0.0320 - val_loss: 0.0192
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.03198
# 39/39 - 3s - 88ms/step - loss: 0.0322 - val_loss: 0.0188
# Epoch 86/100
#
# Epoch 86: loss improved from 0.03198 to 0.03158, saving model to save_models/GAS_model.keras
# 39/39 - 4s - 91ms/step - loss: 0.0316 - val_loss: 0.0181
# Epoch 87/100
#
# Epoch 87: loss improved from 0.03158 to 0.03086, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 89ms/step - loss: 0.0309 - val_loss: 0.0155
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.03086
# 39/39 - 3s - 84ms/step - loss: 0.0314 - val_loss: 0.0155
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.03086
# 39/39 - 3s - 85ms/step - loss: 0.0310 - val_loss: 0.0172
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.03086
# 39/39 - 4s - 93ms/step - loss: 0.0311 - val_loss: 0.0163
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.03086
# 39/39 - 4s - 92ms/step - loss: 0.0309 - val_loss: 0.0168
# Epoch 92/100
#
# Epoch 92: loss improved from 0.03086 to 0.03049, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 85ms/step - loss: 0.0305 - val_loss: 0.0174
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.03049
# 39/39 - 4s - 90ms/step - loss: 0.0309 - val_loss: 0.0164
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.03049
# 39/39 - 3s - 82ms/step - loss: 0.0316 - val_loss: 0.0179
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.03049
# 39/39 - 3s - 83ms/step - loss: 0.0321 - val_loss: 0.0165
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.03049
# 39/39 - 3s - 85ms/step - loss: 0.0307 - val_loss: 0.0154
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.03049
# 39/39 - 3s - 83ms/step - loss: 0.0308 - val_loss: 0.0167
# Epoch 98/100
#
# Epoch 98: loss improved from 0.03049 to 0.03045, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 79ms/step - loss: 0.0304 - val_loss: 0.0164
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.03045
# 39/39 - 3s - 79ms/step - loss: 0.0309 - val_loss: 0.0164
# Epoch 100/100
#
# Epoch 100: loss improved from 0.03045 to 0.03016, saving model to save_models/GAS_model.keras
# 39/39 - 3s - 78ms/step - loss: 0.0302 - val_loss: 0.0152
# Restoring model weights from the end of the best epoch: 100.

# %%
# save_model_path = "models/ACB_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[1500:] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9878211182038353
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 1.7849636541955953
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.271470997377793
# RMSE trên tập train (VNĐ): 2.6226752772915973
# Độ chính xác trên tập train (%): 97.52811001197776
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9768193064347878
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.4050386798192585
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.4981740473489547
# RMSE trên tập test (VNĐ): 2.24266889530788
# Độ chính xác trên tập test (%): 96.07238372100197
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
