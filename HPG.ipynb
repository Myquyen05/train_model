# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['HPG']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2007-11-19          2.17      115.00             120480     13855000000
# 1     2007-11-21          2.16      114.00             728080     78430000000
# 2     2007-12-03          2.00      106.00              68710      7290000000
# 3     2007-12-04          1.99      105.00             125040     13181000000
# 4     2007-12-05          1.97      104.00             112160     11651000000
# ...          ...           ...         ...                ...             ...
# 4260  2024-12-17         27.00       27.00           10809400    291423000000
# 4261  2024-12-13         27.20       27.20           17265900    470778000000
# 4262  2024-12-18         27.35       27.35           12794200    347227000000
# 4263  2024-12-19         26.85       26.85           30331800    817089000000
# 4264  2024-12-20         26.70       26.70           13746900    368560000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0    115.00      115.00       115.00
# 1               0            0    105.00      114.00       105.00
# 2               0            0    107.00      107.00       106.00
# 3               0            0    105.00      106.00       105.00
# 4               0            0    103.00      105.00       103.00
# ...           ...          ...       ...         ...          ...
# 4260      3011039  80954980850     27.00       27.10        26.85
# 4261      1309589  35315978400     27.30       27.40        27.10
# 4262      1644897  41443159550     27.00       27.35        26.95
# 4263      1627536  44274891200     27.00       27.15        26.80
# 4264            0            0     26.85       26.95        26.70
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               0.00              0.00
# 1               0.00              0.00
# 2               0.00              0.00
# 3               0.00              0.00
# 4               0.00              0.00
# ...              ...               ...
# 4260            0.00              0.00
# 4261           -0.30             -1.09
# 4262            0.35              1.30
# 4263           -0.50             -1.83
# 4264           -0.15             -0.56
#
# [4265 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4265 entries, 0 to 4264
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               4265 non-null   object
#  1   GiaDieuChinh       4265 non-null   float64
#  2   GiaDongCua         4265 non-null   float64
#  3   KhoiLuongKhopLenh  4265 non-null   int64
#  4   GiaTriKhopLenh     4265 non-null   int64
#  5   KLThoaThuan        4265 non-null   int64
#  6   GtThoaThuan        4265 non-null   int64
#  7   GiaMoCua           4265 non-null   float64
#  8   GiaCaoNhat         4265 non-null   float64
#  9   GiaThapNhat        4265 non-null   float64
#  10  ThayDoi_GiaTri     4265 non-null   float64
#  11  ThayDoi_PhanTram   4265 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 400.0+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   4265.000000  4265.000000       4.265000e+03    4.265000e+03
# mean       9.711998    37.799097       7.701481e+06    2.589400e+11
# std        9.987066    15.531103       1.122451e+07    3.998703e+11
# min        0.680000    12.100000       0.000000e+00    0.000000e+00
# 25%        1.770000    26.700000       4.509400e+05    1.739584e+10
# 50%        4.640000    33.400000       2.289250e+06    8.454150e+10
# 75%       13.890000    46.300000       1.186764e+07    3.331000e+11
# max       39.900000   127.000000       9.965880e+07    3.724161e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  4.265000e+03  4.265000e+03  4265.000000  4265.000000  4265.000000
# mean   3.557409e+05  1.184203e+10    37.802450    38.294525    37.320317
# std    1.113968e+06  3.472679e+10    15.544325    15.729764    15.306483
# min    0.000000e+00  0.000000e+00    12.000000    12.450000    11.800000
# 25%    0.000000e+00  0.000000e+00    26.700000    27.050000    26.400000
# 50%    0.000000e+00  0.000000e+00    33.500000    33.900000    33.000000
# 75%    2.503000e+05  7.933140e+09    46.300000    46.850000    45.850000
# max    2.669030e+07  8.210834e+11   130.000000   130.000000   121.000000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     4265.000000       4265.000000
# mean         0.014701          0.061461
# std          0.844265          2.125348
# min        -14.400000        -22.860000
# 25%         -0.300000         -0.900000
# 50%          0.000000          0.000000
# 75%          0.300000          0.980000
# max          4.500000          7.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2007-11-15      127.00
# 2007-11-16      121.00
# 2007-11-19      115.00
# 2007-11-20      110.00
# 2007-11-21      114.00
# ...                ...
# 2024-12-16       27.00
# 2024-12-17       27.00
# 2024-12-18       27.35
# 2024-12-19       26.85
# 2024-12-20       26.70
#
# [4265 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[127.  ],
#        [121.  ],
#        [115.  ],
#        ...,
#        [ 27.35],
#        [ 26.85],
#        [ 26.7 ]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/HPG_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.19541, saving model to save_models/HPG_model.keras
# 53/53 - 14s - 264ms/step - loss: 0.1954 - val_loss: 0.1362
# Epoch 2/100
#
# Epoch 2: loss improved from 0.19541 to 0.11695, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 96ms/step - loss: 0.1170 - val_loss: 0.0954
# Epoch 3/100
#
# Epoch 3: loss improved from 0.11695 to 0.08480, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 94ms/step - loss: 0.0848 - val_loss: 0.0706
# Epoch 4/100
#
# Epoch 4: loss improved from 0.08480 to 0.06587, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 94ms/step - loss: 0.0659 - val_loss: 0.0564
# Epoch 5/100
#
# Epoch 5: loss improved from 0.06587 to 0.05512, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 90ms/step - loss: 0.0551 - val_loss: 0.0493
# Epoch 6/100
#
# Epoch 6: loss improved from 0.05512 to 0.04706, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 74ms/step - loss: 0.0471 - val_loss: 0.0435
# Epoch 7/100
#
# Epoch 7: loss improved from 0.04706 to 0.04241, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 75ms/step - loss: 0.0424 - val_loss: 0.0417
# Epoch 8/100
#
# Epoch 8: loss improved from 0.04241 to 0.03964, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 77ms/step - loss: 0.0396 - val_loss: 0.0374
# Epoch 9/100
#
# Epoch 9: loss improved from 0.03964 to 0.03653, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 77ms/step - loss: 0.0365 - val_loss: 0.0419
# Epoch 10/100
#
# Epoch 10: loss improved from 0.03653 to 0.03567, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 75ms/step - loss: 0.0357 - val_loss: 0.0332
# Epoch 11/100
#
# Epoch 11: loss improved from 0.03567 to 0.03229, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 75ms/step - loss: 0.0323 - val_loss: 0.0315
# Epoch 12/100
#
# Epoch 12: loss improved from 0.03229 to 0.03033, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 76ms/step - loss: 0.0303 - val_loss: 0.0306
# Epoch 13/100
#
# Epoch 13: loss improved from 0.03033 to 0.02955, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 76ms/step - loss: 0.0296 - val_loss: 0.0307
# Epoch 14/100
#
# Epoch 14: loss improved from 0.02955 to 0.02828, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 78ms/step - loss: 0.0283 - val_loss: 0.0284
# Epoch 15/100
#
# Epoch 15: loss improved from 0.02828 to 0.02710, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 78ms/step - loss: 0.0271 - val_loss: 0.0281
# Epoch 16/100
#
# Epoch 16: loss improved from 0.02710 to 0.02553, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 79ms/step - loss: 0.0255 - val_loss: 0.0272
# Epoch 17/100
#
# Epoch 17: loss improved from 0.02553 to 0.02532, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 76ms/step - loss: 0.0253 - val_loss: 0.0263
# Epoch 18/100
#
# Epoch 18: loss improved from 0.02532 to 0.02433, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 76ms/step - loss: 0.0243 - val_loss: 0.0255
# Epoch 19/100
#
# Epoch 19: loss improved from 0.02433 to 0.02388, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 77ms/step - loss: 0.0239 - val_loss: 0.0280
# Epoch 20/100
#
# Epoch 20: loss improved from 0.02388 to 0.02375, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 74ms/step - loss: 0.0238 - val_loss: 0.0243
# Epoch 21/100
#
# Epoch 21: loss improved from 0.02375 to 0.02259, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 75ms/step - loss: 0.0226 - val_loss: 0.0242
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.02259
# 53/53 - 4s - 75ms/step - loss: 0.0232 - val_loss: 0.0241
# Epoch 23/100
#
# Epoch 23: loss improved from 0.02259 to 0.02225, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 81ms/step - loss: 0.0223 - val_loss: 0.0233
# Epoch 24/100
#
# Epoch 24: loss improved from 0.02225 to 0.02118, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 78ms/step - loss: 0.0212 - val_loss: 0.0234
# Epoch 25/100
#
# Epoch 25: loss improved from 0.02118 to 0.02094, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 73ms/step - loss: 0.0209 - val_loss: 0.0222
# Epoch 26/100
#
# Epoch 26: loss improved from 0.02094 to 0.02066, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 73ms/step - loss: 0.0207 - val_loss: 0.0223
# Epoch 27/100
#
# Epoch 27: loss improved from 0.02066 to 0.01986, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 75ms/step - loss: 0.0199 - val_loss: 0.0219
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01986
# 53/53 - 4s - 76ms/step - loss: 0.0204 - val_loss: 0.0226
# Epoch 29/100
#
# Epoch 29: loss improved from 0.01986 to 0.01917, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 75ms/step - loss: 0.0192 - val_loss: 0.0211
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.01917
# 53/53 - 4s - 82ms/step - loss: 0.0197 - val_loss: 0.0212
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01917
# 53/53 - 4s - 80ms/step - loss: 0.0198 - val_loss: 0.0232
# Epoch 32/100
#
# Epoch 32: loss improved from 0.01917 to 0.01906, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 88ms/step - loss: 0.0191 - val_loss: 0.0206
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01906
# 53/53 - 4s - 83ms/step - loss: 0.0193 - val_loss: 0.0222
# Epoch 34/100
#
# Epoch 34: loss improved from 0.01906 to 0.01873, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 84ms/step - loss: 0.0187 - val_loss: 0.0221
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01873
# 53/53 - 5s - 87ms/step - loss: 0.0187 - val_loss: 0.0201
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01873
# 53/53 - 4s - 83ms/step - loss: 0.0192 - val_loss: 0.0202
# Epoch 37/100
#
# Epoch 37: loss improved from 0.01873 to 0.01844, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 89ms/step - loss: 0.0184 - val_loss: 0.0194
# Epoch 38/100
#
# Epoch 38: loss improved from 0.01844 to 0.01812, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 86ms/step - loss: 0.0181 - val_loss: 0.0194
# Epoch 39/100
#
# Epoch 39: loss improved from 0.01812 to 0.01806, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 86ms/step - loss: 0.0181 - val_loss: 0.0194
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01806
# 53/53 - 4s - 83ms/step - loss: 0.0184 - val_loss: 0.0195
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01806
# 53/53 - 5s - 85ms/step - loss: 0.0183 - val_loss: 0.0195
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01806
# 53/53 - 4s - 83ms/step - loss: 0.0185 - val_loss: 0.0203
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01806
# 53/53 - 4s - 83ms/step - loss: 0.0181 - val_loss: 0.0194
# Epoch 44/100
#
# Epoch 44: loss improved from 0.01806 to 0.01769, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 76ms/step - loss: 0.0177 - val_loss: 0.0192
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01769
# 53/53 - 4s - 82ms/step - loss: 0.0179 - val_loss: 0.0252
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01769
# 53/53 - 4s - 79ms/step - loss: 0.0179 - val_loss: 0.0191
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01769
# 53/53 - 4s - 79ms/step - loss: 0.0178 - val_loss: 0.0189
# Epoch 48/100
#
# Epoch 48: loss improved from 0.01769 to 0.01741, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 89ms/step - loss: 0.0174 - val_loss: 0.0220
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01741
# 53/53 - 4s - 84ms/step - loss: 0.0175 - val_loss: 0.0205
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01741
# 53/53 - 4s - 84ms/step - loss: 0.0177 - val_loss: 0.0196
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01741
# 53/53 - 4s - 83ms/step - loss: 0.0176 - val_loss: 0.0185
# Epoch 52/100
#
# Epoch 52: loss improved from 0.01741 to 0.01731, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 83ms/step - loss: 0.0173 - val_loss: 0.0221
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01731
# 53/53 - 4s - 80ms/step - loss: 0.0177 - val_loss: 0.0186
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01731
# 53/53 - 4s - 84ms/step - loss: 0.0175 - val_loss: 0.0193
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01731
# 53/53 - 4s - 82ms/step - loss: 0.0180 - val_loss: 0.0183
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01731
# 53/53 - 5s - 88ms/step - loss: 0.0175 - val_loss: 0.0185
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01731
# 53/53 - 4s - 83ms/step - loss: 0.0176 - val_loss: 0.0183
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01731
# 53/53 - 5s - 87ms/step - loss: 0.0175 - val_loss: 0.0189
# Epoch 59/100
#
# Epoch 59: loss improved from 0.01731 to 0.01726, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 85ms/step - loss: 0.0173 - val_loss: 0.0194
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01726
# 53/53 - 5s - 86ms/step - loss: 0.0176 - val_loss: 0.0185
# Epoch 61/100
#
# Epoch 61: loss improved from 0.01726 to 0.01705, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 84ms/step - loss: 0.0170 - val_loss: 0.0178
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01705
# 53/53 - 5s - 86ms/step - loss: 0.0178 - val_loss: 0.0192
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01705
# 53/53 - 4s - 81ms/step - loss: 0.0172 - val_loss: 0.0181
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01705
# 53/53 - 4s - 83ms/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 65/100
#
# Epoch 65: loss improved from 0.01705 to 0.01683, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 76ms/step - loss: 0.0168 - val_loss: 0.0184
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01683
# 53/53 - 4s - 79ms/step - loss: 0.0172 - val_loss: 0.0181
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01683
# 53/53 - 5s - 86ms/step - loss: 0.0174 - val_loss: 0.0175
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01683
# 53/53 - 4s - 79ms/step - loss: 0.0169 - val_loss: 0.0177
# Epoch 69/100
#
# Epoch 69: loss improved from 0.01683 to 0.01672, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 84ms/step - loss: 0.0167 - val_loss: 0.0173
# Epoch 70/100
#
# Epoch 70: loss improved from 0.01672 to 0.01667, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 83ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01667
# 53/53 - 4s - 75ms/step - loss: 0.0168 - val_loss: 0.0170
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01667
# 53/53 - 4s - 83ms/step - loss: 0.0170 - val_loss: 0.0185
# Epoch 73/100
#
# Epoch 73: loss improved from 0.01667 to 0.01664, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 86ms/step - loss: 0.0166 - val_loss: 0.0181
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01664
# 53/53 - 4s - 82ms/step - loss: 0.0170 - val_loss: 0.0190
# Epoch 75/100
#
# Epoch 75: loss improved from 0.01664 to 0.01659, saving model to save_models/HPG_model.keras
# 53/53 - 4s - 85ms/step - loss: 0.0166 - val_loss: 0.0174
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01659
# 53/53 - 4s - 84ms/step - loss: 0.0169 - val_loss: 0.0173
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01659
# 53/53 - 5s - 91ms/step - loss: 0.0166 - val_loss: 0.0172
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01659
# 53/53 - 4s - 84ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01659
# 53/53 - 4s - 85ms/step - loss: 0.0171 - val_loss: 0.0180
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01659
# 53/53 - 4s - 83ms/step - loss: 0.0169 - val_loss: 0.0195
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01659
# 53/53 - 5s - 85ms/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 82/100
#
# Epoch 82: loss improved from 0.01659 to 0.01650, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 85ms/step - loss: 0.0165 - val_loss: 0.0180
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01650
# 53/53 - 5s - 93ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01650
# 53/53 - 6s - 107ms/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01650
# 53/53 - 5s - 90ms/step - loss: 0.0168 - val_loss: 0.0180
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01650
# 53/53 - 5s - 90ms/step - loss: 0.0166 - val_loss: 0.0164
# Epoch 87/100
#
# Epoch 87: loss improved from 0.01650 to 0.01629, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 89ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01629
# 53/53 - 5s - 91ms/step - loss: 0.0164 - val_loss: 0.0200
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01629
# 53/53 - 4s - 84ms/step - loss: 0.0166 - val_loss: 0.0182
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01629
# 53/53 - 5s - 85ms/step - loss: 0.0166 - val_loss: 0.0162
# Epoch 91/100
#
# Epoch 91: loss improved from 0.01629 to 0.01620, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 87ms/step - loss: 0.0162 - val_loss: 0.0168
# Epoch 92/100
#
# Epoch 92: loss improved from 0.01620 to 0.01613, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 86ms/step - loss: 0.0161 - val_loss: 0.0196
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01613
# 53/53 - 5s - 87ms/step - loss: 0.0165 - val_loss: 0.0159
# Epoch 94/100
#
# Epoch 94: loss improved from 0.01613 to 0.01602, saving model to save_models/HPG_model.keras
# 53/53 - 5s - 85ms/step - loss: 0.0160 - val_loss: 0.0158
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01602
# 53/53 - 5s - 90ms/step - loss: 0.0164 - val_loss: 0.0161
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01602
# 53/53 - 5s - 89ms/step - loss: 0.0164 - val_loss: 0.0157
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01602
# 53/53 - 5s - 91ms/step - loss: 0.0164 - val_loss: 0.0157
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01602
# 53/53 - 5s - 96ms/step - loss: 0.0162 - val_loss: 0.0166
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01602
# 53/53 - 5s - 99ms/step - loss: 0.0162 - val_loss: 0.0172
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01602
# 53/53 - 5s - 98ms/step - loss: 0.0162 - val_loss: 0.0193
# Restoring model weights from the end of the best epoch: 94.

# %%
# Hàm xây dựng mô hình
def build_model():
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(units=64))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# Huấn luyện mô hình
model = build_model()
save_model_path = f"save_models/{collection}_model.keras"
best_model = ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.01953, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 9s - 127ms/step - loss: 0.0195
# Epoch 2/100
#
# Epoch 2: loss improved from 0.01953 to 0.01390, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 67ms/step - loss: 0.0139
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01390 to 0.01147, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 69ms/step - loss: 0.0115
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.01147
# 72/72 - 5s - 64ms/step - loss: 0.0124
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01147 to 0.01087, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0109
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01087 to 0.01084, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 64ms/step - loss: 0.0108
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.01084
# 72/72 - 5s - 66ms/step - loss: 0.0114
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.01084
# 72/72 - 5s - 68ms/step - loss: 0.0109
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01084 to 0.01023, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0102
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01023 to 0.00967, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 68ms/step - loss: 0.0097
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00967
# 72/72 - 5s - 66ms/step - loss: 0.0104
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00967
# 72/72 - 5s - 69ms/step - loss: 0.0098
# Epoch 13/100
#
# Epoch 13: loss improved from 0.00967 to 0.00954, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 65ms/step - loss: 0.0095
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00954
# 72/72 - 4s - 62ms/step - loss: 0.0099
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.00954
# 72/72 - 5s - 64ms/step - loss: 0.0098
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.00954
# 72/72 - 5s - 63ms/step - loss: 0.0100
# Epoch 17/100
#
# Epoch 17: loss improved from 0.00954 to 0.00887, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00887
# 72/72 - 4s - 57ms/step - loss: 0.0096
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0095
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0102
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00887
# 72/72 - 4s - 58ms/step - loss: 0.0138
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00887
# 72/72 - 4s - 59ms/step - loss: 0.0094
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00887
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0089
# Epoch 28/100
#
# Epoch 28: loss improved from 0.00887 to 0.00879, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00879 to 0.00859, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00859
# 72/72 - 5s - 75ms/step - loss: 0.0094
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00859
# 72/72 - 4s - 58ms/step - loss: 0.0090
# Epoch 32/100
#
# Epoch 32: loss improved from 0.00859 to 0.00851, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0114
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0091
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0091
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00851
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00851
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0089
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 41/100
#
# Epoch 41: loss improved from 0.00851 to 0.00840, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00840 to 0.00836, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00836
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00836
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 45/100
#
# Epoch 45: loss improved from 0.00836 to 0.00829, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0083
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00829
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00829 to 0.00812, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0086
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0082
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00812
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0093
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00812
# 72/72 - 5s - 63ms/step - loss: 0.0083
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00812 to 0.00806, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00806
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00806 to 0.00791, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0084
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0079
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0108
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0091
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0081
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0085
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00791
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0086
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0081
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00791 to 0.00789, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0079
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0112
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0094
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00789
# 72/72 - 4s - 59ms/step - loss: 0.0095
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00789
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00789
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0080
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 89/100
#
# Epoch 89: loss improved from 0.00789 to 0.00785, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0079
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00785 to 0.00780, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0078
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0080
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0083
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00780
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00780
# 72/72 - 5s - 63ms/step - loss: 0.0084
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00780 to 0.00772, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0077

# %%
save_model_path = "save_models/HPG_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
# Chọn dữ liệu cho test_data12
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9855636404868571
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 1.055213533590976
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.7019622213876326
# RMSE trên tập train (VNĐ): 1.7035852034113135
# Độ chính xác trên tập train (%): 98.00750268606863
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9917656807601669
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.6726842835528071
# Phần trăm sai số tuyệt đối trung bình trên tập test: 2.3660244879795362
# RMSE trên tập test (VNĐ): 0.9753645140858279
# Độ chính xác trên tập test (%): 97.87502284512891
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
