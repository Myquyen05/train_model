# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['CTG']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2009-07-16         11.09       40.10            2401900     97697685000
# 1     2009-07-21          9.65       34.90            2133390     73973277000
# 2     2009-07-24         10.76       38.90             640060     24898334000
# 3     2009-07-30         10.48       37.90             830120     31154445000
# 4     2009-08-03         11.06       40.00            1203870     48352269000
# ...          ...           ...         ...                ...             ...
# 3850  2024-12-17         36.25       36.25            3429900    124298000000
# 3851  2024-12-13         36.35       36.35            4180300    151817000000
# 3852  2024-12-18         36.25       36.25            2933300    106070000000
# 3853  2024-12-19         36.20       36.20            6319500    226471000000
# 3854  2024-12-20         36.15       36.15            3418200    122893000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0     40.00       45.00        40.00
# 1               0            0     34.40       35.50        34.40
# 2               0            0     38.90       38.90        38.90
# 3               0            0     37.80       38.50        37.00
# 4               0            0     40.00       40.80        39.50
# ...           ...          ...       ...         ...          ...
# 3850       114000   4138200000     36.25       36.35        36.05
# 3851       114000   4144700000     36.15       36.50        36.10
# 3852        20000    728000000     36.20       36.40        35.80
# 3853        44000   1592800000     35.85       36.20        35.60
# 3854            0            0     36.00       36.15        35.70
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0              -9.90            -19.80
# 1              -1.30             -3.59
# 2               1.80              4.85
# 3              -0.70             -1.81
# 4               0.30              0.76
# ...              ...               ...
# 3850            0.00              0.00
# 3851            0.05              0.14
# 3852            0.00              0.00
# 3853           -0.05             -0.14
# 3854           -0.05             -0.14
#
# [3855 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3855 entries, 0 to 3854
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               3855 non-null   object
#  1   GiaDieuChinh       3855 non-null   float64
#  2   GiaDongCua         3855 non-null   float64
#  3   KhoiLuongKhopLenh  3855 non-null   int64
#  4   GiaTriKhopLenh     3855 non-null   int64
#  5   KLThoaThuan        3855 non-null   int64
#  6   GtThoaThuan        3855 non-null   int64
#  7   GiaMoCua           3855 non-null   float64
#  8   GiaCaoNhat         3855 non-null   float64
#  9   GiaThapNhat        3855 non-null   float64
#  10  ThayDoi_GiaTri     3855 non-null   float64
#  11  ThayDoi_PhanTram   3855 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 361.5+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   3855.000000  3855.000000       3.855000e+03    3.855000e+03
# mean      15.905134    24.452879       3.609781e+06    1.082348e+11
# std        8.298953     7.051608       4.487221e+06    1.691182e+11
# min        5.730000    13.700000       1.849000e+04    4.326700e+08
# 25%        9.580000    18.800000       4.543800e+05    8.953684e+09
# 50%       12.310000    22.850000       1.913600e+06    4.155700e+10
# 75%       22.925000    29.000000       5.200970e+06    1.377265e+11
# max       37.000000    54.400000       3.512210e+07    1.670233e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  3.855000e+03  3.855000e+03  3855.000000  3855.000000  3855.000000
# mean   1.990234e+05  5.106468e+09    24.466148    24.788495    24.161193
# std    1.566953e+06  3.488991e+10     7.061550     7.167611     6.945732
# min    0.000000e+00  0.000000e+00    13.700000    13.700000    13.600000
# 25%    0.000000e+00  0.000000e+00    18.800000    19.050000    18.650000
# 50%    0.000000e+00  0.000000e+00    22.850000    23.250000    22.500000
# 75%    8.000000e+04  1.998000e+09    29.050000    29.350000    28.700000
# max    5.739205e+07  1.233929e+12    54.500000    54.900000    53.800000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     3855.000000       3855.000000
# mean        -0.001362          0.023276
# std          0.575130          2.077625
# min         -9.900000        -19.800000
# 25%         -0.200000         -0.985000
# 50%          0.000000          0.000000
# 75%          0.200000          0.930000
# max          3.400000          6.990000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2009-07-16       40.10
# 2009-07-17       38.10
# 2009-07-20       36.20
# 2009-07-21       34.90
# 2009-07-22       35.40
# ...                ...
# 2024-12-16       36.25
# 2024-12-17       36.25
# 2024-12-18       36.25
# 2024-12-19       36.20
# 2024-12-20       36.15
#
# [3855 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[40.1 ],
#        [38.1 ],
#        [36.2 ],
#        ...,
#        [36.25],
#        [36.2 ],
#        [36.15]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/CTG_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.20027, saving model to save_models/CTG_model.keras
# 48/48 - 8s - 165ms/step - loss: 0.2003 - val_loss: 0.1362
# Epoch 2/100
#
# Epoch 2: loss improved from 0.20027 to 0.12651, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 85ms/step - loss: 0.1265 - val_loss: 0.0980
# Epoch 3/100
#
# Epoch 3: loss improved from 0.12651 to 0.09466, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0947 - val_loss: 0.0707
# Epoch 4/100
#
# Epoch 4: loss improved from 0.09466 to 0.07318, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0732 - val_loss: 0.0613
# Epoch 5/100
#
# Epoch 5: loss improved from 0.07318 to 0.06215, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 78ms/step - loss: 0.0621 - val_loss: 0.0509
# Epoch 6/100
#
# Epoch 6: loss improved from 0.06215 to 0.05474, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0547 - val_loss: 0.0423
# Epoch 7/100
#
# Epoch 7: loss improved from 0.05474 to 0.04802, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0480 - val_loss: 0.0396
# Epoch 8/100
#
# Epoch 8: loss improved from 0.04802 to 0.04486, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0449 - val_loss: 0.0371
# Epoch 9/100
#
# Epoch 9: loss improved from 0.04486 to 0.04151, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 78ms/step - loss: 0.0415 - val_loss: 0.0325
# Epoch 10/100
#
# Epoch 10: loss improved from 0.04151 to 0.04031, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 79ms/step - loss: 0.0403 - val_loss: 0.0315
# Epoch 11/100
#
# Epoch 11: loss improved from 0.04031 to 0.03724, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0372 - val_loss: 0.0295
# Epoch 12/100
#
# Epoch 12: loss improved from 0.03724 to 0.03607, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 83ms/step - loss: 0.0361 - val_loss: 0.0304
# Epoch 13/100
#
# Epoch 13: loss improved from 0.03607 to 0.03418, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0342 - val_loss: 0.0273
# Epoch 14/100
#
# Epoch 14: loss improved from 0.03418 to 0.03280, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 75ms/step - loss: 0.0328 - val_loss: 0.0269
# Epoch 15/100
#
# Epoch 15: loss improved from 0.03280 to 0.03198, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 75ms/step - loss: 0.0320 - val_loss: 0.0313
# Epoch 16/100
#
# Epoch 16: loss improved from 0.03198 to 0.03093, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 76ms/step - loss: 0.0309 - val_loss: 0.0251
# Epoch 17/100
#
# Epoch 17: loss improved from 0.03093 to 0.03006, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 76ms/step - loss: 0.0301 - val_loss: 0.0241
# Epoch 18/100
#
# Epoch 18: loss improved from 0.03006 to 0.02922, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 80ms/step - loss: 0.0292 - val_loss: 0.0271
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.02922
# 48/48 - 4s - 84ms/step - loss: 0.0293 - val_loss: 0.0245
# Epoch 20/100
#
# Epoch 20: loss improved from 0.02922 to 0.02780, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 85ms/step - loss: 0.0278 - val_loss: 0.0255
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.02780
# 48/48 - 4s - 80ms/step - loss: 0.0282 - val_loss: 0.0229
# Epoch 22/100
#
# Epoch 22: loss improved from 0.02780 to 0.02759, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 80ms/step - loss: 0.0276 - val_loss: 0.0227
# Epoch 23/100
#
# Epoch 23: loss improved from 0.02759 to 0.02617, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0262 - val_loss: 0.0223
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.02617
# 48/48 - 4s - 81ms/step - loss: 0.0266 - val_loss: 0.0229
# Epoch 25/100
#
# Epoch 25: loss improved from 0.02617 to 0.02613, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 79ms/step - loss: 0.0261 - val_loss: 0.0225
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.02613
# 48/48 - 4s - 75ms/step - loss: 0.0263 - val_loss: 0.0216
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.02613
# 48/48 - 4s - 79ms/step - loss: 0.0262 - val_loss: 0.0215
# Epoch 28/100
#
# Epoch 28: loss improved from 0.02613 to 0.02515, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0252 - val_loss: 0.0207
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.02515
# 48/48 - 4s - 79ms/step - loss: 0.0252 - val_loss: 0.0206
# Epoch 30/100
#
# Epoch 30: loss improved from 0.02515 to 0.02479, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 85ms/step - loss: 0.0248 - val_loss: 0.0240
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.02479
# 48/48 - 4s - 84ms/step - loss: 0.0251 - val_loss: 0.0210
# Epoch 32/100
#
# Epoch 32: loss improved from 0.02479 to 0.02454, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 84ms/step - loss: 0.0245 - val_loss: 0.0201
# Epoch 33/100
#
# Epoch 33: loss improved from 0.02454 to 0.02438, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 84ms/step - loss: 0.0244 - val_loss: 0.0250
# Epoch 34/100
#
# Epoch 34: loss improved from 0.02438 to 0.02434, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 89ms/step - loss: 0.0243 - val_loss: 0.0197
# Epoch 35/100
#
# Epoch 35: loss improved from 0.02434 to 0.02407, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 86ms/step - loss: 0.0241 - val_loss: 0.0210
# Epoch 36/100
#
# Epoch 36: loss improved from 0.02407 to 0.02403, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 86ms/step - loss: 0.0240 - val_loss: 0.0195
# Epoch 37/100
#
# Epoch 37: loss improved from 0.02403 to 0.02281, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 88ms/step - loss: 0.0228 - val_loss: 0.0192
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.02281
# 48/48 - 4s - 87ms/step - loss: 0.0241 - val_loss: 0.0197
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.02281
# 48/48 - 4s - 84ms/step - loss: 0.0242 - val_loss: 0.0215
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.02281
# 48/48 - 4s - 84ms/step - loss: 0.0236 - val_loss: 0.0192
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.02281
# 48/48 - 4s - 87ms/step - loss: 0.0236 - val_loss: 0.0192
# Epoch 42/100
#
# Epoch 42: loss improved from 0.02281 to 0.02262, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 86ms/step - loss: 0.0226 - val_loss: 0.0185
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.02262
# 48/48 - 4s - 92ms/step - loss: 0.0233 - val_loss: 0.0184
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.02262
# 48/48 - 4s - 91ms/step - loss: 0.0233 - val_loss: 0.0184
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.02262
# 48/48 - 4s - 86ms/step - loss: 0.0233 - val_loss: 0.0194
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.02262
# 48/48 - 4s - 85ms/step - loss: 0.0233 - val_loss: 0.0183
# Epoch 47/100
#
# Epoch 47: loss improved from 0.02262 to 0.02250, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 93ms/step - loss: 0.0225 - val_loss: 0.0186
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.02250
# 48/48 - 4s - 91ms/step - loss: 0.0231 - val_loss: 0.0182
# Epoch 49/100
#
# Epoch 49: loss improved from 0.02250 to 0.02248, saving model to save_models/CTG_model.keras
# 48/48 - 5s - 95ms/step - loss: 0.0225 - val_loss: 0.0186
# Epoch 50/100
#
# Epoch 50: loss improved from 0.02248 to 0.02208, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 93ms/step - loss: 0.0221 - val_loss: 0.0180
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.02208
# 48/48 - 4s - 91ms/step - loss: 0.0227 - val_loss: 0.0179
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.02208
# 48/48 - 5s - 100ms/step - loss: 0.0222 - val_loss: 0.0185
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.02208
# 48/48 - 4s - 82ms/step - loss: 0.0225 - val_loss: 0.0179
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.02208
# 48/48 - 4s - 84ms/step - loss: 0.0232 - val_loss: 0.0229
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.02208
# 48/48 - 4s - 83ms/step - loss: 0.0224 - val_loss: 0.0188
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.02208
# 48/48 - 4s - 89ms/step - loss: 0.0224 - val_loss: 0.0181
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.02208
# 48/48 - 5s - 96ms/step - loss: 0.0228 - val_loss: 0.0194
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.02208
# 48/48 - 4s - 85ms/step - loss: 0.0222 - val_loss: 0.0176
# Epoch 59/100
#
# Epoch 59: loss improved from 0.02208 to 0.02194, saving model to save_models/CTG_model.keras
# 48/48 - 5s - 94ms/step - loss: 0.0219 - val_loss: 0.0176
# Epoch 60/100
#
# Epoch 60: loss improved from 0.02194 to 0.02179, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 92ms/step - loss: 0.0218 - val_loss: 0.0174
# Epoch 61/100
#
# Epoch 61: loss improved from 0.02179 to 0.02178, saving model to save_models/CTG_model.keras
# 48/48 - 5s - 96ms/step - loss: 0.0218 - val_loss: 0.0176
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.02178
# 48/48 - 4s - 90ms/step - loss: 0.0221 - val_loss: 0.0176
# Epoch 63/100
#
# Epoch 63: loss improved from 0.02178 to 0.02119, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 92ms/step - loss: 0.0212 - val_loss: 0.0171
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.02119
# 48/48 - 4s - 85ms/step - loss: 0.0221 - val_loss: 0.0182
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.02119
# 48/48 - 4s - 85ms/step - loss: 0.0218 - val_loss: 0.0180
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.02119
# 48/48 - 5s - 95ms/step - loss: 0.0217 - val_loss: 0.0175
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.02119
# 48/48 - 4s - 80ms/step - loss: 0.0215 - val_loss: 0.0190
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.02119
# 48/48 - 4s - 84ms/step - loss: 0.0215 - val_loss: 0.0170
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.02119
# 48/48 - 5s - 97ms/step - loss: 0.0221 - val_loss: 0.0174
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.02119
# 48/48 - 5s - 101ms/step - loss: 0.0214 - val_loss: 0.0170
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02119
# 48/48 - 5s - 98ms/step - loss: 0.0214 - val_loss: 0.0168
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.02119
# 48/48 - 5s - 104ms/step - loss: 0.0216 - val_loss: 0.0170
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.02119
# 48/48 - 4s - 89ms/step - loss: 0.0215 - val_loss: 0.0208
# Epoch 74/100
#
# Epoch 74: loss improved from 0.02119 to 0.02103, saving model to save_models/CTG_model.keras
# 48/48 - 5s - 102ms/step - loss: 0.0210 - val_loss: 0.0167
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.02103
# 48/48 - 4s - 85ms/step - loss: 0.0213 - val_loss: 0.0167
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02103
# 48/48 - 5s - 95ms/step - loss: 0.0213 - val_loss: 0.0187
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.02103
# 48/48 - 4s - 78ms/step - loss: 0.0219 - val_loss: 0.0182
# Epoch 78/100
#
# Epoch 78: loss improved from 0.02103 to 0.02099, saving model to save_models/CTG_model.keras
# 48/48 - 5s - 94ms/step - loss: 0.0210 - val_loss: 0.0167
# Epoch 79/100
#
# Epoch 79: loss improved from 0.02099 to 0.02063, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 87ms/step - loss: 0.0206 - val_loss: 0.0174
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.02063
# 48/48 - 4s - 92ms/step - loss: 0.0211 - val_loss: 0.0195
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.02063
# 48/48 - 4s - 92ms/step - loss: 0.0212 - val_loss: 0.0181
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.02063
# 48/48 - 4s - 86ms/step - loss: 0.0215 - val_loss: 0.0183
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.02063
# 48/48 - 4s - 81ms/step - loss: 0.0220 - val_loss: 0.0169
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.02063
# 48/48 - 4s - 89ms/step - loss: 0.0219 - val_loss: 0.0166
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.02063
# 48/48 - 4s - 90ms/step - loss: 0.0209 - val_loss: 0.0166
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.02063
# 48/48 - 4s - 86ms/step - loss: 0.0208 - val_loss: 0.0172
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.02063
# 48/48 - 4s - 83ms/step - loss: 0.0211 - val_loss: 0.0163
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.02063
# 48/48 - 4s - 89ms/step - loss: 0.0214 - val_loss: 0.0177
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.02063
# 48/48 - 4s - 78ms/step - loss: 0.0213 - val_loss: 0.0166
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.02063
# 48/48 - 5s - 96ms/step - loss: 0.0209 - val_loss: 0.0190
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.02063
# 48/48 - 4s - 91ms/step - loss: 0.0208 - val_loss: 0.0162
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.02063
# 48/48 - 5s - 96ms/step - loss: 0.0208 - val_loss: 0.0163
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.02063
# 48/48 - 4s - 86ms/step - loss: 0.0218 - val_loss: 0.0163
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.02063
# 48/48 - 4s - 88ms/step - loss: 0.0211 - val_loss: 0.0175
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.02063
# 48/48 - 4s - 86ms/step - loss: 0.0207 - val_loss: 0.0159
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.02063
# 48/48 - 4s - 80ms/step - loss: 0.0209 - val_loss: 0.0163
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.02063
# 48/48 - 4s - 88ms/step - loss: 0.0207 - val_loss: 0.0159
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.02063
# 48/48 - 4s - 85ms/step - loss: 0.0210 - val_loss: 0.0160
# Epoch 99/100
#
# Epoch 99: loss improved from 0.02063 to 0.02047, saving model to save_models/CTG_model.keras
# 48/48 - 4s - 91ms/step - loss: 0.0205 - val_loss: 0.0158
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.02047
# 48/48 - 5s - 94ms/step - loss: 0.0205 - val_loss: 0.0158
# Restoring model weights from the end of the best epoch: 99.

# %%
# save_model_path = "save_models/CTG_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9871088531501306
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 0.48527067400706625
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.0555295833154594
# RMSE trên tập train (VNĐ): 0.7552296963144518
# Độ chính xác trên tập train (%): 98.14439878055417
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9573500050719358
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.5600025518395094
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.8865476711175975
# RMSE trên tập test (VNĐ): 0.7433334844255863
# Độ chính xác trên tập test (%): 95.83566675391828
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
