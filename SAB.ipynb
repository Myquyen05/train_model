# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['SAB']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2016-12-07         58.13       141.2                 30         4000000
# 1     2016-12-08         62.16       151.0               1000       151000000
# 2     2016-12-30         82.63       197.7              96740     18983000000
# 3     2017-01-04         82.34       197.0              87490     17252000000
# 4     2017-01-10         85.47       204.5              44540      9068000000
# ...          ...           ...         ...                ...             ...
# 2005  2024-12-17         57.30        57.3             339400     19452000000
# 2006  2024-12-13         57.40        57.4             461700     26554000000
# 2007  2024-12-18         57.40        57.4             270100     15512000000
# 2008  2024-12-19         56.90        56.9             769800     43759000000
# 2009  2024-12-20         56.50        56.5             778600     44098000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0          285300  35200750000     141.2       141.2        141.2
# 1               0            0     151.0       151.0        151.0
# 2           27000   5688900000     198.0       198.0        195.5
# 3               0            0     197.0       198.6        195.0
# 4               0            0     206.9       206.9        201.5
# ...           ...          ...       ...         ...          ...
# 2005       110000   6257500000      57.5        57.6         57.0
# 2006       110000   6308000000      57.5        57.7         57.2
# 2007        70000   4011000000      57.3        57.6         57.3
# 2008        90000   4948500000      57.0        57.3         56.4
# 2009            0            0      56.9        57.1         56.4
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0                9.2              6.97
# 1                9.8              6.94
# 2                0.7              0.36
# 3                0.0              0.00
# 4               -0.5             -0.24
# ...              ...               ...
# 2005             0.0              0.00
# 2006            -0.1             -0.17
# 2007             0.1              0.17
# 2008            -0.5             -0.87
# 2009            -0.4             -0.70
#
# [2010 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2010 entries, 0 to 2009
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               2010 non-null   object
#  1   GiaDieuChinh       2010 non-null   float64
#  2   GiaDongCua         2010 non-null   float64
#  3   KhoiLuongKhopLenh  2010 non-null   int64
#  4   GiaTriKhopLenh     2010 non-null   int64
#  5   KLThoaThuan        2010 non-null   int64
#  6   GtThoaThuan        2010 non-null   int64
#  7   GiaMoCua           2010 non-null   float64
#  8   GiaCaoNhat         2010 non-null   float64
#  9   GiaThapNhat        2010 non-null   float64
#  10  ThayDoi_GiaTri     2010 non-null   float64
#  11  ThayDoi_PhanTram   2010 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 188.6+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   2010.000000  2010.000000       2.010000e+03    2.010000e+03
# mean      83.754055   179.862438       2.181134e+05    2.421814e+10
# std       18.311197    64.476871       3.479111e+05    2.297775e+10
# min       50.780000    52.000000       3.000000e+01    4.000000e+06
# 25%       70.910000   155.100000       4.219500e+04    8.978250e+09
# 50%       82.200000   184.750000       1.022850e+05    1.865650e+10
# 75%       96.460000   226.000000       2.150800e+05    3.179175e+10
# max      141.690000   339.000000       3.852700e+06    2.445010e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  2.010000e+03  2.010000e+03  2010.000000  2010.000000  2010.000000
# mean   8.433639e+04  1.329580e+10   179.947015   182.037861   177.662090
# std    6.331476e+05  1.149736e+11    64.421553    65.199835    63.484591
# min    0.000000e+00  0.000000e+00    52.800000    53.600000    52.000000
# 25%    0.000000e+00  0.000000e+00   155.225000   157.000000   153.925000
# 50%    3.000000e+04  4.527000e+09   185.000000   186.800000   183.000000
# 75%    8.000000e+04  1.110390e+10   226.075000   230.000000   223.500000
# max    2.661734e+07  4.897591e+12   341.800000   347.000000   330.000000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     2010.000000       2010.000000
# mean         0.018303          0.018547
# std          2.859814          1.531433
# min        -21.600000         -6.990000
# 25%         -0.600000         -0.420000
# 50%          0.000000          0.000000
# 75%          0.500000          0.307500
# max         16.700000          7.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2016-12-06       132.0
# 2016-12-07       141.2
# 2016-12-08       151.0
# 2016-12-09       161.5
# 2016-12-12       172.8
# ...                ...
# 2024-12-16        57.3
# 2024-12-17        57.3
# 2024-12-18        57.4
# 2024-12-19        56.9
# 2024-12-20        56.5
#
# [2010 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[132. ],
#        [141.2],
#        [151. ],
#        ...,
#        [ 57.4],
#        [ 56.9],
#        [ 56.5]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # Giảm số đơn vị trong LSTM và tăng regularization
    model.add(LSTM(units=64, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.35))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0001))
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/SAB_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=15, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.60601, saving model to save_models/SAB_model.keras
# 25/25 - 5s - 216ms/step - loss: 0.6060 - val_loss: 0.6153
# Epoch 2/100
#
# Epoch 2: loss improved from 0.60601 to 0.41176, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 56ms/step - loss: 0.4118 - val_loss: 0.3294
# Epoch 3/100
#
# Epoch 3: loss improved from 0.41176 to 0.19109, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 55ms/step - loss: 0.1911 - val_loss: 0.1246
# Epoch 4/100
#
# Epoch 4: loss improved from 0.19109 to 0.17110, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 48ms/step - loss: 0.1711 - val_loss: 0.1383
# Epoch 5/100
#
# Epoch 5: loss improved from 0.17110 to 0.16532, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 50ms/step - loss: 0.1653 - val_loss: 0.1331
# Epoch 6/100
#
# Epoch 6: loss improved from 0.16532 to 0.15938, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 44ms/step - loss: 0.1594 - val_loss: 0.1270
# Epoch 7/100
#
# Epoch 7: loss improved from 0.15938 to 0.15480, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.1548 - val_loss: 0.1207
# Epoch 8/100
#
# Epoch 8: loss improved from 0.15480 to 0.15290, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.1529 - val_loss: 0.1163
# Epoch 9/100
#
# Epoch 9: loss improved from 0.15290 to 0.14592, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.1459 - val_loss: 0.1161
# Epoch 10/100
#
# Epoch 10: loss improved from 0.14592 to 0.14571, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.1457 - val_loss: 0.1142
# Epoch 11/100
#
# Epoch 11: loss improved from 0.14571 to 0.13849, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.1385 - val_loss: 0.1098
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.13849
# 25/25 - 1s - 41ms/step - loss: 0.1402 - val_loss: 0.1116
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.13849
# 25/25 - 1s - 45ms/step - loss: 0.1395 - val_loss: 0.1043
# Epoch 14/100
#
# Epoch 14: loss improved from 0.13849 to 0.13460, saving model to save_models/SAB_model.keras
# 25/25 - 2s - 94ms/step - loss: 0.1346 - val_loss: 0.1050
# Epoch 15/100
#
# Epoch 15: loss improved from 0.13460 to 0.13201, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 48ms/step - loss: 0.1320 - val_loss: 0.1020
# Epoch 16/100
#
# Epoch 16: loss improved from 0.13201 to 0.12627, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 44ms/step - loss: 0.1263 - val_loss: 0.1016
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.12627
# 25/25 - 1s - 42ms/step - loss: 0.1280 - val_loss: 0.0998
# Epoch 18/100
#
# Epoch 18: loss improved from 0.12627 to 0.12556, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 43ms/step - loss: 0.1256 - val_loss: 0.1009
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.12556
# 25/25 - 1s - 41ms/step - loss: 0.1258 - val_loss: 0.0940
# Epoch 20/100
#
# Epoch 20: loss improved from 0.12556 to 0.12158, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 42ms/step - loss: 0.1216 - val_loss: 0.0991
# Epoch 21/100
#
# Epoch 21: loss improved from 0.12158 to 0.12150, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 41ms/step - loss: 0.1215 - val_loss: 0.0973
# Epoch 22/100
#
# Epoch 22: loss improved from 0.12150 to 0.11894, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 45ms/step - loss: 0.1189 - val_loss: 0.0899
# Epoch 23/100
#
# Epoch 23: loss improved from 0.11894 to 0.11797, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 53ms/step - loss: 0.1180 - val_loss: 0.0926
# Epoch 24/100
#
# Epoch 24: loss improved from 0.11797 to 0.11654, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.1165 - val_loss: 0.0872
# Epoch 25/100
#
# Epoch 25: loss improved from 0.11654 to 0.11455, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.1145 - val_loss: 0.0886
# Epoch 26/100
#
# Epoch 26: loss improved from 0.11455 to 0.11088, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.1109 - val_loss: 0.0862
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.11088
# 25/25 - 1s - 47ms/step - loss: 0.1121 - val_loss: 0.0866
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.11088
# 25/25 - 1s - 45ms/step - loss: 0.1116 - val_loss: 0.0894
# Epoch 29/100
#
# Epoch 29: loss improved from 0.11088 to 0.10985, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 46ms/step - loss: 0.1099 - val_loss: 0.0807
# Epoch 30/100
#
# Epoch 30: loss improved from 0.10985 to 0.10730, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.1073 - val_loss: 0.0796
# Epoch 31/100
#
# Epoch 31: loss improved from 0.10730 to 0.10644, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.1064 - val_loss: 0.0787
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.10644
# 25/25 - 1s - 46ms/step - loss: 0.1066 - val_loss: 0.0808
# Epoch 33/100
#
# Epoch 33: loss improved from 0.10644 to 0.10340, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 55ms/step - loss: 0.1034 - val_loss: 0.0773
# Epoch 34/100
#
# Epoch 34: loss improved from 0.10340 to 0.10028, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 59ms/step - loss: 0.1003 - val_loss: 0.0774
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.10028
# 25/25 - 1s - 50ms/step - loss: 0.1043 - val_loss: 0.0800
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.10028
# 25/25 - 1s - 48ms/step - loss: 0.1013 - val_loss: 0.0781
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.10028
# 25/25 - 1s - 49ms/step - loss: 0.1018 - val_loss: 0.0750
# Epoch 38/100
#
# Epoch 38: loss improved from 0.10028 to 0.09728, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.0973 - val_loss: 0.0731
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.09728
# 25/25 - 1s - 47ms/step - loss: 0.0977 - val_loss: 0.0710
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.09728
# 25/25 - 1s - 41ms/step - loss: 0.0990 - val_loss: 0.0703
# Epoch 41/100
#
# Epoch 41: loss improved from 0.09728 to 0.09716, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.0972 - val_loss: 0.0702
# Epoch 42/100
#
# Epoch 42: loss improved from 0.09716 to 0.09469, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.0947 - val_loss: 0.0717
# Epoch 43/100
#
# Epoch 43: loss improved from 0.09469 to 0.09308, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.0931 - val_loss: 0.0684
# Epoch 44/100
#
# Epoch 44: loss improved from 0.09308 to 0.09060, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.0906 - val_loss: 0.0698
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.09060
# 25/25 - 1s - 45ms/step - loss: 0.0911 - val_loss: 0.0670
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.09060
# 25/25 - 1s - 45ms/step - loss: 0.0945 - val_loss: 0.0728
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.09060
# 25/25 - 1s - 44ms/step - loss: 0.0921 - val_loss: 0.0702
# Epoch 48/100
#
# Epoch 48: loss improved from 0.09060 to 0.08944, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 48ms/step - loss: 0.0894 - val_loss: 0.0645
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.08944
# 25/25 - 1s - 48ms/step - loss: 0.0903 - val_loss: 0.0639
# Epoch 50/100
#
# Epoch 50: loss improved from 0.08944 to 0.08763, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 50ms/step - loss: 0.0876 - val_loss: 0.0633
# Epoch 51/100
#
# Epoch 51: loss improved from 0.08763 to 0.08704, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 52ms/step - loss: 0.0870 - val_loss: 0.0650
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.08704
# 25/25 - 1s - 47ms/step - loss: 0.0887 - val_loss: 0.0614
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.08704
# 25/25 - 1s - 42ms/step - loss: 0.0872 - val_loss: 0.0630
# Epoch 54/100
#
# Epoch 54: loss improved from 0.08704 to 0.08546, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 50ms/step - loss: 0.0855 - val_loss: 0.0630
# Epoch 55/100
#
# Epoch 55: loss improved from 0.08546 to 0.08479, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.0848 - val_loss: 0.0622
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.08479
# 25/25 - 1s - 45ms/step - loss: 0.0850 - val_loss: 0.0594
# Epoch 57/100
#
# Epoch 57: loss improved from 0.08479 to 0.08366, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.0837 - val_loss: 0.0589
# Epoch 58/100
#
# Epoch 58: loss improved from 0.08366 to 0.08158, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.0816 - val_loss: 0.0643
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.08158
# 25/25 - 1s - 47ms/step - loss: 0.0831 - val_loss: 0.0579
# Epoch 60/100
#
# Epoch 60: loss improved from 0.08158 to 0.08087, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.0809 - val_loss: 0.0574
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.08087
# 25/25 - 1s - 45ms/step - loss: 0.0825 - val_loss: 0.0603
# Epoch 62/100
#
# Epoch 62: loss improved from 0.08087 to 0.07959, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 58ms/step - loss: 0.0796 - val_loss: 0.0564
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.07959
# 25/25 - 1s - 43ms/step - loss: 0.0806 - val_loss: 0.0579
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.07959
# 25/25 - 1s - 43ms/step - loss: 0.0818 - val_loss: 0.0566
# Epoch 65/100
#
# Epoch 65: loss improved from 0.07959 to 0.07947, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 48ms/step - loss: 0.0795 - val_loss: 0.0550
# Epoch 66/100
#
# Epoch 66: loss improved from 0.07947 to 0.07846, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.0785 - val_loss: 0.0570
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.07846
# 25/25 - 1s - 46ms/step - loss: 0.0792 - val_loss: 0.0575
# Epoch 68/100
#
# Epoch 68: loss improved from 0.07846 to 0.07837, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.0784 - val_loss: 0.0556
# Epoch 69/100
#
# Epoch 69: loss improved from 0.07837 to 0.07732, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 46ms/step - loss: 0.0773 - val_loss: 0.0538
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.07732
# 25/25 - 1s - 49ms/step - loss: 0.0781 - val_loss: 0.0574
# Epoch 71/100
#
# Epoch 71: loss improved from 0.07732 to 0.07441, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 48ms/step - loss: 0.0744 - val_loss: 0.0575
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.07441
# 25/25 - 1s - 47ms/step - loss: 0.0762 - val_loss: 0.0560
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.07441
# 25/25 - 1s - 51ms/step - loss: 0.0767 - val_loss: 0.0526
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.07441
# 25/25 - 1s - 50ms/step - loss: 0.0750 - val_loss: 0.0584
# Epoch 75/100
#
# Epoch 75: loss improved from 0.07441 to 0.07370, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.0737 - val_loss: 0.0566
# Epoch 76/100
#
# Epoch 76: loss improved from 0.07370 to 0.07272, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 50ms/step - loss: 0.0727 - val_loss: 0.0572
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.07272
# 25/25 - 1s - 50ms/step - loss: 0.0735 - val_loss: 0.0514
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.07272
# 25/25 - 1s - 52ms/step - loss: 0.0743 - val_loss: 0.0511
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.07272
# 25/25 - 1s - 47ms/step - loss: 0.0735 - val_loss: 0.0550
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.07272
# 25/25 - 1s - 58ms/step - loss: 0.0735 - val_loss: 0.0512
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.07272
# 25/25 - 1s - 53ms/step - loss: 0.0736 - val_loss: 0.0506
# Epoch 82/100
#
# Epoch 82: loss improved from 0.07272 to 0.07179, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 47ms/step - loss: 0.0718 - val_loss: 0.0505
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.07179
# 25/25 - 1s - 48ms/step - loss: 0.0720 - val_loss: 0.0523
# Epoch 84/100
#
# Epoch 84: loss improved from 0.07179 to 0.07135, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 51ms/step - loss: 0.0713 - val_loss: 0.0517
# Epoch 85/100
#
# Epoch 85: loss improved from 0.07135 to 0.07021, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.0702 - val_loss: 0.0535
# Epoch 86/100
#
# Epoch 86: loss improved from 0.07021 to 0.06956, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 49ms/step - loss: 0.0696 - val_loss: 0.0491
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.06956
# 25/25 - 1s - 53ms/step - loss: 0.0719 - val_loss: 0.0540
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.06956
# 25/25 - 1s - 53ms/step - loss: 0.0700 - val_loss: 0.0510
# Epoch 89/100
#
# Epoch 89: loss improved from 0.06956 to 0.06914, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 54ms/step - loss: 0.0691 - val_loss: 0.0531
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.06914
# 25/25 - 1s - 53ms/step - loss: 0.0705 - val_loss: 0.0487
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.06914
# 25/25 - 1s - 49ms/step - loss: 0.0718 - val_loss: 0.0519
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.06914
# 25/25 - 1s - 48ms/step - loss: 0.0717 - val_loss: 0.0551
# Epoch 93/100
#
# Epoch 93: loss improved from 0.06914 to 0.06795, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 50ms/step - loss: 0.0680 - val_loss: 0.0487
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.06795
# 25/25 - 1s - 48ms/step - loss: 0.0697 - val_loss: 0.0503
# Epoch 95/100
#
# Epoch 95: loss improved from 0.06795 to 0.06792, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 48ms/step - loss: 0.0679 - val_loss: 0.0587
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.06792
# 25/25 - 1s - 52ms/step - loss: 0.0696 - val_loss: 0.0550
# Epoch 97/100
#
# Epoch 97: loss improved from 0.06792 to 0.06716, saving model to save_models/SAB_model.keras
# 25/25 - 1s - 48ms/step - loss: 0.0672 - val_loss: 0.0476
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.06716
# 25/25 - 1s - 48ms/step - loss: 0.0682 - val_loss: 0.0472
# Epoch 99/100
#
# Epoch 99: loss improved from 0.06716 to 0.06698, saving model to save_models/SAB_model.keras
# 25/25 - 2s - 69ms/step - loss: 0.0670 - val_loss: 0.0480
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.06698
# 25/25 - 1s - 46ms/step - loss: 0.0672 - val_loss: 0.0503
# Restoring model weights from the end of the best epoch: 99.

# %%
save_model_path = "models/SAB_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ----')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ----
# Độ phù hợp tập train (R2): 0.9846586615315706
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 3.893195068790299
# Phần trăm sai số tuyệt đối trung bình trên tập train: 1.8963041087984485
# RMSE trên tập train (VNĐ): 5.118702189862259
# Độ chính xác trên tập train (%): 97.70975293518467
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9838419327900181
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.424549421623572
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.784483171367908
# RMSE trên tập test (VNĐ): 5.027094621203783
# Độ chính xác trên tập test (%): 95.6996624283971
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
