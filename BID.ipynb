# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['BID']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2014-02-24          8.75       16.70             833430     13892557000
# 1     2014-02-26          8.75       16.70            1399670     23420081000
# 2     2014-03-05          8.70       16.60             737090     12295954000
# 3     2014-03-10          8.75       16.70             957770     15933866000
# 4     2014-03-18          8.81       16.80            2171570     36323243000
# ...          ...           ...         ...                ...             ...
# 2716  2024-12-17         46.60       46.60            2248800    105478000000
# 2717  2024-12-13         46.40       46.40            1382900     64398000000
# 2718  2024-12-18         46.85       46.85            1661100     77806000000
# 2719  2024-12-19         46.45       46.45            2706000    126005000000
# 2720  2024-12-20         46.45       46.45            2993400    139081000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0     16.80       16.80        16.60
# 1               0            0     16.70       16.90        16.60
# 2               0            0     16.70       16.80        16.60
# 3               0            0     16.60       16.80        16.60
# 4          926290  14450124000     16.60       16.90        16.50
# ...           ...          ...       ...         ...          ...
# 2716            0            0     47.00       47.15        46.60
# 2717            0            0     46.55       46.80        46.40
# 2718            0            0     46.85       47.00        46.70
# 2719        20000    933800000     46.65       46.75        46.40
# 2720            0            0     46.50       46.70        46.35
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               0.00              0.00
# 1               0.00              0.00
# 2               0.00              0.00
# 3               0.10              0.60
# 4               0.20              1.20
# ...              ...               ...
# 2716           -0.15             -0.32
# 2717           -0.20             -0.43
# 2718            0.25              0.54
# 2719           -0.40             -0.85
# 2720            0.00              0.00
#
# [2721 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2721 entries, 0 to 2720
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               2721 non-null   object
#  1   GiaDieuChinh       2721 non-null   float64
#  2   GiaDongCua         2721 non-null   float64
#  3   KhoiLuongKhopLenh  2721 non-null   int64
#  4   GiaTriKhopLenh     2721 non-null   int64
#  5   KLThoaThuan        2721 non-null   int64
#  6   GtThoaThuan        2721 non-null   int64
#  7   GiaMoCua           2721 non-null   float64
#  8   GiaCaoNhat         2721 non-null   float64
#  9   GiaThapNhat        2721 non-null   float64
#  10  ThayDoi_GiaTri     2721 non-null   float64
#  11  ThayDoi_PhanTram   2721 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 255.2+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   2721.000000  2721.000000       2.721000e+03    2.721000e+03
# mean      24.669625    32.487119       1.866774e+06    6.140684e+10
# std       12.604303    12.015242       1.420746e+06    5.116713e+10
# min        6.990000    12.600000       5.143000e+04    6.589300e+08
# 25%       12.270000    19.300000       9.025500e+05    2.663500e+10
# 50%       24.570000    34.900000       1.531300e+06    5.016500e+10
# 75%       32.830000    42.950000       2.405890e+06    8.035000e+10
# max       54.400000    55.500000       1.570104e+07    5.718800e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  2.721000e+03  2.721000e+03  2721.000000  2721.000000  2721.000000
# mean   3.675189e+04  1.241424e+09    32.485998    32.965472    32.049577
# std    1.698928e+05  6.794541e+09    12.046853    12.198697    11.885673
# min    0.000000e+00  0.000000e+00    12.600000    12.700000    12.500000
# 25%    0.000000e+00  0.000000e+00    19.300000    19.700000    19.000000
# 50%    0.000000e+00  0.000000e+00    34.900000    35.500000    34.450000
# 75%    0.000000e+00  0.000000e+00    43.000000    43.500000    42.300000
# max    4.080700e+06  1.845315e+11    54.900000    56.700000    53.800000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     2721.000000       2721.000000
# mean         0.003447          0.036229
# std          0.720733          2.130528
# min         -4.150000         -9.650000
# 25%         -0.300000         -0.930000
# 50%          0.000000          0.000000
# 75%          0.300000          1.040000
# max          2.900000          7.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2014-01-24       18.80
# 2014-01-27       18.40
# 2014-02-06       17.60
# 2014-02-07       16.60
# 2014-02-10       17.00
# ...                ...
# 2024-12-16       46.75
# 2024-12-17       46.60
# 2024-12-18       46.85
# 2024-12-19       46.45
# 2024-12-20       46.45
#
# [2721 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[18.8 ],
#        [18.4 ],
#        [17.6 ],
#        ...,
#        [46.85],
#        [46.45],
#        [46.45]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/BID_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.28367, saving model to save_models/BID_model.keras
# 34/34 - 8s - 240ms/step - loss: 0.2837 - val_loss: 0.1528
# Epoch 2/100
#
# Epoch 2: loss improved from 0.28367 to 0.17435, saving model to save_models/BID_model.keras
# 34/34 - 3s - 87ms/step - loss: 0.1744 - val_loss: 0.1184
# Epoch 3/100
#
# Epoch 3: loss improved from 0.17435 to 0.14266, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.1427 - val_loss: 0.0954
# Epoch 4/100
#
# Epoch 4: loss improved from 0.14266 to 0.12167, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.1217 - val_loss: 0.0785
# Epoch 5/100
#
# Epoch 5: loss improved from 0.12167 to 0.10665, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.1066 - val_loss: 0.0657
# Epoch 6/100
#
# Epoch 6: loss improved from 0.10665 to 0.09780, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.0978 - val_loss: 0.0582
# Epoch 7/100
#
# Epoch 7: loss improved from 0.09780 to 0.09082, saving model to save_models/BID_model.keras
# 34/34 - 3s - 83ms/step - loss: 0.0908 - val_loss: 0.0572
# Epoch 8/100
#
# Epoch 8: loss improved from 0.09082 to 0.08152, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0815 - val_loss: 0.0462
# Epoch 9/100
#
# Epoch 9: loss improved from 0.08152 to 0.07860, saving model to save_models/BID_model.keras
# 34/34 - 3s - 87ms/step - loss: 0.0786 - val_loss: 0.0477
# Epoch 10/100
#
# Epoch 10: loss improved from 0.07860 to 0.07602, saving model to save_models/BID_model.keras
# 34/34 - 3s - 83ms/step - loss: 0.0760 - val_loss: 0.0398
# Epoch 11/100
#
# Epoch 11: loss improved from 0.07602 to 0.07090, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0709 - val_loss: 0.0375
# Epoch 12/100
#
# Epoch 12: loss improved from 0.07090 to 0.06704, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0670 - val_loss: 0.0370
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.06704
# 34/34 - 3s - 82ms/step - loss: 0.0675 - val_loss: 0.0344
# Epoch 14/100
#
# Epoch 14: loss improved from 0.06704 to 0.06395, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0639 - val_loss: 0.0338
# Epoch 15/100
#
# Epoch 15: loss improved from 0.06395 to 0.06384, saving model to save_models/BID_model.keras
# 34/34 - 3s - 86ms/step - loss: 0.0638 - val_loss: 0.0331
# Epoch 16/100
#
# Epoch 16: loss improved from 0.06384 to 0.06082, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.0608 - val_loss: 0.0317
# Epoch 17/100
#
# Epoch 17: loss improved from 0.06082 to 0.05978, saving model to save_models/BID_model.keras
# 34/34 - 3s - 83ms/step - loss: 0.0598 - val_loss: 0.0307
# Epoch 18/100
#
# Epoch 18: loss improved from 0.05978 to 0.05874, saving model to save_models/BID_model.keras
# 34/34 - 3s - 83ms/step - loss: 0.0587 - val_loss: 0.0296
# Epoch 19/100
#
# Epoch 19: loss improved from 0.05874 to 0.05774, saving model to save_models/BID_model.keras
# 34/34 - 3s - 83ms/step - loss: 0.0577 - val_loss: 0.0283
# Epoch 20/100
#
# Epoch 20: loss improved from 0.05774 to 0.05608, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0561 - val_loss: 0.0274
# Epoch 21/100
#
# Epoch 21: loss improved from 0.05608 to 0.05515, saving model to save_models/BID_model.keras
# 34/34 - 3s - 91ms/step - loss: 0.0551 - val_loss: 0.0266
# Epoch 22/100
#
# Epoch 22: loss improved from 0.05515 to 0.05403, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.0540 - val_loss: 0.0251
# Epoch 23/100
#
# Epoch 23: loss improved from 0.05403 to 0.05308, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0531 - val_loss: 0.0269
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.05308
# 34/34 - 3s - 84ms/step - loss: 0.0534 - val_loss: 0.0243
# Epoch 25/100
#
# Epoch 25: loss improved from 0.05308 to 0.05184, saving model to save_models/BID_model.keras
# 34/34 - 3s - 80ms/step - loss: 0.0518 - val_loss: 0.0236
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.05184
# 34/34 - 3s - 81ms/step - loss: 0.0523 - val_loss: 0.0226
# Epoch 27/100
#
# Epoch 27: loss improved from 0.05184 to 0.05065, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.0506 - val_loss: 0.0223
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.05065
# 34/34 - 3s - 78ms/step - loss: 0.0514 - val_loss: 0.0230
# Epoch 29/100
#
# Epoch 29: loss improved from 0.05065 to 0.05047, saving model to save_models/BID_model.keras
# 34/34 - 3s - 80ms/step - loss: 0.0505 - val_loss: 0.0230
# Epoch 30/100
#
# Epoch 30: loss improved from 0.05047 to 0.04839, saving model to save_models/BID_model.keras
# 34/34 - 3s - 81ms/step - loss: 0.0484 - val_loss: 0.0215
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.04839
# 34/34 - 3s - 80ms/step - loss: 0.0487 - val_loss: 0.0227
# Epoch 32/100
#
# Epoch 32: loss improved from 0.04839 to 0.04791, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.0479 - val_loss: 0.0221
# Epoch 33/100
#
# Epoch 33: loss improved from 0.04791 to 0.04768, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0477 - val_loss: 0.0200
# Epoch 34/100
#
# Epoch 34: loss improved from 0.04768 to 0.04678, saving model to save_models/BID_model.keras
# 34/34 - 3s - 84ms/step - loss: 0.0468 - val_loss: 0.0197
# Epoch 35/100
#
# Epoch 35: loss improved from 0.04678 to 0.04601, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0460 - val_loss: 0.0195
# Epoch 36/100
#
# Epoch 36: loss improved from 0.04601 to 0.04440, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0444 - val_loss: 0.0193
# Epoch 37/100
#
# Epoch 37: loss improved from 0.04440 to 0.04417, saving model to save_models/BID_model.keras
# 34/34 - 3s - 83ms/step - loss: 0.0442 - val_loss: 0.0188
# Epoch 38/100
#
# Epoch 38: loss improved from 0.04417 to 0.04357, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0436 - val_loss: 0.0189
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.04357
# 34/34 - 3s - 82ms/step - loss: 0.0458 - val_loss: 0.0186
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.04357
# 34/34 - 3s - 87ms/step - loss: 0.0454 - val_loss: 0.0198
# Epoch 41/100
#
# Epoch 41: loss improved from 0.04357 to 0.04335, saving model to save_models/BID_model.keras
# 34/34 - 3s - 81ms/step - loss: 0.0434 - val_loss: 0.0190
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.04335
# 34/34 - 3s - 79ms/step - loss: 0.0434 - val_loss: 0.0174
# Epoch 43/100
#
# Epoch 43: loss improved from 0.04335 to 0.04310, saving model to save_models/BID_model.keras
# 34/34 - 3s - 81ms/step - loss: 0.0431 - val_loss: 0.0182
# Epoch 44/100
#
# Epoch 44: loss improved from 0.04310 to 0.04285, saving model to save_models/BID_model.keras
# 34/34 - 4s - 108ms/step - loss: 0.0428 - val_loss: 0.0177
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.04285
# 34/34 - 3s - 79ms/step - loss: 0.0432 - val_loss: 0.0193
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.04285
# 34/34 - 3s - 75ms/step - loss: 0.0436 - val_loss: 0.0180
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.04285
# 34/34 - 3s - 77ms/step - loss: 0.0429 - val_loss: 0.0194
# Epoch 48/100
#
# Epoch 48: loss improved from 0.04285 to 0.04268, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0427 - val_loss: 0.0179
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.04268
# 34/34 - 3s - 80ms/step - loss: 0.0438 - val_loss: 0.0165
# Epoch 50/100
#
# Epoch 50: loss improved from 0.04268 to 0.04181, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0418 - val_loss: 0.0172
# Epoch 51/100
#
# Epoch 51: loss improved from 0.04181 to 0.03964, saving model to save_models/BID_model.keras
# 34/34 - 3s - 81ms/step - loss: 0.0396 - val_loss: 0.0165
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.03964
# 34/34 - 3s - 79ms/step - loss: 0.0403 - val_loss: 0.0170
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.03964
# 34/34 - 3s - 80ms/step - loss: 0.0408 - val_loss: 0.0162
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.03964
# 34/34 - 3s - 83ms/step - loss: 0.0400 - val_loss: 0.0164
# Epoch 55/100
#
# Epoch 55: loss improved from 0.03964 to 0.03936, saving model to save_models/BID_model.keras
# 34/34 - 3s - 85ms/step - loss: 0.0394 - val_loss: 0.0157
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.03936
# 34/34 - 3s - 84ms/step - loss: 0.0404 - val_loss: 0.0157
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.03936
# 34/34 - 3s - 81ms/step - loss: 0.0403 - val_loss: 0.0161
# Epoch 58/100
#
# Epoch 58: loss improved from 0.03936 to 0.03932, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0393 - val_loss: 0.0170
# Epoch 59/100
#
# Epoch 59: loss improved from 0.03932 to 0.03903, saving model to save_models/BID_model.keras
# 34/34 - 3s - 86ms/step - loss: 0.0390 - val_loss: 0.0170
# Epoch 60/100
#
# Epoch 60: loss improved from 0.03903 to 0.03831, saving model to save_models/BID_model.keras
# 34/34 - 5s - 154ms/step - loss: 0.0383 - val_loss: 0.0151
# Epoch 61/100
#
# Epoch 61: loss improved from 0.03831 to 0.03801, saving model to save_models/BID_model.keras
# 34/34 - 3s - 80ms/step - loss: 0.0380 - val_loss: 0.0155
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.03801
# 34/34 - 3s - 79ms/step - loss: 0.0395 - val_loss: 0.0171
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.03801
# 34/34 - 3s - 75ms/step - loss: 0.0388 - val_loss: 0.0147
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.03801
# 34/34 - 3s - 77ms/step - loss: 0.0384 - val_loss: 0.0147
# Epoch 65/100
#
# Epoch 65: loss improved from 0.03801 to 0.03771, saving model to save_models/BID_model.keras
# 34/34 - 3s - 80ms/step - loss: 0.0377 - val_loss: 0.0163
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.03771
# 34/34 - 3s - 82ms/step - loss: 0.0383 - val_loss: 0.0164
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.03771
# 34/34 - 3s - 83ms/step - loss: 0.0383 - val_loss: 0.0145
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.03771
# 34/34 - 3s - 78ms/step - loss: 0.0385 - val_loss: 0.0152
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.03771
# 34/34 - 3s - 79ms/step - loss: 0.0383 - val_loss: 0.0143
# Epoch 70/100
#
# Epoch 70: loss improved from 0.03771 to 0.03714, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0371 - val_loss: 0.0144
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.03714
# 34/34 - 3s - 80ms/step - loss: 0.0379 - val_loss: 0.0166
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.03714
# 34/34 - 3s - 79ms/step - loss: 0.0380 - val_loss: 0.0149
# Epoch 73/100
#
# Epoch 73: loss improved from 0.03714 to 0.03677, saving model to save_models/BID_model.keras
# 34/34 - 3s - 80ms/step - loss: 0.0368 - val_loss: 0.0147
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.03677
# 34/34 - 3s - 79ms/step - loss: 0.0371 - val_loss: 0.0145
# Epoch 75/100
#
# Epoch 75: loss improved from 0.03677 to 0.03676, saving model to save_models/BID_model.keras
# 34/34 - 3s - 80ms/step - loss: 0.0368 - val_loss: 0.0138
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.03676
# 34/34 - 3s - 80ms/step - loss: 0.0384 - val_loss: 0.0170
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.03676
# 34/34 - 3s - 80ms/step - loss: 0.0374 - val_loss: 0.0151
# Epoch 78/100
#
# Epoch 78: loss improved from 0.03676 to 0.03671, saving model to save_models/BID_model.keras
# 34/34 - 3s - 81ms/step - loss: 0.0367 - val_loss: 0.0161
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.03671
# 34/34 - 3s - 83ms/step - loss: 0.0379 - val_loss: 0.0141
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.03671
# 34/34 - 3s - 83ms/step - loss: 0.0380 - val_loss: 0.0167
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.03671
# 34/34 - 3s - 78ms/step - loss: 0.0378 - val_loss: 0.0149
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.03671
# 34/34 - 3s - 77ms/step - loss: 0.0377 - val_loss: 0.0158
# Epoch 83/100
#
# Epoch 83: loss improved from 0.03671 to 0.03622, saving model to save_models/BID_model.keras
# 34/34 - 3s - 82ms/step - loss: 0.0362 - val_loss: 0.0161
# Epoch 84/100
#
# Epoch 84: loss improved from 0.03622 to 0.03609, saving model to save_models/BID_model.keras
# 34/34 - 3s - 81ms/step - loss: 0.0361 - val_loss: 0.0152
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.03609
# 34/34 - 3s - 81ms/step - loss: 0.0377 - val_loss: 0.0144
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.03609
# 34/34 - 3s - 81ms/step - loss: 0.0391 - val_loss: 0.0141
# Epoch 87/100
#
# Epoch 87: loss improved from 0.03609 to 0.03602, saving model to save_models/BID_model.keras
# 34/34 - 3s - 81ms/step - loss: 0.0360 - val_loss: 0.0150
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.03602
# 34/34 - 3s - 83ms/step - loss: 0.0366 - val_loss: 0.0134
# Epoch 89/100
#
# Epoch 89: loss improved from 0.03602 to 0.03487, saving model to save_models/BID_model.keras
# 34/34 - 3s - 79ms/step - loss: 0.0349 - val_loss: 0.0173
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.03487
# 34/34 - 3s - 88ms/step - loss: 0.0356 - val_loss: 0.0161
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.03487
# 34/34 - 3s - 86ms/step - loss: 0.0362 - val_loss: 0.0152
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.03487
# 34/34 - 3s - 82ms/step - loss: 0.0362 - val_loss: 0.0160
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.03487
# 34/34 - 3s - 85ms/step - loss: 0.0368 - val_loss: 0.0198
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.03487
# 34/34 - 3s - 86ms/step - loss: 0.0362 - val_loss: 0.0134
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.03487
# 34/34 - 3s - 84ms/step - loss: 0.0355 - val_loss: 0.0191
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.03487
# 34/34 - 3s - 79ms/step - loss: 0.0351 - val_loss: 0.0163
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.03487
# 34/34 - 3s - 80ms/step - loss: 0.0356 - val_loss: 0.0191
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.03487
# 34/34 - 3s - 82ms/step - loss: 0.0361 - val_loss: 0.0145
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.03487
# 34/34 - 3s - 82ms/step - loss: 0.0362 - val_loss: 0.0131
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.03487
# 34/34 - 3s - 81ms/step - loss: 0.0360 - val_loss: 0.0143
# Restoring model weights from the end of the best epoch: 89.

# %%
# save_model_path = "save_models/BID_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)

# Loại bỏ chiều thừa trước khi áp dụng inverse_transform
y_train_predict = y_train_predict.reshape(-1, 1)
y_train_predict = sc.inverse_transform(y_train_predict)

# Áp dụng inverse_transform cho y_train để so sánh
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(24, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9890948674295008
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 0.8344349801035726
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.9520125101525645
# RMSE trên tập train (VNĐ): 1.158375035043592
# Độ chính xác trên tập train (%): 97.29982509313848
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9048335263792958
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.0056449610158937
# Phần trăm sai số tuyệt đối trung bình trên tập test: 2.2071019693313776
# RMSE trên tập test (VNĐ): 1.2786645097627105
# Độ chính xác trên tập test (%): 94.6833076517143
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
