# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['MSN']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2009-11-09         22.19        43.1             379190     16685898000
# 1     2009-11-12         19.56        38.0             282170     10824764000
# 2     2009-11-13         20.07        39.0             664120     24610896000
# 3     2009-11-16         20.95        40.7             231890      9219190000
# 4     2009-12-01         18.22        35.4             118540      4194741000
# ...          ...           ...         ...                ...             ...
# 3771  2024-12-17         71.00        71.0            1652300    117476000000
# 3772  2024-12-13         71.10        71.1            3536600    252688000000
# 3773  2024-12-18         71.40        71.4            2486900    177060000000
# 3774  2024-12-19         70.40        70.4            3513100    248415000000
# 3775  2024-12-20         70.30        70.3            2753800    193621000000
#
#       KLThoaThuan   GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0             0      44.0        45.2         43.1
# 1               0             0      38.4        39.7         38.0
# 2               0             0      36.1        39.0         36.1
# 3               0             0      39.0        40.7         38.5
# 4               0             0      34.9        35.9         34.0
# ...           ...           ...       ...         ...          ...
# 3771       998000   70729000000      71.0        71.3         71.0
# 3772       486000   34554600000      72.0        72.0         71.0
# 3773      5657000  402212700000      71.1        71.4         71.0
# 3774      1700100  119972040000      71.0        71.2         70.3
# 3775            0             0      70.5        70.6         70.0
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               -2.2             -4.86
# 1                0.0              0.00
# 2                0.0              0.00
# 3                1.7              4.36
# 4                0.5              1.43
# ...              ...               ...
# 3771            -0.1             -0.14
# 3772             0.0              0.00
# 3773             0.4              0.56
# 3774             0.0              0.00
# 3775            -0.1             -0.14
#
# [3776 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3776 entries, 0 to 3775
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               3776 non-null   object
#  1   GiaDieuChinh       3776 non-null   float64
#  2   GiaDongCua         3776 non-null   float64
#  3   KhoiLuongKhopLenh  3776 non-null   int64
#  4   GiaTriKhopLenh     3776 non-null   int64
#  5   KLThoaThuan        3776 non-null   int64
#  6   GtThoaThuan        3776 non-null   int64
#  7   GiaMoCua           3776 non-null   float64
#  8   GiaCaoNhat         3776 non-null   float64
#  9   GiaThapNhat        3776 non-null   float64
#  10  ThayDoi_GiaTri     3776 non-null   float64
#  11  ThayDoi_PhanTram   3776 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 354.1+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   3776.000000  3776.000000       3.776000e+03    3.776000e+03
# mean      58.582858    83.028151       9.311914e+05    7.694072e+10
# std       24.451095    24.731707       1.478423e+06    1.282948e+11
# min       16.780000    32.600000       2.300000e+02    1.758000e+07
# 25%       41.440000    68.500000       1.059950e+05    8.323888e+09
# 50%       51.710000    81.500000       3.986950e+05    2.960000e+10
# 75%       72.477500    95.425000       1.083975e+06    9.186775e+10
# max      142.280000   172.000000       1.987080e+07    1.709567e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  3.776000e+03  3.776000e+03  3776.000000  3776.000000  3776.000000
# mean   5.688051e+05  4.500803e+10    83.047630    84.219690    81.844439
# std    3.254469e+06  2.758604e+11    24.795626    25.229562    24.359018
# min    0.000000e+00  0.000000e+00    32.500000    34.000000    32.500000
# 25%    0.000000e+00  0.000000e+00    68.500000    69.300000    67.500000
# 50%    0.000000e+00  0.000000e+00    81.500000    82.500000    80.500000
# 75%    2.080375e+05  1.690537e+10    95.500000    97.000000    94.000000
# max    1.098999e+08  1.098999e+13   172.000000   175.000000   169.500000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     3776.000000       3776.000000
# mean         0.048769          0.071830
# std          1.449977          1.732814
# min         -8.100000         -7.000000
# 25%         -0.300000         -0.482500
# 50%          0.000000          0.000000
# 75%          0.400000          0.502500
# max          9.400000         20.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2009-11-05        43.2
# 2009-11-06        45.3
# 2009-11-09        43.1
# 2009-11-10        41.0
# 2009-11-11        40.0
# ...                ...
# 2024-12-16        71.1
# 2024-12-17        71.0
# 2024-12-18        71.4
# 2024-12-19        70.4
# 2024-12-20        70.3
#
# [3776 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[43.2],
#        [45.3],
#        [43.1],
#        ...,
#        [71.4],
#        [70.4],
#        [70.3]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/MSN_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.24382, saving model to save_models/MSN_model.keras
# 47/47 - 14s - 288ms/step - loss: 0.2438 - val_loss: 0.1491
# Epoch 2/100
#
# Epoch 2: loss improved from 0.24382 to 0.14621, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 115ms/step - loss: 0.1462 - val_loss: 0.1124
# Epoch 3/100
#
# Epoch 3: loss improved from 0.14621 to 0.11500, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 97ms/step - loss: 0.1150 - val_loss: 0.0869
# Epoch 4/100
#
# Epoch 4: loss improved from 0.11500 to 0.09346, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 102ms/step - loss: 0.0935 - val_loss: 0.0749
# Epoch 5/100
#
# Epoch 5: loss improved from 0.09346 to 0.08071, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 112ms/step - loss: 0.0807 - val_loss: 0.0619
# Epoch 6/100
#
# Epoch 6: loss improved from 0.08071 to 0.07358, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 116ms/step - loss: 0.0736 - val_loss: 0.0556
# Epoch 7/100
#
# Epoch 7: loss improved from 0.07358 to 0.06723, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 114ms/step - loss: 0.0672 - val_loss: 0.0629
# Epoch 8/100
#
# Epoch 8: loss improved from 0.06723 to 0.06291, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 112ms/step - loss: 0.0629 - val_loss: 0.0491
# Epoch 9/100
#
# Epoch 9: loss improved from 0.06291 to 0.05930, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 117ms/step - loss: 0.0593 - val_loss: 0.0473
# Epoch 10/100
#
# Epoch 10: loss improved from 0.05930 to 0.05750, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 117ms/step - loss: 0.0575 - val_loss: 0.0467
# Epoch 11/100
#
# Epoch 11: loss improved from 0.05750 to 0.05434, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 101ms/step - loss: 0.0543 - val_loss: 0.0415
# Epoch 12/100
#
# Epoch 12: loss improved from 0.05434 to 0.05192, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 96ms/step - loss: 0.0519 - val_loss: 0.0399
# Epoch 13/100
#
# Epoch 13: loss improved from 0.05192 to 0.05080, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 98ms/step - loss: 0.0508 - val_loss: 0.0384
# Epoch 14/100
#
# Epoch 14: loss improved from 0.05080 to 0.04726, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 99ms/step - loss: 0.0473 - val_loss: 0.0390
# Epoch 15/100
#
# Epoch 15: loss improved from 0.04726 to 0.04713, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 100ms/step - loss: 0.0471 - val_loss: 0.0354
# Epoch 16/100
#
# Epoch 16: loss improved from 0.04713 to 0.04584, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 99ms/step - loss: 0.0458 - val_loss: 0.0343
# Epoch 17/100
#
# Epoch 17: loss improved from 0.04584 to 0.04368, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 96ms/step - loss: 0.0437 - val_loss: 0.0348
# Epoch 18/100
#
# Epoch 18: loss improved from 0.04368 to 0.04225, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 97ms/step - loss: 0.0423 - val_loss: 0.0352
# Epoch 19/100
#
# Epoch 19: loss improved from 0.04225 to 0.04177, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 100ms/step - loss: 0.0418 - val_loss: 0.0313
# Epoch 20/100
#
# Epoch 20: loss improved from 0.04177 to 0.04041, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 98ms/step - loss: 0.0404 - val_loss: 0.0309
# Epoch 21/100
#
# Epoch 21: loss improved from 0.04041 to 0.04008, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 97ms/step - loss: 0.0401 - val_loss: 0.0306
# Epoch 22/100
#
# Epoch 22: loss improved from 0.04008 to 0.03851, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 95ms/step - loss: 0.0385 - val_loss: 0.0299
# Epoch 23/100
#
# Epoch 23: loss improved from 0.03851 to 0.03731, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 97ms/step - loss: 0.0373 - val_loss: 0.0290
# Epoch 24/100
#
# Epoch 24: loss improved from 0.03731 to 0.03640, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 98ms/step - loss: 0.0364 - val_loss: 0.0285
# Epoch 25/100
#
# Epoch 25: loss improved from 0.03640 to 0.03603, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 94ms/step - loss: 0.0360 - val_loss: 0.0367
# Epoch 26/100
#
# Epoch 26: loss improved from 0.03603 to 0.03552, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 89ms/step - loss: 0.0355 - val_loss: 0.0303
# Epoch 27/100
#
# Epoch 27: loss improved from 0.03552 to 0.03503, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 94ms/step - loss: 0.0350 - val_loss: 0.0282
# Epoch 28/100
#
# Epoch 28: loss improved from 0.03503 to 0.03419, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 96ms/step - loss: 0.0342 - val_loss: 0.0276
# Epoch 29/100
#
# Epoch 29: loss improved from 0.03419 to 0.03288, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 92ms/step - loss: 0.0329 - val_loss: 0.0270
# Epoch 30/100
#
# Epoch 30: loss improved from 0.03288 to 0.03159, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 110ms/step - loss: 0.0316 - val_loss: 0.0266
# Epoch 31/100
#
# Epoch 31: loss improved from 0.03159 to 0.03112, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 92ms/step - loss: 0.0311 - val_loss: 0.0259
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.03112
# 47/47 - 4s - 84ms/step - loss: 0.0322 - val_loss: 0.0273
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.03112
# 47/47 - 4s - 94ms/step - loss: 0.0316 - val_loss: 0.0254
# Epoch 34/100
#
# Epoch 34: loss improved from 0.03112 to 0.03089, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 104ms/step - loss: 0.0309 - val_loss: 0.0255
# Epoch 35/100
#
# Epoch 35: loss improved from 0.03089 to 0.03028, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 102ms/step - loss: 0.0303 - val_loss: 0.0249
# Epoch 36/100
#
# Epoch 36: loss improved from 0.03028 to 0.02980, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 104ms/step - loss: 0.0298 - val_loss: 0.0267
# Epoch 37/100
#
# Epoch 37: loss improved from 0.02980 to 0.02922, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 85ms/step - loss: 0.0292 - val_loss: 0.0278
# Epoch 38/100
#
# Epoch 38: loss improved from 0.02922 to 0.02866, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 79ms/step - loss: 0.0287 - val_loss: 0.0246
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.02866
# 47/47 - 4s - 80ms/step - loss: 0.0289 - val_loss: 0.0258
# Epoch 40/100
#
# Epoch 40: loss improved from 0.02866 to 0.02864, saving model to save_models/MSN_model.keras
# 47/47 - 4s - 85ms/step - loss: 0.0286 - val_loss: 0.0302
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.02864
# 47/47 - 4s - 84ms/step - loss: 0.0290 - val_loss: 0.0241
# Epoch 42/100
#
# Epoch 42: loss improved from 0.02864 to 0.02824, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 118ms/step - loss: 0.0282 - val_loss: 0.0256
# Epoch 43/100
#
# Epoch 43: loss improved from 0.02824 to 0.02796, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 98ms/step - loss: 0.0280 - val_loss: 0.0240
# Epoch 44/100
#
# Epoch 44: loss improved from 0.02796 to 0.02738, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 119ms/step - loss: 0.0274 - val_loss: 0.0247
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.02738
# 47/47 - 5s - 108ms/step - loss: 0.0276 - val_loss: 0.0233
# Epoch 46/100
#
# Epoch 46: loss improved from 0.02738 to 0.02727, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 125ms/step - loss: 0.0273 - val_loss: 0.0235
# Epoch 47/100
#
# Epoch 47: loss improved from 0.02727 to 0.02683, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 108ms/step - loss: 0.0268 - val_loss: 0.0253
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.02683
# 47/47 - 5s - 105ms/step - loss: 0.0278 - val_loss: 0.0253
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.02683
# 47/47 - 5s - 98ms/step - loss: 0.0275 - val_loss: 0.0258
# Epoch 50/100
#
# Epoch 50: loss improved from 0.02683 to 0.02671, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 103ms/step - loss: 0.0267 - val_loss: 0.0226
# Epoch 51/100
#
# Epoch 51: loss improved from 0.02671 to 0.02587, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 103ms/step - loss: 0.0259 - val_loss: 0.0249
# Epoch 52/100
#
# Epoch 52: loss improved from 0.02587 to 0.02581, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 97ms/step - loss: 0.0258 - val_loss: 0.0224
# Epoch 53/100
#
# Epoch 53: loss improved from 0.02581 to 0.02568, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 98ms/step - loss: 0.0257 - val_loss: 0.0225
# Epoch 54/100
#
# Epoch 54: loss improved from 0.02568 to 0.02548, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 110ms/step - loss: 0.0255 - val_loss: 0.0228
# Epoch 55/100
#
# Epoch 55: loss improved from 0.02548 to 0.02539, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 124ms/step - loss: 0.0254 - val_loss: 0.0223
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.02539
# 47/47 - 5s - 109ms/step - loss: 0.0261 - val_loss: 0.0234
# Epoch 57/100
#
# Epoch 57: loss improved from 0.02539 to 0.02536, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 111ms/step - loss: 0.0254 - val_loss: 0.0226
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.02536
# 47/47 - 11s - 224ms/step - loss: 0.0260 - val_loss: 0.0238
# Epoch 59/100
#
# Epoch 59: loss improved from 0.02536 to 0.02533, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 97ms/step - loss: 0.0253 - val_loss: 0.0218
# Epoch 60/100
#
# Epoch 60: loss improved from 0.02533 to 0.02495, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 101ms/step - loss: 0.0249 - val_loss: 0.0221
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.02495
# 47/47 - 5s - 103ms/step - loss: 0.0250 - val_loss: 0.0247
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.02495
# 47/47 - 5s - 103ms/step - loss: 0.0252 - val_loss: 0.0225
# Epoch 63/100
#
# Epoch 63: loss improved from 0.02495 to 0.02468, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 109ms/step - loss: 0.0247 - val_loss: 0.0217
# Epoch 64/100
#
# Epoch 64: loss improved from 0.02468 to 0.02438, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 104ms/step - loss: 0.0244 - val_loss: 0.0216
# Epoch 65/100
#
# Epoch 65: loss improved from 0.02438 to 0.02436, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 115ms/step - loss: 0.0244 - val_loss: 0.0243
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.02436
# 47/47 - 5s - 115ms/step - loss: 0.0252 - val_loss: 0.0223
# Epoch 67/100
#
# Epoch 67: loss improved from 0.02436 to 0.02432, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 110ms/step - loss: 0.0243 - val_loss: 0.0222
# Epoch 68/100
#
# Epoch 68: loss improved from 0.02432 to 0.02402, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 110ms/step - loss: 0.0240 - val_loss: 0.0213
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.02402
# 47/47 - 5s - 108ms/step - loss: 0.0249 - val_loss: 0.0224
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.02402
# 47/47 - 6s - 121ms/step - loss: 0.0245 - val_loss: 0.0213
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02402
# 47/47 - 6s - 122ms/step - loss: 0.0242 - val_loss: 0.0218
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.02402
# 47/47 - 6s - 120ms/step - loss: 0.0245 - val_loss: 0.0209
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.02402
# 47/47 - 6s - 126ms/step - loss: 0.0244 - val_loss: 0.0210
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.02402
# 47/47 - 6s - 120ms/step - loss: 0.0243 - val_loss: 0.0221
# Epoch 75/100
#
# Epoch 75: loss improved from 0.02402 to 0.02379, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 124ms/step - loss: 0.0238 - val_loss: 0.0215
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02379
# 47/47 - 5s - 111ms/step - loss: 0.0240 - val_loss: 0.0208
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.02379
# 47/47 - 6s - 126ms/step - loss: 0.0245 - val_loss: 0.0230
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.02379
# 47/47 - 6s - 120ms/step - loss: 0.0242 - val_loss: 0.0229
# Epoch 79/100
#
# Epoch 79: loss improved from 0.02379 to 0.02374, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 123ms/step - loss: 0.0237 - val_loss: 0.0206
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.02374
# 47/47 - 6s - 124ms/step - loss: 0.0238 - val_loss: 0.0212
# Epoch 81/100
#
# Epoch 81: loss improved from 0.02374 to 0.02332, saving model to save_models/MSN_model.keras
# 47/47 - 10s - 220ms/step - loss: 0.0233 - val_loss: 0.0251
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.02332
# 47/47 - 10s - 213ms/step - loss: 0.0239 - val_loss: 0.0225
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.02332
# 47/47 - 6s - 124ms/step - loss: 0.0243 - val_loss: 0.0199
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.02332
# 47/47 - 6s - 122ms/step - loss: 0.0238 - val_loss: 0.0213
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.02332
# 47/47 - 6s - 121ms/step - loss: 0.0238 - val_loss: 0.0203
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.02332
# 47/47 - 6s - 128ms/step - loss: 0.0234 - val_loss: 0.0198
# Epoch 87/100
#
# Epoch 87: loss improved from 0.02332 to 0.02302, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 125ms/step - loss: 0.0230 - val_loss: 0.0217
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.02302
# 47/47 - 6s - 120ms/step - loss: 0.0237 - val_loss: 0.0195
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.02302
# 47/47 - 6s - 134ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.02302
# 47/47 - 6s - 119ms/step - loss: 0.0231 - val_loss: 0.0196
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.02302
# 47/47 - 6s - 125ms/step - loss: 0.0232 - val_loss: 0.0194
# Epoch 92/100
#
# Epoch 92: loss improved from 0.02302 to 0.02300, saving model to save_models/MSN_model.keras
# 47/47 - 10s - 218ms/step - loss: 0.0230 - val_loss: 0.0207
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.02300
# 47/47 - 6s - 122ms/step - loss: 0.0232 - val_loss: 0.0209
# Epoch 94/100
#
# Epoch 94: loss improved from 0.02300 to 0.02268, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 132ms/step - loss: 0.0227 - val_loss: 0.0196
# Epoch 95/100
#
# Epoch 95: loss improved from 0.02268 to 0.02264, saving model to save_models/MSN_model.keras
# 47/47 - 6s - 124ms/step - loss: 0.0226 - val_loss: 0.0206
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.02264
# 47/47 - 6s - 129ms/step - loss: 0.0241 - val_loss: 0.0206
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.02264
# 47/47 - 5s - 112ms/step - loss: 0.0228 - val_loss: 0.0205
# Epoch 98/100
#
# Epoch 98: loss improved from 0.02264 to 0.02263, saving model to save_models/MSN_model.keras
# 47/47 - 5s - 99ms/step - loss: 0.0226 - val_loss: 0.0194
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.02263
# 47/47 - 4s - 95ms/step - loss: 0.0227 - val_loss: 0.0191
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.02263
# 47/47 - 4s - 96ms/step - loss: 0.0235 - val_loss: 0.0190
# Restoring model weights from the end of the best epoch: 98.

# %%
# Hàm xây dựng mô hình
def build_model():
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(units=64))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# Huấn luyện mô hình
model = build_model()
save_model_path = f"save_models/{collection}_model.keras"
best_model = ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.01953, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 9s - 127ms/step - loss: 0.0195
# Epoch 2/100
#
# Epoch 2: loss improved from 0.01953 to 0.01390, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 67ms/step - loss: 0.0139
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01390 to 0.01147, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 69ms/step - loss: 0.0115
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.01147
# 72/72 - 5s - 64ms/step - loss: 0.0124
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01147 to 0.01087, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0109
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01087 to 0.01084, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 64ms/step - loss: 0.0108
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.01084
# 72/72 - 5s - 66ms/step - loss: 0.0114
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.01084
# 72/72 - 5s - 68ms/step - loss: 0.0109
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01084 to 0.01023, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0102
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01023 to 0.00967, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 68ms/step - loss: 0.0097
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00967
# 72/72 - 5s - 66ms/step - loss: 0.0104
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00967
# 72/72 - 5s - 69ms/step - loss: 0.0098
# Epoch 13/100
#
# Epoch 13: loss improved from 0.00967 to 0.00954, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 65ms/step - loss: 0.0095
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00954
# 72/72 - 4s - 62ms/step - loss: 0.0099
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.00954
# 72/72 - 5s - 64ms/step - loss: 0.0098
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.00954
# 72/72 - 5s - 63ms/step - loss: 0.0100
# Epoch 17/100
#
# Epoch 17: loss improved from 0.00954 to 0.00887, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00887
# 72/72 - 4s - 57ms/step - loss: 0.0096
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0095
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0102
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00887
# 72/72 - 4s - 58ms/step - loss: 0.0138
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00887
# 72/72 - 4s - 59ms/step - loss: 0.0094
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00887
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0089
# Epoch 28/100
#
# Epoch 28: loss improved from 0.00887 to 0.00879, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00879 to 0.00859, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00859
# 72/72 - 5s - 75ms/step - loss: 0.0094
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00859
# 72/72 - 4s - 58ms/step - loss: 0.0090
# Epoch 32/100
#
# Epoch 32: loss improved from 0.00859 to 0.00851, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0114
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0091
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0091
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00851
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00851
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0089
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 41/100
#
# Epoch 41: loss improved from 0.00851 to 0.00840, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00840 to 0.00836, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00836
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00836
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 45/100
#
# Epoch 45: loss improved from 0.00836 to 0.00829, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0083
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00829
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00829 to 0.00812, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0086
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0082
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00812
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0093
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00812
# 72/72 - 5s - 63ms/step - loss: 0.0083
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00812 to 0.00806, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00806
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00806 to 0.00791, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0084
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0079
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0108
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0091
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0081
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0085
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00791
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0086
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0081
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00791 to 0.00789, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0079
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0112
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0094
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00789
# 72/72 - 4s - 59ms/step - loss: 0.0095
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00789
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00789
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0080
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 89/100
#
# Epoch 89: loss improved from 0.00789 to 0.00785, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0079
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00785 to 0.00780, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0078
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0080
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0083
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00780
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00780
# 72/72 - 5s - 63ms/step - loss: 0.0084
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00780 to 0.00772, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0077

# %%
save_model_path = "save_models/MSN_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.986514016427958
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 1.8080099941985774
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.1703048215634966
# RMSE trên tập train (VNĐ): 2.7262925257462967
# Độ chính xác trên tập train (%): 97.78530257859764
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9848778722924928
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 2.1366450092779896
# Phần trăm sai số tuyệt đối trung bình trên tập test: 2.310953258615344
# RMSE trên tập test (VNĐ): 3.228229076963713
# Độ chính xác trên tập test (%): 97.17317944223844
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
