# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['BVH']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2009-06-30         35.02        53.0             274410     14543730000
# 1     2009-07-08         30.66        46.4             212950      9844633000
# 2     2009-07-15         26.10        39.5             389850     15543602000
# 3     2009-07-29         26.43        40.0             254170     10241950000
# 4     2009-08-07         27.09        41.0             347350     14137870000
# ...          ...           ...         ...                ...             ...
# 3865  2024-12-17         52.10        52.1             538600     28200000000
# 3866  2024-12-13         53.20        53.2            1403200     75455000000
# 3867  2024-12-18         52.20        52.2             495600     25821000000
# 3868  2024-12-19         52.40        52.4             892800     46952000000
# 3869  2024-12-20         51.20        51.2            1322900     68343000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0      53.0        53.0         53.0
# 1               0            0      46.0        47.5         45.6
# 2           30000   1185000000      39.9        41.0         39.0
# 3               0            0      40.5        40.8         40.0
# 4           78000   3219300000      42.0        42.0         40.0
# ...           ...          ...       ...         ...          ...
# 3865            0            0      52.2        53.0         52.1
# 3866            0            0      52.7        54.8         52.2
# 3867            0            0      51.9        53.0         51.7
# 3868            0            0      52.0        53.3         51.6
# 3869            0            0      52.0        52.8         51.1
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0                2.5              4.95
# 1               -1.1             -2.32
# 2               -0.4             -1.00
# 3               -0.5             -1.23
# 4                0.0              0.00
# ...              ...               ...
# 3865            -0.2             -0.38
# 3866             0.3              0.57
# 3867             0.1              0.19
# 3868             0.2              0.38
# 3869            -1.2             -2.29
#
# [3870 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3870 entries, 0 to 3869
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               3870 non-null   object
#  1   GiaDieuChinh       3870 non-null   float64
#  2   GiaDongCua         3870 non-null   float64
#  3   KhoiLuongKhopLenh  3870 non-null   int64
#  4   GiaTriKhopLenh     3870 non-null   int64
#  5   KLThoaThuan        3870 non-null   int64
#  6   GtThoaThuan        3870 non-null   int64
#  7   GiaMoCua           3870 non-null   float64
#  8   GiaCaoNhat         3870 non-null   float64
#  9   GiaThapNhat        3870 non-null   float64
#  10  ThayDoi_GiaTri     3870 non-null   float64
#  11  ThayDoi_PhanTram   3870 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 362.9+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   3870.000000  3870.000000       3.870000e+03    3.870000e+03
# mean      45.609070    55.119238       4.702622e+05    2.493322e+10
# std       14.166483    16.127113       4.999762e+05    2.822637e+10
# min       15.060000    22.800000       1.060000e+03    4.773300e+07
# 25%       35.432500    43.400000       1.503700e+05    8.088938e+09
# 50%       44.805000    52.050000       2.973850e+05    1.468300e+10
# 75%       51.707500    61.900000       6.095675e+05    3.101475e+10
# max       91.350000   107.900000       4.575300e+06    2.845160e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  3.870000e+03  3.870000e+03  3870.000000  3870.000000  3870.000000
# mean   1.652512e+04  9.363525e+08    55.123075    55.981305    54.352920
# std    1.366716e+05  7.705234e+09    16.086445    16.391662    15.831068
# min    0.000000e+00  0.000000e+00    22.500000    23.200000    22.500000
# 25%    0.000000e+00  0.000000e+00    43.350000    43.950000    42.912500
# 50%    0.000000e+00  0.000000e+00    52.200000    53.300000    51.450000
# 75%    0.000000e+00  0.000000e+00    61.900000    63.000000    61.000000
# max    4.413470e+06  2.136725e+11   109.400000   111.000000   107.000000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     3870.000000       3870.000000
# mean         0.022351          0.061543
# std          1.240881          2.201482
# min         -6.700000         -7.000000
# 25%         -0.500000         -0.840000
# 50%          0.000000          0.000000
# 75%          0.500000          0.880000
# max          7.700000         20.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2009-06-25        46.2
# 2009-06-26        48.5
# 2009-06-29        50.5
# 2009-06-30        53.0
# 2009-07-01        50.5
# ...                ...
# 2024-12-16        52.3
# 2024-12-17        52.1
# 2024-12-18        52.2
# 2024-12-19        52.4
# 2024-12-20        51.2
#
# [3870 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[46.2],
#        [48.5],
#        [50.5],
#        ...,
#        [52.2],
#        [52.4],
#        [51.2]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/BVH_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.24405, saving model to save_models/BVH_model.keras
# 48/48 - 9s - 191ms/step - loss: 0.2440 - val_loss: 0.1608
# Epoch 2/100
#
# Epoch 2: loss improved from 0.24405 to 0.15488, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 83ms/step - loss: 0.1549 - val_loss: 0.1265
# Epoch 3/100
#
# Epoch 3: loss improved from 0.15488 to 0.12391, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 83ms/step - loss: 0.1239 - val_loss: 0.0978
# Epoch 4/100
#
# Epoch 4: loss improved from 0.12391 to 0.10351, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.1035 - val_loss: 0.0814
# Epoch 5/100
#
# Epoch 5: loss improved from 0.10351 to 0.08910, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0891 - val_loss: 0.0713
# Epoch 6/100
#
# Epoch 6: loss improved from 0.08910 to 0.08272, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 80ms/step - loss: 0.0827 - val_loss: 0.0642
# Epoch 7/100
#
# Epoch 7: loss improved from 0.08272 to 0.07609, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 83ms/step - loss: 0.0761 - val_loss: 0.0595
# Epoch 8/100
#
# Epoch 8: loss improved from 0.07609 to 0.07095, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 79ms/step - loss: 0.0709 - val_loss: 0.0569
# Epoch 9/100
#
# Epoch 9: loss improved from 0.07095 to 0.06782, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0678 - val_loss: 0.0535
# Epoch 10/100
#
# Epoch 10: loss improved from 0.06782 to 0.06594, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 86ms/step - loss: 0.0659 - val_loss: 0.0506
# Epoch 11/100
#
# Epoch 11: loss improved from 0.06594 to 0.06541, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0654 - val_loss: 0.0486
# Epoch 12/100
#
# Epoch 12: loss improved from 0.06541 to 0.06195, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 83ms/step - loss: 0.0619 - val_loss: 0.0470
# Epoch 13/100
#
# Epoch 13: loss improved from 0.06195 to 0.06010, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0601 - val_loss: 0.0458
# Epoch 14/100
#
# Epoch 14: loss improved from 0.06010 to 0.05622, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 79ms/step - loss: 0.0562 - val_loss: 0.0450
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.05622
# 48/48 - 4s - 81ms/step - loss: 0.0570 - val_loss: 0.0431
# Epoch 16/100
#
# Epoch 16: loss improved from 0.05622 to 0.05341, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0534 - val_loss: 0.0414
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.05341
# 48/48 - 4s - 80ms/step - loss: 0.0541 - val_loss: 0.0426
# Epoch 18/100
#
# Epoch 18: loss improved from 0.05341 to 0.05120, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0512 - val_loss: 0.0430
# Epoch 19/100
#
# Epoch 19: loss improved from 0.05120 to 0.04883, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0488 - val_loss: 0.0418
# Epoch 20/100
#
# Epoch 20: loss improved from 0.04883 to 0.04745, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 82ms/step - loss: 0.0474 - val_loss: 0.0378
# Epoch 21/100
#
# Epoch 21: loss improved from 0.04745 to 0.04649, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0465 - val_loss: 0.0374
# Epoch 22/100
#
# Epoch 22: loss improved from 0.04649 to 0.04515, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 106ms/step - loss: 0.0452 - val_loss: 0.0363
# Epoch 23/100
#
# Epoch 23: loss improved from 0.04515 to 0.04373, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 88ms/step - loss: 0.0437 - val_loss: 0.0374
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.04373
# 48/48 - 4s - 80ms/step - loss: 0.0453 - val_loss: 0.0349
# Epoch 25/100
#
# Epoch 25: loss improved from 0.04373 to 0.04252, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0425 - val_loss: 0.0345
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.04252
# 48/48 - 4s - 80ms/step - loss: 0.0429 - val_loss: 0.0351
# Epoch 27/100
#
# Epoch 27: loss improved from 0.04252 to 0.04211, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 83ms/step - loss: 0.0421 - val_loss: 0.0338
# Epoch 28/100
#
# Epoch 28: loss improved from 0.04211 to 0.04161, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0416 - val_loss: 0.0338
# Epoch 29/100
#
# Epoch 29: loss improved from 0.04161 to 0.04000, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 81ms/step - loss: 0.0400 - val_loss: 0.0327
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.04000
# 48/48 - 4s - 91ms/step - loss: 0.0401 - val_loss: 0.0352
# Epoch 31/100
#
# Epoch 31: loss improved from 0.04000 to 0.03878, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 85ms/step - loss: 0.0388 - val_loss: 0.0322
# Epoch 32/100
#
# Epoch 32: loss improved from 0.03878 to 0.03747, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 109ms/step - loss: 0.0375 - val_loss: 0.0324
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.03747
# 48/48 - 4s - 91ms/step - loss: 0.0381 - val_loss: 0.0319
# Epoch 34/100
#
# Epoch 34: loss improved from 0.03747 to 0.03732, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 99ms/step - loss: 0.0373 - val_loss: 0.0322
# Epoch 35/100
#
# Epoch 35: loss improved from 0.03732 to 0.03682, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 94ms/step - loss: 0.0368 - val_loss: 0.0313
# Epoch 36/100
#
# Epoch 36: loss improved from 0.03682 to 0.03572, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 105ms/step - loss: 0.0357 - val_loss: 0.0322
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.03572
# 48/48 - 5s - 109ms/step - loss: 0.0362 - val_loss: 0.0315
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.03572
# 48/48 - 5s - 112ms/step - loss: 0.0360 - val_loss: 0.0330
# Epoch 39/100
#
# Epoch 39: loss improved from 0.03572 to 0.03558, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 99ms/step - loss: 0.0356 - val_loss: 0.0307
# Epoch 40/100
#
# Epoch 40: loss improved from 0.03558 to 0.03528, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 92ms/step - loss: 0.0353 - val_loss: 0.0333
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.03528
# 48/48 - 5s - 103ms/step - loss: 0.0359 - val_loss: 0.0308
# Epoch 42/100
#
# Epoch 42: loss improved from 0.03528 to 0.03495, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 88ms/step - loss: 0.0349 - val_loss: 0.0302
# Epoch 43/100
#
# Epoch 43: loss improved from 0.03495 to 0.03476, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 105ms/step - loss: 0.0348 - val_loss: 0.0304
# Epoch 44/100
#
# Epoch 44: loss improved from 0.03476 to 0.03392, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 89ms/step - loss: 0.0339 - val_loss: 0.0300
# Epoch 45/100
#
# Epoch 45: loss improved from 0.03392 to 0.03305, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 102ms/step - loss: 0.0331 - val_loss: 0.0296
# Epoch 46/100
#
# Epoch 46: loss improved from 0.03305 to 0.03296, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 91ms/step - loss: 0.0330 - val_loss: 0.0317
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.03296
# 48/48 - 5s - 100ms/step - loss: 0.0333 - val_loss: 0.0293
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.03296
# 48/48 - 5s - 94ms/step - loss: 0.0332 - val_loss: 0.0292
# Epoch 49/100
#
# Epoch 49: loss improved from 0.03296 to 0.03251, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 88ms/step - loss: 0.0325 - val_loss: 0.0295
# Epoch 50/100
#
# Epoch 50: loss improved from 0.03251 to 0.03234, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 106ms/step - loss: 0.0323 - val_loss: 0.0292
# Epoch 51/100
#
# Epoch 51: loss improved from 0.03234 to 0.03133, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 96ms/step - loss: 0.0313 - val_loss: 0.0287
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.03133
# 48/48 - 5s - 96ms/step - loss: 0.0325 - val_loss: 0.0291
# Epoch 53/100
#
# Epoch 53: loss improved from 0.03133 to 0.03115, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 96ms/step - loss: 0.0311 - val_loss: 0.0299
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.03115
# 48/48 - 5s - 95ms/step - loss: 0.0312 - val_loss: 0.0281
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.03115
# 48/48 - 4s - 91ms/step - loss: 0.0318 - val_loss: 0.0285
# Epoch 56/100
#
# Epoch 56: loss improved from 0.03115 to 0.03069, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 93ms/step - loss: 0.0307 - val_loss: 0.0293
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.03069
# 48/48 - 5s - 103ms/step - loss: 0.0308 - val_loss: 0.0279
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.03069
# 48/48 - 4s - 91ms/step - loss: 0.0308 - val_loss: 0.0284
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.03069
# 48/48 - 5s - 113ms/step - loss: 0.0310 - val_loss: 0.0277
# Epoch 60/100
#
# Epoch 60: loss improved from 0.03069 to 0.03048, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 96ms/step - loss: 0.0305 - val_loss: 0.0275
# Epoch 61/100
#
# Epoch 61: loss improved from 0.03048 to 0.03015, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 106ms/step - loss: 0.0302 - val_loss: 0.0276
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.03015
# 48/48 - 4s - 93ms/step - loss: 0.0315 - val_loss: 0.0276
# Epoch 63/100
#
# Epoch 63: loss improved from 0.03015 to 0.02959, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 93ms/step - loss: 0.0296 - val_loss: 0.0269
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.02959
# 48/48 - 5s - 95ms/step - loss: 0.0309 - val_loss: 0.0274
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.02959
# 48/48 - 4s - 92ms/step - loss: 0.0296 - val_loss: 0.0266
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.02959
# 48/48 - 4s - 92ms/step - loss: 0.0299 - val_loss: 0.0268
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.02959
# 48/48 - 5s - 103ms/step - loss: 0.0302 - val_loss: 0.0271
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.02959
# 48/48 - 4s - 92ms/step - loss: 0.0310 - val_loss: 0.0274
# Epoch 69/100
#
# Epoch 69: loss improved from 0.02959 to 0.02914, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 102ms/step - loss: 0.0291 - val_loss: 0.0266
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.02914
# 48/48 - 5s - 98ms/step - loss: 0.0294 - val_loss: 0.0266
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02914
# 48/48 - 5s - 98ms/step - loss: 0.0302 - val_loss: 0.0265
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.02914
# 48/48 - 5s - 104ms/step - loss: 0.0302 - val_loss: 0.0268
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.02914
# 48/48 - 4s - 93ms/step - loss: 0.0293 - val_loss: 0.0262
# Epoch 74/100
#
# Epoch 74: loss improved from 0.02914 to 0.02911, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 101ms/step - loss: 0.0291 - val_loss: 0.0259
# Epoch 75/100
#
# Epoch 75: loss improved from 0.02911 to 0.02827, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 97ms/step - loss: 0.0283 - val_loss: 0.0257
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02827
# 48/48 - 5s - 99ms/step - loss: 0.0285 - val_loss: 0.0262
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.02827
# 48/48 - 4s - 88ms/step - loss: 0.0290 - val_loss: 0.0264
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.02827
# 48/48 - 4s - 88ms/step - loss: 0.0293 - val_loss: 0.0268
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.02827
# 48/48 - 5s - 100ms/step - loss: 0.0295 - val_loss: 0.0255
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.02827
# 48/48 - 5s - 107ms/step - loss: 0.0286 - val_loss: 0.0265
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.02827
# 48/48 - 5s - 101ms/step - loss: 0.0294 - val_loss: 0.0253
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.02827
# 48/48 - 4s - 92ms/step - loss: 0.0287 - val_loss: 0.0254
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.02827
# 48/48 - 4s - 88ms/step - loss: 0.0288 - val_loss: 0.0259
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.02827
# 48/48 - 4s - 86ms/step - loss: 0.0297 - val_loss: 0.0256
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.02827
# 48/48 - 4s - 93ms/step - loss: 0.0295 - val_loss: 0.0257
# Epoch 86/100
#
# Epoch 86: loss improved from 0.02827 to 0.02815, saving model to save_models/BVH_model.keras
# 48/48 - 5s - 110ms/step - loss: 0.0281 - val_loss: 0.0255
# Epoch 87/100
#
# Epoch 87: loss improved from 0.02815 to 0.02794, saving model to save_models/BVH_model.keras
# 48/48 - 6s - 130ms/step - loss: 0.0279 - val_loss: 0.0256
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.02794
# 48/48 - 6s - 120ms/step - loss: 0.0284 - val_loss: 0.0252
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.02794
# 48/48 - 4s - 93ms/step - loss: 0.0294 - val_loss: 0.0269
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.02794
# 48/48 - 5s - 95ms/step - loss: 0.0284 - val_loss: 0.0251
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.02794
# 48/48 - 5s - 99ms/step - loss: 0.0283 - val_loss: 0.0269
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.02794
# 48/48 - 4s - 92ms/step - loss: 0.0290 - val_loss: 0.0261
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.02794
# 48/48 - 5s - 105ms/step - loss: 0.0285 - val_loss: 0.0250
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.02794
# 48/48 - 5s - 98ms/step - loss: 0.0280 - val_loss: 0.0249
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.02794
# 48/48 - 5s - 99ms/step - loss: 0.0282 - val_loss: 0.0246
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.02794
# 48/48 - 5s - 94ms/step - loss: 0.0280 - val_loss: 0.0256
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.02794
# 48/48 - 5s - 106ms/step - loss: 0.0282 - val_loss: 0.0256
# Epoch 98/100
#
# Epoch 98: loss improved from 0.02794 to 0.02759, saving model to save_models/BVH_model.keras
# 48/48 - 4s - 89ms/step - loss: 0.0276 - val_loss: 0.0242
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.02759
# 48/48 - 5s - 106ms/step - loss: 0.0285 - val_loss: 0.0249
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.02759
# 48/48 - 4s - 91ms/step - loss: 0.0278 - val_loss: 0.0250
# Restoring model weights from the end of the best epoch: 98.

# %%
save_model_path = "save_models/BVH_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9869226203228909
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 1.383676113521904
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.4561581931183762
# RMSE trên tập train (VNĐ): 1.9860098162127542
# Độ chính xác trên tập train (%): 97.66626343570769
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9662665193034846
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.7921187230782916
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.5914233886051041
# RMSE trên tập test (VNĐ): 1.1757025148239286
# Độ chính xác trên tập test (%): 95.84557415256563
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
