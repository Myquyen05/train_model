# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['SHB']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2009-04-21          2.55       15.40             769000    1.159867e+10
# 1     2009-05-08          3.11       18.80            1997000    3.693096e+10
# 2     2009-05-11          3.06       18.50            1146500    2.121971e+10
# 3     2009-05-13          3.08       18.60             792100    1.472497e+10
# 4     2009-05-29          4.17       25.20            2490700    6.251849e+10
# ...          ...           ...         ...                ...             ...
# 3910  2024-12-17         10.35       10.35            5356100    5.542700e+10
# 3911  2024-12-13         10.40       10.40            7682100    8.024600e+10
# 3912  2024-12-18         10.35       10.35            3927800    4.063700e+10
# 3913  2024-12-19         10.20       10.20           22186000    2.269230e+11
# 3914  2024-12-20         10.15       10.15           13996400    1.426120e+11
#
#       KLThoaThuan   GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0           64000     885600000     15.10       15.40        14.10
# 1               0             0     19.50       19.50        18.20
# 2               0             0     19.20       19.20        18.10
# 3               0             0     18.70       19.00        18.40
# 4               0             0     23.90       25.20        23.60
# ...           ...           ...       ...         ...          ...
# 3910      4269002   44755754360     10.35       10.40        10.30
# 3911     11325001  119161259770     10.45       10.55        10.40
# 3912       584001    6205609630     10.35       10.40        10.30
# 3913       855001    9091759630     10.30       10.35        10.15
# 3914            0             0     10.20       10.25        10.15
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               0.00              0.00
# 1              -0.70             -3.59
# 2               0.00              0.00
# 3               0.10              0.54
# 4               1.60              6.78
# ...              ...               ...
# 3910           -0.05             -0.48
# 3911           -0.10             -0.95
# 3912            0.00              0.00
# 3913           -0.15             -1.45
# 3914           -0.05             -0.49
#
# [3915 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3915 entries, 0 to 3914
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               3915 non-null   object
#  1   GiaDieuChinh       3915 non-null   float64
#  2   GiaDongCua         3915 non-null   float64
#  3   KhoiLuongKhopLenh  3915 non-null   int64
#  4   GiaTriKhopLenh     3915 non-null   float64
#  5   KLThoaThuan        3915 non-null   int64
#  6   GtThoaThuan        3915 non-null   int64
#  7   GiaMoCua           3915 non-null   float64
#  8   GiaCaoNhat         3915 non-null   float64
#  9   GiaThapNhat        3915 non-null   float64
#  10  ThayDoi_GiaTri     3915 non-null   float64
#  11  ThayDoi_PhanTram   3915 non-null   float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 367.2+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   3915.000000  3915.000000       3.915000e+03    3.915000e+03
# mean       5.096031    11.607364       8.002837e+06    1.064433e+11
# std        4.208915     6.535257       1.023260e+07    1.796608e+11
# min        1.250000     4.500000       4.620000e+04    9.402800e+08
# 25%        2.180000     7.100000       1.380161e+06    1.077149e+10
# 50%        2.680000     9.300000       3.882565e+06    3.545855e+10
# 75%        8.240000    13.000000       1.108331e+07    1.268960e+11
# max       18.560000    40.500000       1.271032e+08    1.683911e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  3.915000e+03  3.915000e+03  3915.000000  3915.000000  3915.000000
# mean   1.601555e+06  1.956388e+10    11.629267    11.846084    11.387806
# std    4.091677e+06  5.822632e+10     6.578305     6.704040     6.387799
# min    0.000000e+00  0.000000e+00     4.200000     4.600000     4.200000
# 25%    0.000000e+00  0.000000e+00     7.100000     7.200000     6.900000
# 50%    2.029600e+04  2.114363e+08     9.300000     9.500000     9.100000
# 75%    1.383026e+06  1.252277e+10    13.000000    13.300000    12.800000
# max    7.450000e+07  1.419000e+12    40.000000    41.600000    38.000000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     3915.000000       3915.000000
# mean        -0.000133          0.020519
# std          0.389438          2.576493
# min         -2.700000        -15.050000
# 25%         -0.100000         -1.350000
# 50%          0.000000          0.000000
# 75%          0.100000          1.250000
# max          2.600000         10.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2009-04-20       15.20
# 2009-04-21       15.40
# 2009-04-22       16.10
# 2009-04-23       17.20
# 2009-04-24       16.90
# ...                ...
# 2024-12-16       10.40
# 2024-12-17       10.35
# 2024-12-18       10.35
# 2024-12-19       10.20
# 2024-12-20       10.15
#
# [3915 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[15.2 ],
#        [15.4 ],
#        [16.1 ],
#        ...,
#        [10.35],
#        [10.2 ],
#        [10.15]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/SHB_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.19606, saving model to save_models/SHB_model.keras
# 49/49 - 12s - 243ms/step - loss: 0.1961 - val_loss: 0.1308
# Epoch 2/100
#
# Epoch 2: loss improved from 0.19606 to 0.11556, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 106ms/step - loss: 0.1156 - val_loss: 0.0897
# Epoch 3/100
#
# Epoch 3: loss improved from 0.11556 to 0.08337, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 101ms/step - loss: 0.0834 - val_loss: 0.0657
# Epoch 4/100
#
# Epoch 4: loss improved from 0.08337 to 0.06425, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 106ms/step - loss: 0.0643 - val_loss: 0.0511
# Epoch 5/100
#
# Epoch 5: loss improved from 0.06425 to 0.05198, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 107ms/step - loss: 0.0520 - val_loss: 0.0480
# Epoch 6/100
#
# Epoch 6: loss improved from 0.05198 to 0.04538, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 109ms/step - loss: 0.0454 - val_loss: 0.0385
# Epoch 7/100
#
# Epoch 7: loss improved from 0.04538 to 0.04065, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 104ms/step - loss: 0.0407 - val_loss: 0.0358
# Epoch 8/100
#
# Epoch 8: loss improved from 0.04065 to 0.03643, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 108ms/step - loss: 0.0364 - val_loss: 0.0324
# Epoch 9/100
#
# Epoch 9: loss improved from 0.03643 to 0.03436, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 121ms/step - loss: 0.0344 - val_loss: 0.0328
# Epoch 10/100
#
# Epoch 10: loss improved from 0.03436 to 0.03232, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 124ms/step - loss: 0.0323 - val_loss: 0.0282
# Epoch 11/100
#
# Epoch 11: loss improved from 0.03232 to 0.02978, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 112ms/step - loss: 0.0298 - val_loss: 0.0259
# Epoch 12/100
#
# Epoch 12: loss improved from 0.02978 to 0.02888, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 118ms/step - loss: 0.0289 - val_loss: 0.0248
# Epoch 13/100
#
# Epoch 13: loss improved from 0.02888 to 0.02801, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 132ms/step - loss: 0.0280 - val_loss: 0.0244
# Epoch 14/100
#
# Epoch 14: loss improved from 0.02801 to 0.02657, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 129ms/step - loss: 0.0266 - val_loss: 0.0228
# Epoch 15/100
#
# Epoch 15: loss improved from 0.02657 to 0.02520, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 121ms/step - loss: 0.0252 - val_loss: 0.0224
# Epoch 16/100
#
# Epoch 16: loss improved from 0.02520 to 0.02518, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 125ms/step - loss: 0.0252 - val_loss: 0.0243
# Epoch 17/100
#
# Epoch 17: loss improved from 0.02518 to 0.02403, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 121ms/step - loss: 0.0240 - val_loss: 0.0221
# Epoch 18/100
#
# Epoch 18: loss improved from 0.02403 to 0.02393, saving model to save_models/SHB_model.keras
# 49/49 - 10s - 203ms/step - loss: 0.0239 - val_loss: 0.0211
# Epoch 19/100
#
# Epoch 19: loss improved from 0.02393 to 0.02285, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 106ms/step - loss: 0.0229 - val_loss: 0.0207
# Epoch 20/100
#
# Epoch 20: loss improved from 0.02285 to 0.02283, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 120ms/step - loss: 0.0228 - val_loss: 0.0309
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.02283
# 49/49 - 5s - 106ms/step - loss: 0.0235 - val_loss: 0.0208
# Epoch 22/100
#
# Epoch 22: loss improved from 0.02283 to 0.02218, saving model to save_models/SHB_model.keras
# 49/49 - 4s - 90ms/step - loss: 0.0222 - val_loss: 0.0188
# Epoch 23/100
#
# Epoch 23: loss improved from 0.02218 to 0.02134, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 106ms/step - loss: 0.0213 - val_loss: 0.0224
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.02134
# 49/49 - 5s - 98ms/step - loss: 0.0217 - val_loss: 0.0185
# Epoch 25/100
#
# Epoch 25: loss improved from 0.02134 to 0.02089, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 101ms/step - loss: 0.0209 - val_loss: 0.0197
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.02089
# 49/49 - 5s - 100ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.02089
# 49/49 - 6s - 115ms/step - loss: 0.0210 - val_loss: 0.0216
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.02089
# 49/49 - 5s - 110ms/step - loss: 0.0210 - val_loss: 0.0188
# Epoch 29/100
#
# Epoch 29: loss improved from 0.02089 to 0.02086, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 130ms/step - loss: 0.0209 - val_loss: 0.0174
# Epoch 30/100
#
# Epoch 30: loss improved from 0.02086 to 0.01951, saving model to save_models/SHB_model.keras
# 49/49 - 10s - 199ms/step - loss: 0.0195 - val_loss: 0.0187
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01951
# 49/49 - 5s - 111ms/step - loss: 0.0201 - val_loss: 0.0179
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01951
# 49/49 - 5s - 104ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01951
# 49/49 - 6s - 120ms/step - loss: 0.0207 - val_loss: 0.0186
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01951
# 49/49 - 5s - 109ms/step - loss: 0.0199 - val_loss: 0.0255
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01951
# 49/49 - 11s - 217ms/step - loss: 0.0202 - val_loss: 0.0261
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01951
# 49/49 - 6s - 120ms/step - loss: 0.0206 - val_loss: 0.0187
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01951
# 49/49 - 5s - 111ms/step - loss: 0.0205 - val_loss: 0.0174
# Epoch 38/100
#
# Epoch 38: loss improved from 0.01951 to 0.01904, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 115ms/step - loss: 0.0190 - val_loss: 0.0177
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01904
# 49/49 - 6s - 119ms/step - loss: 0.0196 - val_loss: 0.0227
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01904
# 49/49 - 6s - 125ms/step - loss: 0.0198 - val_loss: 0.0202
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01904
# 49/49 - 6s - 117ms/step - loss: 0.0194 - val_loss: 0.0161
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01904
# 49/49 - 5s - 112ms/step - loss: 0.0192 - val_loss: 0.0168
# Epoch 43/100
#
# Epoch 43: loss improved from 0.01904 to 0.01871, saving model to save_models/SHB_model.keras
# 49/49 - 6s - 133ms/step - loss: 0.0187 - val_loss: 0.0168
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01871
# 49/49 - 6s - 117ms/step - loss: 0.0193 - val_loss: 0.0227
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01871
# 49/49 - 6s - 115ms/step - loss: 0.0199 - val_loss: 0.0175
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01871
# 49/49 - 5s - 111ms/step - loss: 0.0196 - val_loss: 0.0161
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01871
# 49/49 - 7s - 139ms/step - loss: 0.0193 - val_loss: 0.0178
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01871
# 49/49 - 7s - 138ms/step - loss: 0.0188 - val_loss: 0.0168
# Epoch 49/100
#
# Epoch 49: loss improved from 0.01871 to 0.01852, saving model to save_models/SHB_model.keras
# 49/49 - 7s - 139ms/step - loss: 0.0185 - val_loss: 0.0164
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01852
# 49/49 - 10s - 207ms/step - loss: 0.0187 - val_loss: 0.0168
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01852
# 49/49 - 6s - 123ms/step - loss: 0.0190 - val_loss: 0.0161
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01852
# 49/49 - 5s - 110ms/step - loss: 0.0190 - val_loss: 0.0165
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01852
# 49/49 - 6s - 114ms/step - loss: 0.0188 - val_loss: 0.0181
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01852
# 49/49 - 6s - 124ms/step - loss: 0.0195 - val_loss: 0.0165
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01852
# 49/49 - 6s - 122ms/step - loss: 0.0189 - val_loss: 0.0179
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01852
# 49/49 - 6s - 127ms/step - loss: 0.0192 - val_loss: 0.0155
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01852
# 49/49 - 10s - 209ms/step - loss: 0.0189 - val_loss: 0.0159
# Epoch 58/100
#
# Epoch 58: loss improved from 0.01852 to 0.01844, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 103ms/step - loss: 0.0184 - val_loss: 0.0173
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01844
# 49/49 - 6s - 122ms/step - loss: 0.0188 - val_loss: 0.0172
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01844
# 49/49 - 6s - 128ms/step - loss: 0.0188 - val_loss: 0.0154
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01844
# 49/49 - 6s - 131ms/step - loss: 0.0194 - val_loss: 0.0196
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01844
# 49/49 - 6s - 122ms/step - loss: 0.0186 - val_loss: 0.0183
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01844
# 49/49 - 6s - 120ms/step - loss: 0.0194 - val_loss: 0.0174
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01844
# 49/49 - 6s - 122ms/step - loss: 0.0186 - val_loss: 0.0154
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01844
# 49/49 - 11s - 229ms/step - loss: 0.0186 - val_loss: 0.0151
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01844
# 49/49 - 6s - 130ms/step - loss: 0.0190 - val_loss: 0.0183
# Epoch 67/100
#
# Epoch 67: loss improved from 0.01844 to 0.01803, saving model to save_models/SHB_model.keras
# 49/49 - 7s - 153ms/step - loss: 0.0180 - val_loss: 0.0176
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01803
# 49/49 - 7s - 134ms/step - loss: 0.0180 - val_loss: 0.0175
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01803
# 49/49 - 5s - 111ms/step - loss: 0.0187 - val_loss: 0.0160
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01803
# 49/49 - 5s - 111ms/step - loss: 0.0190 - val_loss: 0.0155
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01803
# 49/49 - 6s - 120ms/step - loss: 0.0181 - val_loss: 0.0150
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01803
# 49/49 - 10s - 201ms/step - loss: 0.0189 - val_loss: 0.0153
# Epoch 73/100
#
# Epoch 73: loss improved from 0.01803 to 0.01780, saving model to save_models/SHB_model.keras
# 49/49 - 11s - 228ms/step - loss: 0.0178 - val_loss: 0.0165
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01780
# 49/49 - 6s - 124ms/step - loss: 0.0186 - val_loss: 0.0150
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01780
# 49/49 - 6s - 126ms/step - loss: 0.0179 - val_loss: 0.0154
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01780
# 49/49 - 6s - 131ms/step - loss: 0.0184 - val_loss: 0.0155
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01780
# 49/49 - 6s - 132ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01780
# 49/49 - 7s - 135ms/step - loss: 0.0179 - val_loss: 0.0175
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01780
# 49/49 - 6s - 131ms/step - loss: 0.0186 - val_loss: 0.0180
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01780
# 49/49 - 6s - 126ms/step - loss: 0.0181 - val_loss: 0.0143
# Epoch 81/100
#
# Epoch 81: loss improved from 0.01780 to 0.01769, saving model to save_models/SHB_model.keras
# 49/49 - 5s - 103ms/step - loss: 0.0177 - val_loss: 0.0148
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01769
# 49/49 - 6s - 127ms/step - loss: 0.0185 - val_loss: 0.0169
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01769
# 49/49 - 6s - 128ms/step - loss: 0.0180 - val_loss: 0.0148
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01769
# 49/49 - 11s - 222ms/step - loss: 0.0179 - val_loss: 0.0148
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01769
# 49/49 - 6s - 131ms/step - loss: 0.0179 - val_loss: 0.0188
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01769
# 49/49 - 6s - 132ms/step - loss: 0.0185 - val_loss: 0.0150
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01769
# 49/49 - 6s - 124ms/step - loss: 0.0177 - val_loss: 0.0140
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01769
# 49/49 - 6s - 124ms/step - loss: 0.0184 - val_loss: 0.0144
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01769
# 49/49 - 6s - 130ms/step - loss: 0.0178 - val_loss: 0.0185
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01769
# 49/49 - 6s - 127ms/step - loss: 0.0180 - val_loss: 0.0152
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01769
# 49/49 - 9s - 192ms/step - loss: 0.0183 - val_loss: 0.0143
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01769
# 49/49 - 6s - 125ms/step - loss: 0.0182 - val_loss: 0.0142
# Epoch 93/100
#
# Epoch 93: loss improved from 0.01769 to 0.01741, saving model to save_models/SHB_model.keras
# 49/49 - 10s - 214ms/step - loss: 0.0174 - val_loss: 0.0158
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01741
# 49/49 - 5s - 107ms/step - loss: 0.0181 - val_loss: 0.0143
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01741
# 49/49 - 6s - 127ms/step - loss: 0.0179 - val_loss: 0.0153
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01741
# 49/49 - 6s - 124ms/step - loss: 0.0185 - val_loss: 0.0148
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01741
# 49/49 - 6s - 127ms/step - loss: 0.0180 - val_loss: 0.0193
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01741
# 49/49 - 6s - 122ms/step - loss: 0.0176 - val_loss: 0.0161
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01741
# 49/49 - 6s - 116ms/step - loss: 0.0182 - val_loss: 0.0144
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01741
# 49/49 - 7s - 135ms/step - loss: 0.0180 - val_loss: 0.0147
# Restoring model weights from the end of the best epoch: 93.

# %%
# Hàm xây dựng mô hình
def build_model():
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(units=64))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# Huấn luyện mô hình
model = build_model()
save_model_path = f"save_models/{collection}_model.keras"
best_model = ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.01953, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 9s - 127ms/step - loss: 0.0195
# Epoch 2/100
#
# Epoch 2: loss improved from 0.01953 to 0.01390, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 67ms/step - loss: 0.0139
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01390 to 0.01147, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 69ms/step - loss: 0.0115
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.01147
# 72/72 - 5s - 64ms/step - loss: 0.0124
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01147 to 0.01087, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0109
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01087 to 0.01084, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 64ms/step - loss: 0.0108
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.01084
# 72/72 - 5s - 66ms/step - loss: 0.0114
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.01084
# 72/72 - 5s - 68ms/step - loss: 0.0109
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01084 to 0.01023, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0102
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01023 to 0.00967, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 68ms/step - loss: 0.0097
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00967
# 72/72 - 5s - 66ms/step - loss: 0.0104
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00967
# 72/72 - 5s - 69ms/step - loss: 0.0098
# Epoch 13/100
#
# Epoch 13: loss improved from 0.00967 to 0.00954, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 65ms/step - loss: 0.0095
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00954
# 72/72 - 4s - 62ms/step - loss: 0.0099
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.00954
# 72/72 - 5s - 64ms/step - loss: 0.0098
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.00954
# 72/72 - 5s - 63ms/step - loss: 0.0100
# Epoch 17/100
#
# Epoch 17: loss improved from 0.00954 to 0.00887, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00887
# 72/72 - 4s - 57ms/step - loss: 0.0096
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0095
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0102
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00887
# 72/72 - 4s - 58ms/step - loss: 0.0138
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00887
# 72/72 - 4s - 59ms/step - loss: 0.0094
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00887
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0089
# Epoch 28/100
#
# Epoch 28: loss improved from 0.00887 to 0.00879, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00879 to 0.00859, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00859
# 72/72 - 5s - 75ms/step - loss: 0.0094
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00859
# 72/72 - 4s - 58ms/step - loss: 0.0090
# Epoch 32/100
#
# Epoch 32: loss improved from 0.00859 to 0.00851, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0114
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0091
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0091
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00851
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00851
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0089
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 41/100
#
# Epoch 41: loss improved from 0.00851 to 0.00840, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00840 to 0.00836, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00836
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00836
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 45/100
#
# Epoch 45: loss improved from 0.00836 to 0.00829, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0083
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00829
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00829 to 0.00812, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0086
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0082
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00812
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0093
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00812
# 72/72 - 5s - 63ms/step - loss: 0.0083
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00812 to 0.00806, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00806
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00806 to 0.00791, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0084
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0079
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0108
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0091
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0081
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0085
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00791
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0086
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0081
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00791 to 0.00789, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0079
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0112
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0094
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00789
# 72/72 - 4s - 59ms/step - loss: 0.0095
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00789
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00789
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0080
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 89/100
#
# Epoch 89: loss improved from 0.00789 to 0.00785, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0079
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00785 to 0.00780, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0078
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0080
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0083
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00780
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00780
# 72/72 - 5s - 63ms/step - loss: 0.0084
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00780 to 0.00772, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0077

# %%
save_model_path = "save_models/SHB_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[1500:] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9917509513969084
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 0.3383790624830183
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.8022673673548524
# RMSE trên tập train (VNĐ): 0.6061168603000137
# Độ chính xác trên tập train (%): 98.17434680632526
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9753712409785367
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.3768675386372806
# Phần trăm sai số tuyệt đối trung bình trên tập test: 2.6771753565892
# RMSE trên tập test (VNĐ): 0.6363184132882393
# Độ chính xác trên tập test (%): 97.1894063017304
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
