# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['VPB']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2017-08-23          7.50       36.20             520790     18835000000
# 1     2017-08-24          7.51       36.25             678690     24497000000
# 2     2017-09-08          7.91       38.20             339640     13031000000
# 3     2017-09-11          7.67       37.00             655570     24475000000
# 4     2017-10-02          7.72       37.25             634350     23710000000
# ...          ...           ...         ...                ...             ...
# 1832  2024-12-17         18.95       18.95            8186500    155606000000
# 1833  2024-12-13         19.15       19.15            7750600    148718000000
# 1834  2024-12-18         19.00       19.00            4843000     92072000000
# 1835  2024-12-19         18.80       18.80           21112100    396073000000
# 1836  2024-12-20         18.90       18.90            6638600    124657000000
#
#       KLThoaThuan   GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0             0     36.00       36.80        35.75
# 1          610937   22738576900     36.35       36.35        35.80
# 2               0             0     38.50       38.50        38.15
# 3           60000    2133000000     38.00       38.10        36.90
# 4               0             0     37.50       37.60        37.00
# ...           ...           ...       ...         ...          ...
# 1832      3365000   63574600000     19.10       19.15        18.95
# 1833     14700002  290092535900     19.20       19.30        19.10
# 1834      3400501   67834517650     19.00       19.10        18.95
# 1835       215000    4212000000     18.95       18.95        18.60
# 1836            0             0     18.80       18.90        18.65
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               0.20              0.56
# 1               0.05              0.14
# 2              -0.35             -0.91
# 3              -1.20             -3.14
# 4              -0.25             -0.67
# ...              ...               ...
# 1832           -0.15             -0.79
# 1833           -0.15             -0.78
# 1834            0.05              0.26
# 1835           -0.20             -1.05
# 1836            0.10              0.53
#
# [1837 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               1837 non-null   object
#  1   GiaDieuChinh       1837 non-null   float64
#  2   GiaDongCua         1837 non-null   float64
#  3   KhoiLuongKhopLenh  1837 non-null   int64
#  4   GiaTriKhopLenh     1837 non-null   int64
#  5   KLThoaThuan        1837 non-null   int64
#  6   GtThoaThuan        1837 non-null   int64
#  7   GiaMoCua           1837 non-null   float64
#  8   GiaCaoNhat         1837 non-null   float64
#  9   GiaThapNhat        1837 non-null   float64
#  10  ThayDoi_GiaTri     1837 non-null   float64
#  11  ThayDoi_PhanTram   1837 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 172.3+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   1837.000000  1837.000000       1.837000e+03    1.837000e+03
# mean      13.812112    29.092542       1.013771e+07    3.011198e+11
# std        5.735441    13.744285       1.007580e+07    4.259942e+11
# min        5.680000    14.650000       2.199900e+05    8.135000e+09
# 25%        7.810000    19.500000       3.019180e+06    7.970000e+10
# 50%       14.670000    22.350000       7.066080e+06    1.915670e+11
# 75%       18.750000    36.000000       1.359910e+07    3.474140e+11
# max       24.370000    72.700000       7.658340e+07    5.448352e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  1.837000e+03  1.837000e+03  1837.000000  1837.000000  1837.000000
# mean   1.729560e+06  4.218281e+10    29.078688    29.501252    28.640147
# std    3.270042e+06  7.787455e+10    13.708889    13.947124    13.463384
# min    0.000000e+00  0.000000e+00    13.650000    15.250000    13.650000
# 25%    0.000000e+00  0.000000e+00    19.550000    19.750000    19.300000
# 50%    4.100000e+05  1.148838e+10    22.300000    22.550000    22.000000
# 75%    2.174006e+06  5.403604e+10    36.000000    36.400000    35.500000
# max    4.178438e+07  1.004466e+12    72.500000    73.300000    71.500000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     1837.000000       1837.000000
# mean         0.009243          0.039058
# std          0.704613          2.105152
# min         -4.800000         -7.210000
# 25%         -0.250000         -0.950000
# 50%          0.000000          0.000000
# 75%          0.250000          0.970000
# max          3.500000          6.970000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2017-08-17       39.00
# 2017-08-18       37.20
# 2017-08-21       35.85
# 2017-08-22       36.00
# 2017-08-23       36.20
# ...                ...
# 2024-12-16       19.10
# 2024-12-17       18.95
# 2024-12-18       19.00
# 2024-12-19       18.80
# 2024-12-20       18.90
#
# [1837 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[39.  ],
#        [37.2 ],
#        [35.85],
#        ...,
#        [19.  ],
#        [18.8 ],
#        [18.9 ]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # Giảm số đơn vị trong LSTM và tăng regularization
    model.add(LSTM(units=64, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.2))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0001))
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/VPB_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=15, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.36001, saving model to save_models/VPB_model.keras
# 23/23 - 11s - 491ms/step - loss: 0.3600 - val_loss: 0.3939
# Epoch 2/100
#
# Epoch 2: loss improved from 0.36001 to 0.26541, saving model to save_models/VPB_model.keras
# 23/23 - 6s - 281ms/step - loss: 0.2654 - val_loss: 0.2584
# Epoch 3/100
#
# Epoch 3: loss improved from 0.26541 to 0.18599, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 58ms/step - loss: 0.1860 - val_loss: 0.1726
# Epoch 4/100
#
# Epoch 4: loss improved from 0.18599 to 0.15581, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.1558 - val_loss: 0.1536
# Epoch 5/100
#
# Epoch 5: loss improved from 0.15581 to 0.13580, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 52ms/step - loss: 0.1358 - val_loss: 0.1391
# Epoch 6/100
#
# Epoch 6: loss improved from 0.13580 to 0.12917, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.1292 - val_loss: 0.1349
# Epoch 7/100
#
# Epoch 7: loss improved from 0.12917 to 0.12751, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.1275 - val_loss: 0.1306
# Epoch 8/100
#
# Epoch 8: loss improved from 0.12751 to 0.12344, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.1234 - val_loss: 0.1269
# Epoch 9/100
#
# Epoch 9: loss improved from 0.12344 to 0.12047, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.1205 - val_loss: 0.1247
# Epoch 10/100
#
# Epoch 10: loss improved from 0.12047 to 0.11776, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 42ms/step - loss: 0.1178 - val_loss: 0.1219
# Epoch 11/100
#
# Epoch 11: loss improved from 0.11776 to 0.11381, saving model to save_models/VPB_model.keras
# 23/23 - 3s - 142ms/step - loss: 0.1138 - val_loss: 0.1183
# Epoch 12/100
#
# Epoch 12: loss improved from 0.11381 to 0.11157, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.1116 - val_loss: 0.1146
# Epoch 13/100
#
# Epoch 13: loss improved from 0.11157 to 0.10906, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.1091 - val_loss: 0.1125
# Epoch 14/100
#
# Epoch 14: loss improved from 0.10906 to 0.10626, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.1063 - val_loss: 0.1096
# Epoch 15/100
#
# Epoch 15: loss improved from 0.10626 to 0.10314, saving model to save_models/VPB_model.keras
# 23/23 - 8s - 360ms/step - loss: 0.1031 - val_loss: 0.1070
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.10314
# 23/23 - 1s - 42ms/step - loss: 0.1041 - val_loss: 0.1045
# Epoch 17/100
#
# Epoch 17: loss improved from 0.10314 to 0.09943, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0994 - val_loss: 0.1051
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.09943
# 23/23 - 1s - 41ms/step - loss: 0.1006 - val_loss: 0.1001
# Epoch 19/100
#
# Epoch 19: loss improved from 0.09943 to 0.09682, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0968 - val_loss: 0.0977
# Epoch 20/100
#
# Epoch 20: loss improved from 0.09682 to 0.09410, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0941 - val_loss: 0.0957
# Epoch 21/100
#
# Epoch 21: loss improved from 0.09410 to 0.09178, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0918 - val_loss: 0.0941
# Epoch 22/100
#
# Epoch 22: loss improved from 0.09178 to 0.09037, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0904 - val_loss: 0.0923
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.09037
# 23/23 - 1s - 40ms/step - loss: 0.0915 - val_loss: 0.0905
# Epoch 24/100
#
# Epoch 24: loss improved from 0.09037 to 0.08839, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0884 - val_loss: 0.0906
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.08839
# 23/23 - 1s - 42ms/step - loss: 0.0888 - val_loss: 0.0887
# Epoch 26/100
#
# Epoch 26: loss improved from 0.08839 to 0.08582, saving model to save_models/VPB_model.keras
# 23/23 - 2s - 99ms/step - loss: 0.0858 - val_loss: 0.0863
# Epoch 27/100
#
# Epoch 27: loss improved from 0.08582 to 0.08272, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0827 - val_loss: 0.0845
# Epoch 28/100
#
# Epoch 28: loss improved from 0.08272 to 0.08168, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0817 - val_loss: 0.0834
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.08168
# 23/23 - 1s - 42ms/step - loss: 0.0832 - val_loss: 0.0826
# Epoch 30/100
#
# Epoch 30: loss improved from 0.08168 to 0.08049, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.0805 - val_loss: 0.0805
# Epoch 31/100
#
# Epoch 31: loss improved from 0.08049 to 0.07927, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0793 - val_loss: 0.0800
# Epoch 32/100
#
# Epoch 32: loss improved from 0.07927 to 0.07861, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0786 - val_loss: 0.0782
# Epoch 33/100
#
# Epoch 33: loss improved from 0.07861 to 0.07597, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0760 - val_loss: 0.0768
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.07597
# 23/23 - 1s - 41ms/step - loss: 0.0768 - val_loss: 0.0766
# Epoch 35/100
#
# Epoch 35: loss improved from 0.07597 to 0.07381, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.0738 - val_loss: 0.0751
# Epoch 36/100
#
# Epoch 36: loss improved from 0.07381 to 0.07354, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0735 - val_loss: 0.0739
# Epoch 37/100
#
# Epoch 37: loss improved from 0.07354 to 0.07296, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 56ms/step - loss: 0.0730 - val_loss: 0.0724
# Epoch 38/100
#
# Epoch 38: loss improved from 0.07296 to 0.07170, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0717 - val_loss: 0.0717
# Epoch 39/100
#
# Epoch 39: loss improved from 0.07170 to 0.06993, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0699 - val_loss: 0.0711
# Epoch 40/100
#
# Epoch 40: loss improved from 0.06993 to 0.06916, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0692 - val_loss: 0.0701
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.06916
# 23/23 - 1s - 43ms/step - loss: 0.0692 - val_loss: 0.0697
# Epoch 42/100
#
# Epoch 42: loss improved from 0.06916 to 0.06779, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0678 - val_loss: 0.0686
# Epoch 43/100
#
# Epoch 43: loss improved from 0.06779 to 0.06755, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0675 - val_loss: 0.0699
# Epoch 44/100
#
# Epoch 44: loss improved from 0.06755 to 0.06694, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0669 - val_loss: 0.0676
# Epoch 45/100
#
# Epoch 45: loss improved from 0.06694 to 0.06531, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0653 - val_loss: 0.0670
# Epoch 46/100
#
# Epoch 46: loss improved from 0.06531 to 0.06513, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0651 - val_loss: 0.0653
# Epoch 47/100
#
# Epoch 47: loss improved from 0.06513 to 0.06442, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0644 - val_loss: 0.0641
# Epoch 48/100
#
# Epoch 48: loss improved from 0.06442 to 0.06369, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.0637 - val_loss: 0.0657
# Epoch 49/100
#
# Epoch 49: loss improved from 0.06369 to 0.06258, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0626 - val_loss: 0.0641
# Epoch 50/100
#
# Epoch 50: loss improved from 0.06258 to 0.06161, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0616 - val_loss: 0.0629
# Epoch 51/100
#
# Epoch 51: loss improved from 0.06161 to 0.06069, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0607 - val_loss: 0.0619
# Epoch 52/100
#
# Epoch 52: loss improved from 0.06069 to 0.06050, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 62ms/step - loss: 0.0605 - val_loss: 0.0611
# Epoch 53/100
#
# Epoch 53: loss improved from 0.06050 to 0.05936, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0594 - val_loss: 0.0606
# Epoch 54/100
#
# Epoch 54: loss improved from 0.05936 to 0.05850, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 42ms/step - loss: 0.0585 - val_loss: 0.0598
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.05850
# 23/23 - 1s - 45ms/step - loss: 0.0596 - val_loss: 0.0594
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.05850
# 23/23 - 1s - 41ms/step - loss: 0.0590 - val_loss: 0.0585
# Epoch 57/100
#
# Epoch 57: loss improved from 0.05850 to 0.05792, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0579 - val_loss: 0.0583
# Epoch 58/100
#
# Epoch 58: loss improved from 0.05792 to 0.05758, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.0576 - val_loss: 0.0585
# Epoch 59/100
#
# Epoch 59: loss improved from 0.05758 to 0.05588, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0559 - val_loss: 0.0568
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.05588
# 23/23 - 1s - 41ms/step - loss: 0.0564 - val_loss: 0.0567
# Epoch 61/100
#
# Epoch 61: loss improved from 0.05588 to 0.05518, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0552 - val_loss: 0.0583
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.05518
# 23/23 - 1s - 44ms/step - loss: 0.0552 - val_loss: 0.0567
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.05518
# 23/23 - 1s - 43ms/step - loss: 0.0558 - val_loss: 0.0549
# Epoch 64/100
#
# Epoch 64: loss improved from 0.05518 to 0.05408, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0541 - val_loss: 0.0554
# Epoch 65/100
#
# Epoch 65: loss improved from 0.05408 to 0.05395, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 48ms/step - loss: 0.0540 - val_loss: 0.0541
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.05395
# 23/23 - 1s - 48ms/step - loss: 0.0540 - val_loss: 0.0535
# Epoch 67/100
#
# Epoch 67: loss improved from 0.05395 to 0.05247, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0525 - val_loss: 0.0539
# Epoch 68/100
#
# Epoch 68: loss improved from 0.05247 to 0.05231, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.0523 - val_loss: 0.0527
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.05231
# 23/23 - 1s - 44ms/step - loss: 0.0540 - val_loss: 0.0534
# Epoch 70/100
#
# Epoch 70: loss improved from 0.05231 to 0.05136, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 46ms/step - loss: 0.0514 - val_loss: 0.0532
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.05136
# 23/23 - 1s - 43ms/step - loss: 0.0516 - val_loss: 0.0517
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.05136
# 23/23 - 1s - 44ms/step - loss: 0.0515 - val_loss: 0.0512
# Epoch 73/100
#
# Epoch 73: loss improved from 0.05136 to 0.05075, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0507 - val_loss: 0.0507
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.05075
# 23/23 - 1s - 46ms/step - loss: 0.0508 - val_loss: 0.0510
# Epoch 75/100
#
# Epoch 75: loss improved from 0.05075 to 0.04953, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 48ms/step - loss: 0.0495 - val_loss: 0.0505
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.04953
# 23/23 - 1s - 46ms/step - loss: 0.0500 - val_loss: 0.0502
# Epoch 77/100
#
# Epoch 77: loss improved from 0.04953 to 0.04868, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 50ms/step - loss: 0.0487 - val_loss: 0.0493
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.04868
# 23/23 - 1s - 54ms/step - loss: 0.0489 - val_loss: 0.0493
# Epoch 79/100
#
# Epoch 79: loss improved from 0.04868 to 0.04855, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0486 - val_loss: 0.0491
# Epoch 80/100
#
# Epoch 80: loss improved from 0.04855 to 0.04828, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 48ms/step - loss: 0.0483 - val_loss: 0.0492
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.04828
# 23/23 - 1s - 46ms/step - loss: 0.0495 - val_loss: 0.0484
# Epoch 82/100
#
# Epoch 82: loss improved from 0.04828 to 0.04805, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 47ms/step - loss: 0.0480 - val_loss: 0.0477
# Epoch 83/100
#
# Epoch 83: loss improved from 0.04805 to 0.04764, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 42ms/step - loss: 0.0476 - val_loss: 0.0474
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.04764
# 23/23 - 1s - 43ms/step - loss: 0.0491 - val_loss: 0.0474
# Epoch 85/100
#
# Epoch 85: loss improved from 0.04764 to 0.04662, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 50ms/step - loss: 0.0466 - val_loss: 0.0476
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.04662
# 23/23 - 1s - 42ms/step - loss: 0.0485 - val_loss: 0.0465
# Epoch 87/100
#
# Epoch 87: loss improved from 0.04662 to 0.04658, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0466 - val_loss: 0.0485
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.04658
# 23/23 - 1s - 42ms/step - loss: 0.0466 - val_loss: 0.0461
# Epoch 89/100
#
# Epoch 89: loss improved from 0.04658 to 0.04562, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0456 - val_loss: 0.0464
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.04562
# 23/23 - 1s - 44ms/step - loss: 0.0457 - val_loss: 0.0459
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.04562
# 23/23 - 1s - 43ms/step - loss: 0.0467 - val_loss: 0.0451
# Epoch 92/100
#
# Epoch 92: loss improved from 0.04562 to 0.04523, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 45ms/step - loss: 0.0452 - val_loss: 0.0451
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.04523
# 23/23 - 1s - 43ms/step - loss: 0.0456 - val_loss: 0.0459
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.04523
# 23/23 - 1s - 41ms/step - loss: 0.0465 - val_loss: 0.0466
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.04523
# 23/23 - 1s - 43ms/step - loss: 0.0465 - val_loss: 0.0445
# Epoch 96/100
#
# Epoch 96: loss improved from 0.04523 to 0.04426, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 44ms/step - loss: 0.0443 - val_loss: 0.0446
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.04426
# 23/23 - 1s - 42ms/step - loss: 0.0452 - val_loss: 0.0450
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.04426
# 23/23 - 1s - 45ms/step - loss: 0.0446 - val_loss: 0.0437
# Epoch 99/100
#
# Epoch 99: loss improved from 0.04426 to 0.04350, saving model to save_models/VPB_model.keras
# 23/23 - 1s - 43ms/step - loss: 0.0435 - val_loss: 0.0443
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.04350
# 23/23 - 1s - 44ms/step - loss: 0.0439 - val_loss: 0.0437
# Restoring model weights from the end of the best epoch: 99.

# %%
save_model_path = "models/VPB_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9903332622341702
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 0.8063966491677711
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.367985960657632
# RMSE trên tập train (VNĐ): 1.4362871084381952
# Độ chính xác trên tập train (%): 97.52577586832352
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9025374282416737
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.27276976834172784
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.3766846455054598
# RMSE trên tập test (VNĐ): 0.3576542634594856
# Độ chính xác trên tập test (%): 92.62568528949514
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
