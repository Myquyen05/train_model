# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['PLX']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[2], line 7
#       4 collection = db['PLX']
#       6 # Chuyển dữ liệu thành DataFrame
# ----> 7 df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
#       8 df
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1257, in Cursor.next(self)
#    1255 if self._empty:
#    1256     raise StopIteration
# -> 1257 if len(self._data) or self._refresh():
#    1258     return self._data.popleft()
#    1259 else:
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1205, in Cursor._refresh(self)
#    1183         raise InvalidOperation(
#    1184             "Passing a 'hint' is required when using the min/max query"
#    1185             " option to ensure the query utilizes the correct index"
#    1186         )
#    1187     q = self._query_class(
#    1188         self._query_flags,
#    1189         self._collection.database.name,
#    (...)
#    1203         self._exhaust,
#    1204     )
# -> 1205     self._send_message(q)
#    1206 elif self._id:  # Get More
#    1207     if self._limit:
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\cursor.py:1100, in Cursor._send_message(self, operation)
#    1097     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1099 try:
# -> 1100     response = client._run_operation(
#    1101         operation, self._unpack_response, address=self._address
#    1102     )
#    1103 except OperationFailure as exc:
#    1104     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1105         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:1754, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1744     operation.reset()  # Reset op in case of retry.
#    1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    (...)
#    1751         self,
#    1752     )
# -> 1754 return self._retryable_read(
#    1755     _cmd,
#    1756     operation.read_preference,
#    1757     operation.session,  # type: ignore[arg-type]
#    1758     address=address,
#    1759     retryable=isinstance(operation, _Query),
#    1760     operation=operation.name,
#    1761 )
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2689, in _ClientConnectionRetryable._read(self)
#    2684 def _read(self) -> T:
#    2685     """Wrapper method for read-type retryable client executions
#    2686
#    2687     :return: Output for func()'s call
#    2688     """
# -> 2689     self._server = self._get_server()
#    2690     assert self._read_pref is not None, "Read Preference required on read calls"
#    2691     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2692         conn,
#    2693         read_pref,
#    2694     ):
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:2645, in _ClientConnectionRetryable._get_server(self)
#    2640 def _get_server(self) -> Server:
#    2641     """Retrieves a server object based on provided object context
#    2642
#    2643     :return: Abstraction to connect to server
#    2644     """
# -> 2645     return self._client._select_server(
#    2646         self._server_selector,
#    2647         self._session,
#    2648         self._operation,
#    2649         address=self._address,
#    2650         deprioritized_servers=self._deprioritized_servers,
#    2651         operation_id=self._operation_id,
#    2652     )
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\mongo_client.py:1649, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1647             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1648     else:
# -> 1649         server = topology.select_server(
#    1650             server_selector,
#    1651             operation,
#    1652             deprioritized_servers=deprioritized_servers,
#    1653             operation_id=operation_id,
#    1654         )
#    1655     return server
#    1656 except PyMongoError as exc:
#    1657     # Server selection errors in a transaction are transient.
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:398, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     388 def select_server(
#     389     self,
#     390     selector: Callable[[Selection], Selection],
#    (...)
#     395     operation_id: Optional[int] = None,
#     396 ) -> Server:
#     397     """Like select_servers, but choose a random server if several match."""
# --> 398     server = self._select_server(
#     399         selector,
#     400         operation,
#     401         server_selection_timeout,
#     402         address,
#     403         deprioritized_servers,
#     404         operation_id=operation_id,
#     405     )
#     406     if _csot.get_timeout():
#     407         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:376, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     367 def _select_server(
#     368     self,
#     369     selector: Callable[[Selection], Selection],
#    (...)
#     374     operation_id: Optional[int] = None,
#     375 ) -> Server:
# --> 376     servers = self.select_servers(
#     377         selector, operation, server_selection_timeout, address, operation_id
#     378     )
#     379     servers = _filter_servers(servers, deprioritized_servers)
#     380     if len(servers) == 1:
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:283, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     280     server_timeout = server_selection_timeout
#     282 with self._lock:
# --> 283     server_descriptions = self._select_servers_loop(
#     284         selector, server_timeout, operation, operation_id, address
#     285     )
#     287     return [
#     288         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     289     ]
#
# File c:\Users\TRUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\synchronous\topology.py:333, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     322     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     323         _debug_log(
#     324             _SERVER_SELECTION_LOGGER,
#     325             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     331             failure=self._error_message(selector),
#     332         )
# --> 333     raise ServerSelectionTimeoutError(
#     334         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     335     )
#     337 if not logged_waiting:
#     338     _debug_log(
#     339         _SERVER_SELECTION_LOGGER,
#     340         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     346         remainingTimeMS=int(end_time - time.monotonic()),
#     347     )
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 67696f4d4dff29081d0dd6c3, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1919 entries, 0 to 1918
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               1919 non-null   object
#  1   GiaDieuChinh       1919 non-null   float64
#  2   GiaDongCua         1919 non-null   float64
#  3   KhoiLuongKhopLenh  1919 non-null   int64
#  4   GiaTriKhopLenh     1919 non-null   int64
#  5   KLThoaThuan        1919 non-null   int64
#  6   GtThoaThuan        1919 non-null   int64
#  7   GiaMoCua           1919 non-null   float64
#  8   GiaCaoNhat         1919 non-null   float64
#  9   GiaThapNhat        1919 non-null   float64
#  10  ThayDoi_GiaTri     1919 non-null   float64
#  11  ThayDoi_PhanTram   1919 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 180.0+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   1919.000000  1919.000000       1.919000e+03    1.919000e+03
# mean      44.118239    51.356696       1.146475e+06    5.912407e+10
# std        7.809566    12.341779       9.786208e+05    5.491804e+10
# min       23.310000    24.650000       1.986000e+04    1.122000e+09
# 25%       37.740000    40.300000       5.077100e+05    2.328300e+10
# 50%       45.280000    51.800000       8.633000e+05    4.329100e+10
# 75%       49.350000    60.100000       1.452550e+06    7.495900e+10
# max       70.560000    93.100000       7.387900e+06    4.233140e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  1.919000e+03  1.919000e+03  1919.000000  1919.000000  1919.000000
# mean   3.749165e+04  1.936182e+09    51.394320    52.062220    50.724101
# std    2.087065e+05  1.043566e+10    12.314174    12.525426    12.121529
# min    0.000000e+00  0.000000e+00    22.950000    25.750000    22.950000
# 25%    0.000000e+00  0.000000e+00    40.525000    41.000000    40.000000
# 50%    0.000000e+00  0.000000e+00    51.800000    52.800000    51.000000
# 75%    0.000000e+00  0.000000e+00    60.100000    60.900000    59.400000
# max    3.883940e+06  1.781952e+11    94.200000    95.500000    92.800000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     1919.000000       1919.000000
# mean         0.006498          0.030104
# std          1.057015          1.991731
# min         -6.100000         -9.370000
# 25%         -0.400000         -0.850000
# 50%          0.000000          0.000000
# 75%          0.400000          0.880000
# max          5.700000         13.190000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2017-04-21       48.90
# 2017-04-24       48.40
# 2017-04-25       45.15
# 2017-04-26       44.10
# 2017-04-27       45.90
# ...                ...
# 2024-12-16       38.70
# 2024-12-17       38.90
# 2024-12-18       39.30
# 2024-12-19       39.40
# 2024-12-20       39.00
#
# [1919 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[48.9 ],
#        [48.4 ],
#        [45.15],
#        ...,
#        [39.3 ],
#        [39.4 ],
#        [39.  ]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=64, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
    
    # Dropout giảm overfitting
    model.add(Dropout(0.4))
    
    # Lớp Dense đầu ra
    model.add(Dense(1))
    
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    
    return model

# Xác định input_shape
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh theo đầu vào thực tế
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/PLX_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=10, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.23994, saving model to save_models/PLX_model.keras
# 24/24 - 22s - 930ms/step - loss: 0.2399 - val_loss: 0.2289
# Epoch 2/100
#
# Epoch 2: loss improved from 0.23994 to 0.16019, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 67ms/step - loss: 0.1602 - val_loss: 0.1635
# Epoch 3/100
#
# Epoch 3: loss improved from 0.16019 to 0.13614, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 63ms/step - loss: 0.1361 - val_loss: 0.1222
# Epoch 4/100
#
# Epoch 4: loss improved from 0.13614 to 0.12776, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 74ms/step - loss: 0.1278 - val_loss: 0.1168
# Epoch 5/100
#
# Epoch 5: loss improved from 0.12776 to 0.11451, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 75ms/step - loss: 0.1145 - val_loss: 0.1128
# Epoch 6/100
#
# Epoch 6: loss improved from 0.11451 to 0.11149, saving model to save_models/PLX_model.keras
# 24/24 - 1s - 62ms/step - loss: 0.1115 - val_loss: 0.1008
# Epoch 7/100
#
# Epoch 7: loss improved from 0.11149 to 0.10331, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 74ms/step - loss: 0.1033 - val_loss: 0.1065
# Epoch 8/100
#
# Epoch 8: loss improved from 0.10331 to 0.09801, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 102ms/step - loss: 0.0980 - val_loss: 0.0890
# Epoch 9/100
#
# Epoch 9: loss improved from 0.09801 to 0.09432, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 77ms/step - loss: 0.0943 - val_loss: 0.0872
# Epoch 10/100
#
# Epoch 10: loss improved from 0.09432 to 0.09008, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 70ms/step - loss: 0.0901 - val_loss: 0.0980
# Epoch 11/100
#
# Epoch 11: loss improved from 0.09008 to 0.08489, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 72ms/step - loss: 0.0849 - val_loss: 0.0878
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.08489
# 24/24 - 2s - 69ms/step - loss: 0.0857 - val_loss: 0.0745
# Epoch 13/100
#
# Epoch 13: loss improved from 0.08489 to 0.08250, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 83ms/step - loss: 0.0825 - val_loss: 0.0728
# Epoch 14/100
#
# Epoch 14: loss improved from 0.08250 to 0.08015, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 88ms/step - loss: 0.0802 - val_loss: 0.0792
# Epoch 15/100
#
# Epoch 15: loss improved from 0.08015 to 0.07643, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 74ms/step - loss: 0.0764 - val_loss: 0.0669
# Epoch 16/100
#
# Epoch 16: loss improved from 0.07643 to 0.07354, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 75ms/step - loss: 0.0735 - val_loss: 0.0684
# Epoch 17/100
#
# Epoch 17: loss improved from 0.07354 to 0.07345, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 73ms/step - loss: 0.0735 - val_loss: 0.0670
# Epoch 18/100
#
# Epoch 18: loss improved from 0.07345 to 0.07291, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 78ms/step - loss: 0.0729 - val_loss: 0.0656
# Epoch 19/100
#
# Epoch 19: loss improved from 0.07291 to 0.07035, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 98ms/step - loss: 0.0703 - val_loss: 0.0717
# Epoch 20/100
#
# Epoch 20: loss improved from 0.07035 to 0.06848, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 74ms/step - loss: 0.0685 - val_loss: 0.0614
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.06848
# 24/24 - 2s - 66ms/step - loss: 0.0712 - val_loss: 0.0611
# Epoch 22/100
#
# Epoch 22: loss improved from 0.06848 to 0.06740, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 74ms/step - loss: 0.0674 - val_loss: 0.0579
# Epoch 23/100
#
# Epoch 23: loss improved from 0.06740 to 0.06653, saving model to save_models/PLX_model.keras
# 24/24 - 3s - 105ms/step - loss: 0.0665 - val_loss: 0.0565
# Epoch 24/100
#
# Epoch 24: loss improved from 0.06653 to 0.06436, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 73ms/step - loss: 0.0644 - val_loss: 0.0629
# Epoch 25/100
#
# Epoch 25: loss improved from 0.06436 to 0.06328, saving model to save_models/PLX_model.keras
# 24/24 - 3s - 106ms/step - loss: 0.0633 - val_loss: 0.0588
# Epoch 26/100
#
# Epoch 26: loss improved from 0.06328 to 0.06225, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 86ms/step - loss: 0.0622 - val_loss: 0.0560
# Epoch 27/100
#
# Epoch 27: loss improved from 0.06225 to 0.06126, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 76ms/step - loss: 0.0613 - val_loss: 0.0669
# Epoch 28/100
#
# Epoch 28: loss improved from 0.06126 to 0.06066, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 75ms/step - loss: 0.0607 - val_loss: 0.0547
# Epoch 29/100
#
# Epoch 29: loss improved from 0.06066 to 0.05923, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 82ms/step - loss: 0.0592 - val_loss: 0.0515
# Epoch 30/100
#
# Epoch 30: loss improved from 0.05923 to 0.05748, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 75ms/step - loss: 0.0575 - val_loss: 0.0562
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.05748
# 24/24 - 2s - 97ms/step - loss: 0.0580 - val_loss: 0.0562
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.05748
# 24/24 - 2s - 77ms/step - loss: 0.0593 - val_loss: 0.0544
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.05748
# 24/24 - 2s - 66ms/step - loss: 0.0582 - val_loss: 0.0514
# Epoch 34/100
#
# Epoch 34: loss improved from 0.05748 to 0.05675, saving model to save_models/PLX_model.keras
# 24/24 - 3s - 128ms/step - loss: 0.0568 - val_loss: 0.0499
# Epoch 35/100
#
# Epoch 35: loss improved from 0.05675 to 0.05567, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 72ms/step - loss: 0.0557 - val_loss: 0.0502
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.05567
# 24/24 - 2s - 70ms/step - loss: 0.0576 - val_loss: 0.0484
# Epoch 37/100
#
# Epoch 37: loss improved from 0.05567 to 0.05521, saving model to save_models/PLX_model.keras
# 24/24 - 1s - 55ms/step - loss: 0.0552 - val_loss: 0.0555
# Epoch 38/100
#
# Epoch 38: loss improved from 0.05521 to 0.05430, saving model to save_models/PLX_model.keras
# 24/24 - 3s - 114ms/step - loss: 0.0543 - val_loss: 0.0486
# Epoch 39/100
#
# Epoch 39: loss improved from 0.05430 to 0.05173, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 71ms/step - loss: 0.0517 - val_loss: 0.0486
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.05173
# 24/24 - 2s - 69ms/step - loss: 0.0523 - val_loss: 0.0509
# Epoch 41/100
#
# Epoch 41: loss improved from 0.05173 to 0.05172, saving model to save_models/PLX_model.keras
# 24/24 - 3s - 112ms/step - loss: 0.0517 - val_loss: 0.0458
# Epoch 42/100
#
# Epoch 42: loss improved from 0.05172 to 0.04980, saving model to save_models/PLX_model.keras
# 24/24 - 1s - 56ms/step - loss: 0.0498 - val_loss: 0.0484
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.04980
# 24/24 - 1s - 52ms/step - loss: 0.0500 - val_loss: 0.0506
# Epoch 44/100
#
# Epoch 44: loss improved from 0.04980 to 0.04960, saving model to save_models/PLX_model.keras
# 24/24 - 1s - 60ms/step - loss: 0.0496 - val_loss: 0.0459
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.04960
# 24/24 - 1s - 62ms/step - loss: 0.0502 - val_loss: 0.0473
# Epoch 46/100
#
# Epoch 46: loss improved from 0.04960 to 0.04882, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 81ms/step - loss: 0.0488 - val_loss: 0.0438
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.04882
# 24/24 - 2s - 69ms/step - loss: 0.0498 - val_loss: 0.0445
# Epoch 48/100
#
# Epoch 48: loss improved from 0.04882 to 0.04836, saving model to save_models/PLX_model.keras
# 24/24 - 3s - 123ms/step - loss: 0.0484 - val_loss: 0.0444
# Epoch 49/100
#
# Epoch 49: loss improved from 0.04836 to 0.04772, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 102ms/step - loss: 0.0477 - val_loss: 0.0436
# Epoch 50/100
#
# Epoch 50: loss improved from 0.04772 to 0.04585, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 73ms/step - loss: 0.0458 - val_loss: 0.0447
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.04585
# 24/24 - 2s - 65ms/step - loss: 0.0461 - val_loss: 0.0426
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.04585
# 24/24 - 3s - 116ms/step - loss: 0.0465 - val_loss: 0.0428
# Epoch 53/100
#
# Epoch 53: loss improved from 0.04585 to 0.04515, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 69ms/step - loss: 0.0451 - val_loss: 0.0471
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.04515
# 24/24 - 2s - 68ms/step - loss: 0.0453 - val_loss: 0.0417
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.04515
# 24/24 - 2s - 66ms/step - loss: 0.0452 - val_loss: 0.0415
# Epoch 56/100
#
# Epoch 56: loss improved from 0.04515 to 0.04448, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 66ms/step - loss: 0.0445 - val_loss: 0.0481
# Epoch 57/100
#
# Epoch 57: loss improved from 0.04448 to 0.04320, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 79ms/step - loss: 0.0432 - val_loss: 0.0435
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.04320
# 24/24 - 2s - 66ms/step - loss: 0.0450 - val_loss: 0.0417
# Epoch 59/100
#
# Epoch 59: loss improved from 0.04320 to 0.04290, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 76ms/step - loss: 0.0429 - val_loss: 0.0400
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.04290
# 24/24 - 2s - 99ms/step - loss: 0.0439 - val_loss: 0.0471
# Epoch 61/100
#
# Epoch 61: loss improved from 0.04290 to 0.04238, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 80ms/step - loss: 0.0424 - val_loss: 0.0432
# Epoch 62/100
#
# Epoch 62: loss improved from 0.04238 to 0.04105, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 71ms/step - loss: 0.0411 - val_loss: 0.0393
# Epoch 63/100
#
# Epoch 63: loss improved from 0.04105 to 0.04011, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 67ms/step - loss: 0.0401 - val_loss: 0.0483
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.04011
# 24/24 - 3s - 106ms/step - loss: 0.0402 - val_loss: 0.0405
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.04011
# 24/24 - 2s - 64ms/step - loss: 0.0410 - val_loss: 0.0392
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.04011
# 24/24 - 2s - 63ms/step - loss: 0.0414 - val_loss: 0.0395
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.04011
# 24/24 - 2s - 68ms/step - loss: 0.0402 - val_loss: 0.0471
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.04011
# 24/24 - 2s - 72ms/step - loss: 0.0413 - val_loss: 0.0420
# Epoch 69/100
#
# Epoch 69: loss improved from 0.04011 to 0.03925, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 77ms/step - loss: 0.0393 - val_loss: 0.0422
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.03925
# 24/24 - 1s - 56ms/step - loss: 0.0400 - val_loss: 0.0381
# Epoch 71/100
#
# Epoch 71: loss improved from 0.03925 to 0.03909, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 77ms/step - loss: 0.0391 - val_loss: 0.0463
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.03909
# 24/24 - 2s - 67ms/step - loss: 0.0395 - val_loss: 0.0370
# Epoch 73/100
#
# Epoch 73: loss improved from 0.03909 to 0.03893, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 74ms/step - loss: 0.0389 - val_loss: 0.0435
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.03893
# 24/24 - 2s - 72ms/step - loss: 0.0392 - val_loss: 0.0385
# Epoch 75/100
#
# Epoch 75: loss improved from 0.03893 to 0.03672, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 71ms/step - loss: 0.0367 - val_loss: 0.0388
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.03672
# 24/24 - 1s - 61ms/step - loss: 0.0378 - val_loss: 0.0372
# Epoch 77/100
#
# Epoch 77: loss improved from 0.03672 to 0.03647, saving model to save_models/PLX_model.keras
# 24/24 - 1s - 57ms/step - loss: 0.0365 - val_loss: 0.0377
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.03647
# 24/24 - 1s - 51ms/step - loss: 0.0370 - val_loss: 0.0366
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.03647
# 24/24 - 1s - 55ms/step - loss: 0.0376 - val_loss: 0.0358
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.03647
# 24/24 - 1s - 58ms/step - loss: 0.0379 - val_loss: 0.0356
# Epoch 81/100
#
# Epoch 81: loss improved from 0.03647 to 0.03556, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 71ms/step - loss: 0.0356 - val_loss: 0.0358
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.03556
# 24/24 - 2s - 76ms/step - loss: 0.0362 - val_loss: 0.0356
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.03556
# 24/24 - 1s - 61ms/step - loss: 0.0363 - val_loss: 0.0420
# Epoch 84/100
#
# Epoch 84: loss improved from 0.03556 to 0.03541, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 75ms/step - loss: 0.0354 - val_loss: 0.0360
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.03541
# 24/24 - 2s - 69ms/step - loss: 0.0354 - val_loss: 0.0349
# Epoch 86/100
#
# Epoch 86: loss improved from 0.03541 to 0.03489, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 71ms/step - loss: 0.0349 - val_loss: 0.0350
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.03489
# 24/24 - 2s - 70ms/step - loss: 0.0360 - val_loss: 0.0379
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.03489
# 24/24 - 2s - 73ms/step - loss: 0.0364 - val_loss: 0.0360
# Epoch 89/100
#
# Epoch 89: loss improved from 0.03489 to 0.03418, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 77ms/step - loss: 0.0342 - val_loss: 0.0352
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.03418
# 24/24 - 1s - 62ms/step - loss: 0.0344 - val_loss: 0.0354
# Epoch 91/100
#
# Epoch 91: loss improved from 0.03418 to 0.03398, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 72ms/step - loss: 0.0340 - val_loss: 0.0343
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.03398
# 24/24 - 2s - 67ms/step - loss: 0.0343 - val_loss: 0.0358
# Epoch 93/100
#
# Epoch 93: loss improved from 0.03398 to 0.03295, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 72ms/step - loss: 0.0329 - val_loss: 0.0392
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.03295
# 24/24 - 2s - 68ms/step - loss: 0.0330 - val_loss: 0.0340
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.03295
# 24/24 - 2s - 69ms/step - loss: 0.0331 - val_loss: 0.0347
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.03295
# 24/24 - 2s - 69ms/step - loss: 0.0344 - val_loss: 0.0383
# Epoch 97/100
#
# Epoch 97: loss improved from 0.03295 to 0.03280, saving model to save_models/PLX_model.keras
# 24/24 - 2s - 77ms/step - loss: 0.0328 - val_loss: 0.0350
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.03280
# 24/24 - 2s - 99ms/step - loss: 0.0329 - val_loss: 0.0340
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.03280
# 24/24 - 2s - 68ms/step - loss: 0.0340 - val_loss: 0.0400
# Epoch 100/100
#
# Epoch 100: loss improved from 0.03280 to 0.03207, saving model to save_models/PLX_model.keras
# 24/24 - 3s - 106ms/step - loss: 0.0321 - val_loss: 0.0333
# Restoring model weights from the end of the best epoch: 100.

# %%
# Hàm xây dựng mô hình
def build_model():
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(units=64))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# Huấn luyện mô hình
model = build_model()
save_model_path = f"save_models/{collection}_model.keras"
best_model = ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.01953, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 9s - 127ms/step - loss: 0.0195
# Epoch 2/100
#
# Epoch 2: loss improved from 0.01953 to 0.01390, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 67ms/step - loss: 0.0139
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01390 to 0.01147, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 69ms/step - loss: 0.0115
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.01147
# 72/72 - 5s - 64ms/step - loss: 0.0124
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01147 to 0.01087, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0109
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01087 to 0.01084, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 64ms/step - loss: 0.0108
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.01084
# 72/72 - 5s - 66ms/step - loss: 0.0114
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.01084
# 72/72 - 5s - 68ms/step - loss: 0.0109
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01084 to 0.01023, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0102
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01023 to 0.00967, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 68ms/step - loss: 0.0097
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00967
# 72/72 - 5s - 66ms/step - loss: 0.0104
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00967
# 72/72 - 5s - 69ms/step - loss: 0.0098
# Epoch 13/100
#
# Epoch 13: loss improved from 0.00967 to 0.00954, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 65ms/step - loss: 0.0095
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00954
# 72/72 - 4s - 62ms/step - loss: 0.0099
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.00954
# 72/72 - 5s - 64ms/step - loss: 0.0098
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.00954
# 72/72 - 5s - 63ms/step - loss: 0.0100
# Epoch 17/100
#
# Epoch 17: loss improved from 0.00954 to 0.00887, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00887
# 72/72 - 4s - 57ms/step - loss: 0.0096
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0095
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0102
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00887
# 72/72 - 4s - 58ms/step - loss: 0.0138
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00887
# 72/72 - 4s - 59ms/step - loss: 0.0094
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00887
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0089
# Epoch 28/100
#
# Epoch 28: loss improved from 0.00887 to 0.00879, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00879 to 0.00859, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00859
# 72/72 - 5s - 75ms/step - loss: 0.0094
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00859
# 72/72 - 4s - 58ms/step - loss: 0.0090
# Epoch 32/100
#
# Epoch 32: loss improved from 0.00859 to 0.00851, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0114
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0091
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0091
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00851
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00851
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0089
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 41/100
#
# Epoch 41: loss improved from 0.00851 to 0.00840, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00840 to 0.00836, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00836
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00836
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 45/100
#
# Epoch 45: loss improved from 0.00836 to 0.00829, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0083
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00829
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00829 to 0.00812, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0086
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0082
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00812
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0093
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00812
# 72/72 - 5s - 63ms/step - loss: 0.0083
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00812 to 0.00806, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00806
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00806 to 0.00791, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0084
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0079
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0108
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0091
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0081
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0085
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00791
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0086
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0081
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00791 to 0.00789, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0079
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0112
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0094
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00789
# 72/72 - 4s - 59ms/step - loss: 0.0095
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00789
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00789
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0080
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 89/100
#
# Epoch 89: loss improved from 0.00789 to 0.00785, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0079
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00785 to 0.00780, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0078
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0080
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0083
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00780
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00780
# 72/72 - 5s - 63ms/step - loss: 0.0084
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00780 to 0.00772, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0077

# %%
save_model_path = "models/PLX_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9754622858863147
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 1.334679505062424
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.5331495629967944
# RMSE trên tập train (VNĐ): 1.8730243539928826
# Độ chính xác trên tập train (%): 97.26366054931646
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score1
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9356035285422853
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.8075382053852082
# Phần trăm sai số tuyệt đối trung bình trên tập test: 2.0509460746589396
# RMSE trên tập test (VNĐ): 1.082049062053357
# Độ chính xác trên tập test (%): 94.2136413793938
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
