# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['VJC']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2017-03-01         64.92       115.5              99100     11446000000
# 1     2017-03-02         69.42       123.5             190550     23533000000
# 2     2017-03-08         73.07       130.0             916200    118512000000
# 3     2017-03-17         66.04       117.5             496260     57500000000
# 4     2017-03-23         70.82       126.0             402040     50630000000
# ...          ...           ...         ...                ...             ...
# 1951  2024-12-17        101.60       101.6             671400     68067000000
# 1952  2024-12-13        102.40       102.4             575200     58837000000
# 1953  2024-12-18        100.70       100.7             605900     61117000000
# 1954  2024-12-19        100.00       100.0            1135400    112721000000
# 1955  2024-12-20         99.20        99.2            1007700    100478000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0          511570  52162785000     115.5       115.5        115.5
# 1          140000  17290000000     123.5       123.5        123.5
# 2               0            0     130.1       132.5        126.5
# 3           22000   2384800000     115.6       121.0        113.0
# 4          181603  22869265790     125.0       127.5        124.7
# ...           ...          ...       ...         ...          ...
# 1951       588000  60135200000     102.0       102.2        100.8
# 1952            0            0     102.8       102.8        101.8
# 1953       398000  40564160000     101.4       101.4        100.5
# 1954        86000   8643000000     100.5       100.5         98.0
# 1955            0            0     100.0       100.9         99.2
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0                7.5              6.94
# 1                0.0              0.00
# 2               -2.5             -1.89
# 3                0.0              0.00
# 4                0.0              0.00
# ...              ...               ...
# 1951            -0.4             -0.39
# 1952            -0.5             -0.49
# 1953            -0.9             -0.89
# 1954            -0.7             -0.70
# 1955            -0.8             -0.80
#
# [1956 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1956 entries, 0 to 1955
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               1956 non-null   object
#  1   GiaDieuChinh       1956 non-null   float64
#  2   GiaDongCua         1956 non-null   float64
#  3   KhoiLuongKhopLenh  1956 non-null   int64
#  4   GiaTriKhopLenh     1956 non-null   int64
#  5   KLThoaThuan        1956 non-null   int64
#  6   GtThoaThuan        1956 non-null   int64
#  7   GiaMoCua           1956 non-null   float64
#  8   GiaCaoNhat         1956 non-null   float64
#  9   GiaThapNhat        1956 non-null   float64
#  10  ThayDoi_GiaTri     1956 non-null   float64
#  11  ThayDoi_PhanTram   1956 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 183.5+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   1956.000000  1956.000000       1.956000e+03    1.956000e+03
# mean     115.722935   122.943814       6.481172e+05    8.031758e+10
# std       20.844358    22.232769       3.233689e+05    4.577526e+10
# min       60.700000    93.800000       1.203000e+04    1.299000e+09
# 25%      103.000000   105.700000       4.183000e+05    5.199650e+10
# 50%      114.900000   120.700000       6.137750e+05    7.244150e+10
# 75%      129.425000   131.125000       8.077000e+05    9.722275e+10
# max      184.840000   228.100000       3.731860e+06    5.151270e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  1.956000e+03  1.956000e+03  1956.000000  1956.000000  1956.000000
# mean   2.162631e+05  2.669407e+10   122.888701   124.001534   121.421166
# std    6.054119e+05  7.771078e+10    22.237356    22.695325    21.809653
# min    0.000000e+00  0.000000e+00    93.800000    94.000000    92.900000
# 25%    0.000000e+00  0.000000e+00   105.700000   106.200000   104.500000
# 50%    0.000000e+00  0.000000e+00   120.500000   121.650000   119.450000
# 75%    7.749750e+04  9.221459e+09   131.200000   132.000000   129.800000
# max    5.958000e+06  1.019910e+12   228.100000   229.400000   224.200000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count      1956.00000       1956.000000
# mean          0.05887          0.051564
# std           1.91173          1.453529
# min         -12.90000         -7.000000
# 25%          -0.50000         -0.452500
# 50%           0.00000          0.000000
# 75%           0.50000          0.430000
# max          12.20000          7.000000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2017-02-28       108.0
# 2017-03-01       115.5
# 2017-03-02       123.5
# 2017-03-03       132.1
# 2017-03-06       137.4
# ...                ...
# 2024-12-16       102.0
# 2024-12-17       101.6
# 2024-12-18       100.7
# 2024-12-19       100.0
# 2024-12-20        99.2
#
# [1956 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[108. ],
#        [115.5],
#        [123.5],
#        ...,
#        [100.7],
#        [100. ],
#        [ 99.2]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # Giảm số đơn vị trong LSTM và tăng regularization
    model.add(LSTM(units=64, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.4))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001))
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/VJC_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=15, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.18351, saving model to save_models/VJC_model.keras
# 24/24 - 5s - 216ms/step - loss: 0.1835 - val_loss: 0.1374
# Epoch 2/100
#
# Epoch 2: loss improved from 0.18351 to 0.11037, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 50ms/step - loss: 0.1104 - val_loss: 0.1118
# Epoch 3/100
#
# Epoch 3: loss improved from 0.11037 to 0.09050, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 45ms/step - loss: 0.0905 - val_loss: 0.0942
# Epoch 4/100
#
# Epoch 4: loss improved from 0.09050 to 0.07761, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 48ms/step - loss: 0.0776 - val_loss: 0.0850
# Epoch 5/100
#
# Epoch 5: loss improved from 0.07761 to 0.06988, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 51ms/step - loss: 0.0699 - val_loss: 0.0884
# Epoch 6/100
#
# Epoch 6: loss improved from 0.06988 to 0.06446, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 54ms/step - loss: 0.0645 - val_loss: 0.0704
# Epoch 7/100
#
# Epoch 7: loss improved from 0.06446 to 0.05914, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 50ms/step - loss: 0.0591 - val_loss: 0.0777
# Epoch 8/100
#
# Epoch 8: loss improved from 0.05914 to 0.05677, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 51ms/step - loss: 0.0568 - val_loss: 0.0694
# Epoch 9/100
#
# Epoch 9: loss improved from 0.05677 to 0.05269, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 47ms/step - loss: 0.0527 - val_loss: 0.0591
# Epoch 10/100
#
# Epoch 10: loss improved from 0.05269 to 0.05109, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 60ms/step - loss: 0.0511 - val_loss: 0.0581
# Epoch 11/100
#
# Epoch 11: loss improved from 0.05109 to 0.04903, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 55ms/step - loss: 0.0490 - val_loss: 0.0560
# Epoch 12/100
#
# Epoch 12: loss improved from 0.04903 to 0.04729, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0473 - val_loss: 0.0656
# Epoch 13/100
#
# Epoch 13: loss improved from 0.04729 to 0.04474, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 49ms/step - loss: 0.0447 - val_loss: 0.0591
# Epoch 14/100
#
# Epoch 14: loss improved from 0.04474 to 0.04255, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 54ms/step - loss: 0.0425 - val_loss: 0.0554
# Epoch 15/100
#
# Epoch 15: loss improved from 0.04255 to 0.04253, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0425 - val_loss: 0.0505
# Epoch 16/100
#
# Epoch 16: loss improved from 0.04253 to 0.04083, saving model to save_models/VJC_model.keras
# 24/24 - 3s - 112ms/step - loss: 0.0408 - val_loss: 0.0500
# Epoch 17/100
#
# Epoch 17: loss improved from 0.04083 to 0.04083, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 52ms/step - loss: 0.0408 - val_loss: 0.0520
# Epoch 18/100
#
# Epoch 18: loss improved from 0.04083 to 0.03982, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0398 - val_loss: 0.0490
# Epoch 19/100
#
# Epoch 19: loss improved from 0.03982 to 0.03979, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 54ms/step - loss: 0.0398 - val_loss: 0.0539
# Epoch 20/100
#
# Epoch 20: loss improved from 0.03979 to 0.03792, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0379 - val_loss: 0.0513
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.03792
# 24/24 - 1s - 48ms/step - loss: 0.0379 - val_loss: 0.0436
# Epoch 22/100
#
# Epoch 22: loss improved from 0.03792 to 0.03688, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 55ms/step - loss: 0.0369 - val_loss: 0.0442
# Epoch 23/100
#
# Epoch 23: loss improved from 0.03688 to 0.03499, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 51ms/step - loss: 0.0350 - val_loss: 0.0483
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.03499
# 24/24 - 1s - 49ms/step - loss: 0.0367 - val_loss: 0.0471
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.03499
# 24/24 - 1s - 49ms/step - loss: 0.0354 - val_loss: 0.0432
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.03499
# 24/24 - 1s - 54ms/step - loss: 0.0357 - val_loss: 0.0420
# Epoch 27/100
#
# Epoch 27: loss improved from 0.03499 to 0.03318, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 54ms/step - loss: 0.0332 - val_loss: 0.0406
# Epoch 28/100
#
# Epoch 28: loss improved from 0.03318 to 0.03318, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 52ms/step - loss: 0.0332 - val_loss: 0.0408
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.03318
# 24/24 - 1s - 51ms/step - loss: 0.0334 - val_loss: 0.0421
# Epoch 30/100
#
# Epoch 30: loss improved from 0.03318 to 0.03295, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 55ms/step - loss: 0.0329 - val_loss: 0.0386
# Epoch 31/100
#
# Epoch 31: loss improved from 0.03295 to 0.03166, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 54ms/step - loss: 0.0317 - val_loss: 0.0393
# Epoch 32/100
#
# Epoch 32: loss improved from 0.03166 to 0.03106, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 50ms/step - loss: 0.0311 - val_loss: 0.0366
# Epoch 33/100
#
# Epoch 33: loss improved from 0.03106 to 0.03056, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 43ms/step - loss: 0.0306 - val_loss: 0.0361
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.03056
# 24/24 - 1s - 50ms/step - loss: 0.0318 - val_loss: 0.0356
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.03056
# 24/24 - 1s - 47ms/step - loss: 0.0307 - val_loss: 0.0370
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.03056
# 24/24 - 1s - 47ms/step - loss: 0.0312 - val_loss: 0.0378
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.03056
# 24/24 - 1s - 49ms/step - loss: 0.0306 - val_loss: 0.0422
# Epoch 38/100
#
# Epoch 38: loss improved from 0.03056 to 0.03030, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 52ms/step - loss: 0.0303 - val_loss: 0.0399
# Epoch 39/100
#
# Epoch 39: loss improved from 0.03030 to 0.02868, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 54ms/step - loss: 0.0287 - val_loss: 0.0361
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.02868
# 24/24 - 1s - 50ms/step - loss: 0.0298 - val_loss: 0.0372
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.02868
# 24/24 - 1s - 49ms/step - loss: 0.0292 - val_loss: 0.0332
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.02868
# 24/24 - 1s - 49ms/step - loss: 0.0288 - val_loss: 0.0354
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.02868
# 24/24 - 1s - 49ms/step - loss: 0.0289 - val_loss: 0.0321
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.02868
# 24/24 - 1s - 49ms/step - loss: 0.0287 - val_loss: 0.0343
# Epoch 45/100
#
# Epoch 45: loss improved from 0.02868 to 0.02858, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0286 - val_loss: 0.0326
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.02858
# 24/24 - 1s - 56ms/step - loss: 0.0296 - val_loss: 0.0439
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.02858
# 24/24 - 1s - 49ms/step - loss: 0.0298 - val_loss: 0.0410
# Epoch 48/100
#
# Epoch 48: loss improved from 0.02858 to 0.02788, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 50ms/step - loss: 0.0279 - val_loss: 0.0334
# Epoch 49/100
#
# Epoch 49: loss improved from 0.02788 to 0.02762, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 45ms/step - loss: 0.0276 - val_loss: 0.0327
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.02762
# 24/24 - 1s - 48ms/step - loss: 0.0277 - val_loss: 0.0349
# Epoch 51/100
#
# Epoch 51: loss improved from 0.02762 to 0.02761, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 52ms/step - loss: 0.0276 - val_loss: 0.0375
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.02761
# 24/24 - 1s - 48ms/step - loss: 0.0277 - val_loss: 0.0319
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.02761
# 24/24 - 1s - 48ms/step - loss: 0.0278 - val_loss: 0.0379
# Epoch 54/100
#
# Epoch 54: loss improved from 0.02761 to 0.02725, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 56ms/step - loss: 0.0273 - val_loss: 0.0307
# Epoch 55/100
#
# Epoch 55: loss improved from 0.02725 to 0.02699, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 50ms/step - loss: 0.0270 - val_loss: 0.0304
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.02699
# 24/24 - 1s - 48ms/step - loss: 0.0273 - val_loss: 0.0311
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.02699
# 24/24 - 1s - 49ms/step - loss: 0.0273 - val_loss: 0.0303
# Epoch 58/100
#
# Epoch 58: loss improved from 0.02699 to 0.02662, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 49ms/step - loss: 0.0266 - val_loss: 0.0304
# Epoch 59/100
#
# Epoch 59: loss improved from 0.02662 to 0.02649, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 55ms/step - loss: 0.0265 - val_loss: 0.0314
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.02649
# 24/24 - 1s - 50ms/step - loss: 0.0266 - val_loss: 0.0300
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.02649
# 24/24 - 1s - 48ms/step - loss: 0.0268 - val_loss: 0.0351
# Epoch 62/100
#
# Epoch 62: loss improved from 0.02649 to 0.02648, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 61ms/step - loss: 0.0265 - val_loss: 0.0328
# Epoch 63/100
#
# Epoch 63: loss improved from 0.02648 to 0.02639, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0264 - val_loss: 0.0298
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.02639
# 24/24 - 1s - 49ms/step - loss: 0.0274 - val_loss: 0.0308
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.02639
# 24/24 - 1s - 51ms/step - loss: 0.0269 - val_loss: 0.0309
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.02639
# 24/24 - 1s - 50ms/step - loss: 0.0265 - val_loss: 0.0297
# Epoch 67/100
#
# Epoch 67: loss improved from 0.02639 to 0.02557, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 56ms/step - loss: 0.0256 - val_loss: 0.0289
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.02557
# 24/24 - 1s - 50ms/step - loss: 0.0269 - val_loss: 0.0325
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.02557
# 24/24 - 1s - 49ms/step - loss: 0.0268 - val_loss: 0.0310
# Epoch 70/100
#
# Epoch 70: loss improved from 0.02557 to 0.02531, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0253 - val_loss: 0.0316
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02531
# 24/24 - 1s - 51ms/step - loss: 0.0262 - val_loss: 0.0305
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.02531
# 24/24 - 1s - 50ms/step - loss: 0.0275 - val_loss: 0.0283
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.02531
# 24/24 - 1s - 55ms/step - loss: 0.0258 - val_loss: 0.0281
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.02531
# 24/24 - 1s - 51ms/step - loss: 0.0262 - val_loss: 0.0310
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.02531
# 24/24 - 1s - 50ms/step - loss: 0.0267 - val_loss: 0.0289
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02531
# 24/24 - 1s - 49ms/step - loss: 0.0253 - val_loss: 0.0319
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.02531
# 24/24 - 1s - 50ms/step - loss: 0.0260 - val_loss: 0.0295
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.02531
# 24/24 - 1s - 50ms/step - loss: 0.0260 - val_loss: 0.0297
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.02531
# 24/24 - 1s - 51ms/step - loss: 0.0257 - val_loss: 0.0283
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.02531
# 24/24 - 1s - 55ms/step - loss: 0.0260 - val_loss: 0.0273
# Epoch 81/100
#
# Epoch 81: loss improved from 0.02531 to 0.02461, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0246 - val_loss: 0.0315
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.02461
# 24/24 - 1s - 48ms/step - loss: 0.0259 - val_loss: 0.0406
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.02461
# 24/24 - 1s - 48ms/step - loss: 0.0251 - val_loss: 0.0297
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.02461
# 24/24 - 1s - 50ms/step - loss: 0.0250 - val_loss: 0.0268
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.02461
# 24/24 - 1s - 48ms/step - loss: 0.0259 - val_loss: 0.0270
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.02461
# 24/24 - 1s - 52ms/step - loss: 0.0256 - val_loss: 0.0266
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.02461
# 24/24 - 1s - 51ms/step - loss: 0.0247 - val_loss: 0.0287
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.02461
# 24/24 - 1s - 49ms/step - loss: 0.0259 - val_loss: 0.0261
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.02461
# 24/24 - 1s - 49ms/step - loss: 0.0246 - val_loss: 0.0295
# Epoch 90/100
#
# Epoch 90: loss improved from 0.02461 to 0.02452, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 53ms/step - loss: 0.0245 - val_loss: 0.0334
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.02452
# 24/24 - 1s - 48ms/step - loss: 0.0246 - val_loss: 0.0265
# Epoch 92/100
#
# Epoch 92: loss improved from 0.02452 to 0.02407, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 56ms/step - loss: 0.0241 - val_loss: 0.0275
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.02407
# 24/24 - 1s - 49ms/step - loss: 0.0245 - val_loss: 0.0319
# Epoch 94/100
#
# Epoch 94: loss improved from 0.02407 to 0.02384, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 51ms/step - loss: 0.0238 - val_loss: 0.0258
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.02384
# 24/24 - 1s - 57ms/step - loss: 0.0246 - val_loss: 0.0262
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.02384
# 24/24 - 1s - 52ms/step - loss: 0.0246 - val_loss: 0.0258
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.02384
# 24/24 - 1s - 49ms/step - loss: 0.0249 - val_loss: 0.0268
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.02384
# 24/24 - 1s - 50ms/step - loss: 0.0248 - val_loss: 0.0280
# Epoch 99/100
#
# Epoch 99: loss improved from 0.02384 to 0.02370, saving model to save_models/VJC_model.keras
# 24/24 - 1s - 54ms/step - loss: 0.0237 - val_loss: 0.0298
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.02370
# 24/24 - 1s - 51ms/step - loss: 0.0247 - val_loss: 0.0266
# Restoring model weights from the end of the best epoch: 99.

# %%
save_model_path = "models/VJC_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9766755835669119
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 2.189181779586812
# Phần trăm sai số tuyệt đối trung bình trên tập train: 1.660530386557955
# RMSE trên tập train (VNĐ): 3.4353739351019437
# Độ chính xác trên tập train (%): 97.4286123240255
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.7420749107145399
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.8863053574854016
# Phần trăm sai số tuyệt đối trung bình trên tập test: 1.8400869464789489
# RMSE trên tập test (VNĐ): 2.211692844453733
# Độ chính xác trên tập test (%): 91.15322862218507
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
