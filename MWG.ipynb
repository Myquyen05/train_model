# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['MWG']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2014-07-22          8.82       109.0             568890     61431000000
# 1     2014-07-23          8.82       109.0              23330      2550000000
# 2     2014-08-06          8.65       107.0              20800      2185000000
# 3     2014-08-13         10.03       124.0             147010     17690000000
# 4     2014-08-27         11.08       137.0              11450      1570440000
# ...          ...           ...         ...                ...             ...
# 2606  2024-12-17         60.30        60.3            3676200    222299000000
# 2607  2024-12-13         61.00        61.0            5596800    337974000000
# 2608  2024-12-18         60.20        60.2            4076200    244954000000
# 2609  2024-12-19         59.80        59.8            7103100    423511000000
# 2610  2024-12-20         60.60        60.6            3751400    225934000000
#
#       KLThoaThuan  GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0            0     104.0       109.0        104.0
# 1               0            0     110.0       110.0        108.0
# 2               0            0     104.0       107.0        104.0
# 3               0            0     119.0       125.0        117.0
# 4           20000   2800000000     138.0       140.0        135.0
# ...           ...          ...       ...         ...          ...
# 2606       465600  28141480000      61.0        61.0         60.2
# 2607       237000  14314400000      59.8        61.3         59.6
# 2608       846000  51200640000      60.2        60.5         59.9
# 2609       483000  29311460000      59.8        59.9         59.4
# 2610            0            0      60.0        60.8         59.6
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0                0.0              0.00
# 1                0.0              0.00
# 2                0.0              0.00
# 3                0.0              0.00
# 4                0.0              0.00
# ...              ...               ...
# 2606            -0.7             -1.15
# 2607             0.0              0.00
# 2608            -0.1             -0.17
# 2609            -0.4             -0.66
# 2610             0.8              1.34
#
# [2611 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2611 entries, 0 to 2610
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               2611 non-null   object
#  1   GiaDieuChinh       2611 non-null   float64
#  2   GiaDongCua         2611 non-null   float64
#  3   KhoiLuongKhopLenh  2611 non-null   int64
#  4   GiaTriKhopLenh     2611 non-null   int64
#  5   KLThoaThuan        2611 non-null   int64
#  6   GtThoaThuan        2611 non-null   int64
#  7   GiaMoCua           2611 non-null   float64
#  8   GiaCaoNhat         2611 non-null   float64
#  9   GiaThapNhat        2611 non-null   float64
#  10  ThayDoi_GiaTri     2611 non-null   float64
#  11  ThayDoi_PhanTram   2611 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 244.9+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   2611.000000  2611.000000       2.611000e+03    2.611000e+03
# mean      42.498399    98.926216       1.985096e+06    1.356950e+11
# std       18.779299    36.035290       3.285104e+06    1.778879e+11
# min        6.590000    35.100000       8.600000e+02    1.010000e+08
# 25%       29.155000    69.650000       2.280800e+05    2.556450e+10
# 50%       42.260000   102.100000       6.847000e+05    7.179900e+10
# 75%       57.800000   127.550000       1.826860e+06    1.661550e+11
# max       87.030000   183.400000       2.961670e+07    1.653604e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  2.611000e+03  2.611000e+03  2611.000000  2611.000000  2611.000000
# mean   3.326291e+05  2.652231e+10    98.848851   100.123190    97.620050
# std    9.038609e+05  8.070266e+10    35.964811    36.414385    35.587265
# min    0.000000e+00  0.000000e+00    35.250000    37.400000    33.600000
# 25%    0.000000e+00  0.000000e+00    69.700000    70.200000    68.500000
# 50%    0.000000e+00  0.000000e+00   102.000000   103.400000   101.000000
# 75%    2.200780e+05  1.949504e+10   127.500000   129.000000   126.000000
# max    1.227500e+07  1.525310e+12   183.500000   184.000000   180.300000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     2611.000000       2611.000000
# mean         0.070126          0.079219
# std          2.082046          1.976749
# min        -53.900000        -32.770000
# 25%         -0.500000         -0.550000
# 50%          0.000000          0.000000
# 75%          0.500000          0.650000
# max         13.500000         19.850000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2014-07-14        81.5
# 2014-07-15        87.0
# 2014-07-16        93.0
# 2014-07-17        99.5
# 2014-07-18       106.0
# ...                ...
# 2024-12-16        61.0
# 2024-12-17        60.3
# 2024-12-18        60.2
# 2024-12-19        59.8
# 2024-12-20        60.6
#
# [2611 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[81.5],
#        [87. ],
#        [93. ],
#        ...,
#        [60.2],
#        [59.8],
#        [60.6]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    # LSTM đầu tiên
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, kernel_regularizer=l2(0.001)))
    # LSTM thứ hai (giảm số neuron)
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    # Dropout
    model.add(Dropout(0.4))
    # Lớp Dense đầu ra
    model.add(Dense(1))
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0005))
    return model

# Xây dựng và huấn luyện
input_shape = (x_train.shape[1], x_train.shape[2])
model = build_model(input_shape)

callbacks = [
    ModelCheckpoint("save_models/MWG_model.keras", monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=10, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.31136, saving model to save_models/MWG_model.keras
# 32/32 - 10s - 322ms/step - loss: 0.3114 - val_loss: 0.1840
# Epoch 2/100
#
# Epoch 2: loss improved from 0.31136 to 0.19519, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 98ms/step - loss: 0.1952 - val_loss: 0.1482
# Epoch 3/100
#
# Epoch 3: loss improved from 0.19519 to 0.16333, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 108ms/step - loss: 0.1633 - val_loss: 0.1232
# Epoch 4/100
#
# Epoch 4: loss improved from 0.16333 to 0.14082, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 115ms/step - loss: 0.1408 - val_loss: 0.1050
# Epoch 5/100
#
# Epoch 5: loss improved from 0.14082 to 0.12406, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 113ms/step - loss: 0.1241 - val_loss: 0.0973
# Epoch 6/100
#
# Epoch 6: loss improved from 0.12406 to 0.11392, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 134ms/step - loss: 0.1139 - val_loss: 0.0871
# Epoch 7/100
#
# Epoch 7: loss improved from 0.11392 to 0.10202, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 111ms/step - loss: 0.1020 - val_loss: 0.0736
# Epoch 8/100
#
# Epoch 8: loss improved from 0.10202 to 0.09749, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 106ms/step - loss: 0.0975 - val_loss: 0.0730
# Epoch 9/100
#
# Epoch 9: loss improved from 0.09749 to 0.09016, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 105ms/step - loss: 0.0902 - val_loss: 0.0629
# Epoch 10/100
#
# Epoch 10: loss improved from 0.09016 to 0.08559, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 102ms/step - loss: 0.0856 - val_loss: 0.0581
# Epoch 11/100
#
# Epoch 11: loss improved from 0.08559 to 0.08218, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 105ms/step - loss: 0.0822 - val_loss: 0.0550
# Epoch 12/100
#
# Epoch 12: loss improved from 0.08218 to 0.07913, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 97ms/step - loss: 0.0791 - val_loss: 0.0527
# Epoch 13/100
#
# Epoch 13: loss improved from 0.07913 to 0.07713, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 106ms/step - loss: 0.0771 - val_loss: 0.0501
# Epoch 14/100
#
# Epoch 14: loss improved from 0.07713 to 0.07395, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 105ms/step - loss: 0.0739 - val_loss: 0.0528
# Epoch 15/100
#
# Epoch 15: loss improved from 0.07395 to 0.07231, saving model to save_models/MWG_model.keras
# 32/32 - 5s - 160ms/step - loss: 0.0723 - val_loss: 0.0463
# Epoch 16/100
#
# Epoch 16: loss improved from 0.07231 to 0.06965, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 102ms/step - loss: 0.0696 - val_loss: 0.0449
# Epoch 17/100
#
# Epoch 17: loss improved from 0.06965 to 0.06949, saving model to save_models/MWG_model.keras
# 32/32 - 6s - 179ms/step - loss: 0.0695 - val_loss: 0.0473
# Epoch 18/100
#
# Epoch 18: loss improved from 0.06949 to 0.06824, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 128ms/step - loss: 0.0682 - val_loss: 0.0437
# Epoch 19/100
#
# Epoch 19: loss improved from 0.06824 to 0.06543, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 117ms/step - loss: 0.0654 - val_loss: 0.0415
# Epoch 20/100
#
# Epoch 20: loss improved from 0.06543 to 0.06406, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 116ms/step - loss: 0.0641 - val_loss: 0.0444
# Epoch 21/100
#
# Epoch 21: loss improved from 0.06406 to 0.06314, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 100ms/step - loss: 0.0631 - val_loss: 0.0438
# Epoch 22/100
#
# Epoch 22: loss improved from 0.06314 to 0.06198, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 82ms/step - loss: 0.0620 - val_loss: 0.0391
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.06198
# 32/32 - 3s - 103ms/step - loss: 0.0657 - val_loss: 0.0449
# Epoch 24/100
#
# Epoch 24: loss improved from 0.06198 to 0.05983, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 114ms/step - loss: 0.0598 - val_loss: 0.0374
# Epoch 25/100
#
# Epoch 25: loss improved from 0.05983 to 0.05780, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 102ms/step - loss: 0.0578 - val_loss: 0.0367
# Epoch 26/100
#
# Epoch 26: loss improved from 0.05780 to 0.05649, saving model to save_models/MWG_model.keras
# 32/32 - 6s - 173ms/step - loss: 0.0565 - val_loss: 0.0397
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.05649
# 32/32 - 4s - 110ms/step - loss: 0.0567 - val_loss: 0.0352
# Epoch 28/100
#
# Epoch 28: loss improved from 0.05649 to 0.05633, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 106ms/step - loss: 0.0563 - val_loss: 0.0343
# Epoch 29/100
#
# Epoch 29: loss improved from 0.05633 to 0.05504, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 111ms/step - loss: 0.0550 - val_loss: 0.0350
# Epoch 30/100
#
# Epoch 30: loss improved from 0.05504 to 0.05369, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 119ms/step - loss: 0.0537 - val_loss: 0.0332
# Epoch 31/100
#
# Epoch 31: loss improved from 0.05369 to 0.05303, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 111ms/step - loss: 0.0530 - val_loss: 0.0358
# Epoch 32/100
#
# Epoch 32: loss improved from 0.05303 to 0.05191, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 114ms/step - loss: 0.0519 - val_loss: 0.0317
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.05191
# 32/32 - 4s - 117ms/step - loss: 0.0520 - val_loss: 0.0333
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.05191
# 32/32 - 4s - 117ms/step - loss: 0.0521 - val_loss: 0.0311
# Epoch 35/100
#
# Epoch 35: loss improved from 0.05191 to 0.04971, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 124ms/step - loss: 0.0497 - val_loss: 0.0301
# Epoch 36/100
#
# Epoch 36: loss improved from 0.04971 to 0.04963, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 107ms/step - loss: 0.0496 - val_loss: 0.0330
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.04963
# 32/32 - 4s - 115ms/step - loss: 0.0501 - val_loss: 0.0330
# Epoch 38/100
#
# Epoch 38: loss improved from 0.04963 to 0.04910, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 113ms/step - loss: 0.0491 - val_loss: 0.0298
# Epoch 39/100
#
# Epoch 39: loss improved from 0.04910 to 0.04784, saving model to save_models/MWG_model.keras
# 32/32 - 6s - 179ms/step - loss: 0.0478 - val_loss: 0.0309
# Epoch 40/100
#
# Epoch 40: loss improved from 0.04784 to 0.04666, saving model to save_models/MWG_model.keras
# 32/32 - 5s - 156ms/step - loss: 0.0467 - val_loss: 0.0287
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.04666
# 32/32 - 4s - 123ms/step - loss: 0.0471 - val_loss: 0.0292
# Epoch 42/100
#
# Epoch 42: loss improved from 0.04666 to 0.04629, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 134ms/step - loss: 0.0463 - val_loss: 0.0283
# Epoch 43/100
#
# Epoch 43: loss improved from 0.04629 to 0.04457, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 135ms/step - loss: 0.0446 - val_loss: 0.0279
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.04457
# 32/32 - 4s - 123ms/step - loss: 0.0451 - val_loss: 0.0309
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.04457
# 32/32 - 4s - 122ms/step - loss: 0.0446 - val_loss: 0.0274
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.04457
# 32/32 - 4s - 127ms/step - loss: 0.0447 - val_loss: 0.0272
# Epoch 47/100
#
# Epoch 47: loss improved from 0.04457 to 0.04301, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 125ms/step - loss: 0.0430 - val_loss: 0.0264
# Epoch 48/100
#
# Epoch 48: loss improved from 0.04301 to 0.04261, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 124ms/step - loss: 0.0426 - val_loss: 0.0260
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.04261
# 32/32 - 4s - 132ms/step - loss: 0.0429 - val_loss: 0.0256
# Epoch 50/100
#
# Epoch 50: loss improved from 0.04261 to 0.04235, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 130ms/step - loss: 0.0424 - val_loss: 0.0257
# Epoch 51/100
#
# Epoch 51: loss improved from 0.04235 to 0.04142, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 126ms/step - loss: 0.0414 - val_loss: 0.0277
# Epoch 52/100
#
# Epoch 52: loss improved from 0.04142 to 0.04028, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 125ms/step - loss: 0.0403 - val_loss: 0.0257
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.04028
# 32/32 - 4s - 128ms/step - loss: 0.0419 - val_loss: 0.0274
# Epoch 54/100
#
# Epoch 54: loss improved from 0.04028 to 0.03976, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 107ms/step - loss: 0.0398 - val_loss: 0.0257
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.03976
# 32/32 - 3s - 108ms/step - loss: 0.0410 - val_loss: 0.0251
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.03976
# 32/32 - 4s - 123ms/step - loss: 0.0402 - val_loss: 0.0262
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.03976
# 32/32 - 3s - 104ms/step - loss: 0.0404 - val_loss: 0.0258
# Epoch 58/100
#
# Epoch 58: loss improved from 0.03976 to 0.03832, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 114ms/step - loss: 0.0383 - val_loss: 0.0243
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.03832
# 32/32 - 4s - 121ms/step - loss: 0.0387 - val_loss: 0.0245
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.03832
# 32/32 - 4s - 125ms/step - loss: 0.0386 - val_loss: 0.0251
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.03832
# 32/32 - 4s - 126ms/step - loss: 0.0386 - val_loss: 0.0259
# Epoch 62/100
#
# Epoch 62: loss improved from 0.03832 to 0.03755, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 126ms/step - loss: 0.0376 - val_loss: 0.0240
# Epoch 63/100
#
# Epoch 63: loss improved from 0.03755 to 0.03691, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 131ms/step - loss: 0.0369 - val_loss: 0.0232
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.03691
# 32/32 - 4s - 131ms/step - loss: 0.0373 - val_loss: 0.0240
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.03691
# 32/32 - 4s - 122ms/step - loss: 0.0377 - val_loss: 0.0263
# Epoch 66/100
#
# Epoch 66: loss improved from 0.03691 to 0.03679, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 136ms/step - loss: 0.0368 - val_loss: 0.0242
# Epoch 67/100
#
# Epoch 67: loss improved from 0.03679 to 0.03658, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 126ms/step - loss: 0.0366 - val_loss: 0.0251
# Epoch 68/100
#
# Epoch 68: loss improved from 0.03658 to 0.03646, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 139ms/step - loss: 0.0365 - val_loss: 0.0246
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.03646
# 32/32 - 4s - 132ms/step - loss: 0.0367 - val_loss: 0.0234
# Epoch 70/100
#
# Epoch 70: loss improved from 0.03646 to 0.03593, saving model to save_models/MWG_model.keras
# 32/32 - 5s - 164ms/step - loss: 0.0359 - val_loss: 0.0225
# Epoch 71/100
#
# Epoch 71: loss improved from 0.03593 to 0.03571, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 137ms/step - loss: 0.0357 - val_loss: 0.0229
# Epoch 72/100
#
# Epoch 72: loss improved from 0.03571 to 0.03433, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 110ms/step - loss: 0.0343 - val_loss: 0.0232
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.03433
# 32/32 - 3s - 106ms/step - loss: 0.0358 - val_loss: 0.0228
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.03433
# 32/32 - 4s - 130ms/step - loss: 0.0352 - val_loss: 0.0221
# Epoch 75/100
#
# Epoch 75: loss improved from 0.03433 to 0.03421, saving model to save_models/MWG_model.keras
# 32/32 - 5s - 170ms/step - loss: 0.0342 - val_loss: 0.0220
# Epoch 76/100
#
# Epoch 76: loss improved from 0.03421 to 0.03343, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 131ms/step - loss: 0.0334 - val_loss: 0.0220
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.03343
# 32/32 - 4s - 128ms/step - loss: 0.0341 - val_loss: 0.0223
# Epoch 78/100
#
# Epoch 78: loss improved from 0.03343 to 0.03294, saving model to save_models/MWG_model.keras
# 32/32 - 4s - 129ms/step - loss: 0.0329 - val_loss: 0.0226
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.03294
# 32/32 - 4s - 130ms/step - loss: 0.0338 - val_loss: 0.0228
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.03294
# 32/32 - 4s - 126ms/step - loss: 0.0330 - val_loss: 0.0219
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.03294
# 32/32 - 4s - 118ms/step - loss: 0.0337 - val_loss: 0.0221
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.03294
# 32/32 - 5s - 142ms/step - loss: 0.0330 - val_loss: 0.0214
# Epoch 83/100
#
# Epoch 83: loss improved from 0.03294 to 0.03275, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 102ms/step - loss: 0.0327 - val_loss: 0.0227
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.03275
# 32/32 - 3s - 96ms/step - loss: 0.0333 - val_loss: 0.0217
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.03275
# 32/32 - 3s - 94ms/step - loss: 0.0336 - val_loss: 0.0215
# Epoch 86/100
#
# Epoch 86: loss improved from 0.03275 to 0.03229, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 90ms/step - loss: 0.0323 - val_loss: 0.0212
# Epoch 87/100
#
# Epoch 87: loss improved from 0.03229 to 0.03223, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 88ms/step - loss: 0.0322 - val_loss: 0.0215
# Epoch 88/100
#
# Epoch 88: loss improved from 0.03223 to 0.03194, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 96ms/step - loss: 0.0319 - val_loss: 0.0211
# Epoch 89/100
#
# Epoch 89: loss improved from 0.03194 to 0.03179, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 90ms/step - loss: 0.0318 - val_loss: 0.0209
# Epoch 90/100
#
# Epoch 90: loss improved from 0.03179 to 0.03139, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 88ms/step - loss: 0.0314 - val_loss: 0.0212
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.03139
# 32/32 - 3s - 89ms/step - loss: 0.0317 - val_loss: 0.0228
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.03139
# 32/32 - 3s - 86ms/step - loss: 0.0318 - val_loss: 0.0208
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.03139
# 32/32 - 3s - 84ms/step - loss: 0.0316 - val_loss: 0.0217
# Epoch 94/100
#
# Epoch 94: loss improved from 0.03139 to 0.03123, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 89ms/step - loss: 0.0312 - val_loss: 0.0206
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.03123
# 32/32 - 3s - 86ms/step - loss: 0.0313 - val_loss: 0.0222
# Epoch 96/100
#
# Epoch 96: loss improved from 0.03123 to 0.03010, saving model to save_models/MWG_model.keras
# 32/32 - 3s - 95ms/step - loss: 0.0301 - val_loss: 0.0206
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.03010
# 32/32 - 3s - 94ms/step - loss: 0.0303 - val_loss: 0.0208
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.03010
# 32/32 - 3s - 93ms/step - loss: 0.0308 - val_loss: 0.0216
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.03010
# 32/32 - 3s - 82ms/step - loss: 0.0316 - val_loss: 0.0245
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.03010
# 32/32 - 3s - 84ms/step - loss: 0.0309 - val_loss: 0.0228
# Restoring model weights from the end of the best epoch: 96.

# %%
# Hàm xây dựng mô hình
def build_model():
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(units=64))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# Huấn luyện mô hình
model = build_model()
save_model_path = f"save_models/{collection}_model.keras"
best_model = ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.01953, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 9s - 127ms/step - loss: 0.0195
# Epoch 2/100
#
# Epoch 2: loss improved from 0.01953 to 0.01390, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 67ms/step - loss: 0.0139
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01390 to 0.01147, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 69ms/step - loss: 0.0115
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.01147
# 72/72 - 5s - 64ms/step - loss: 0.0124
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01147 to 0.01087, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0109
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01087 to 0.01084, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 64ms/step - loss: 0.0108
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.01084
# 72/72 - 5s - 66ms/step - loss: 0.0114
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.01084
# 72/72 - 5s - 68ms/step - loss: 0.0109
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01084 to 0.01023, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0102
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01023 to 0.00967, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 68ms/step - loss: 0.0097
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00967
# 72/72 - 5s - 66ms/step - loss: 0.0104
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00967
# 72/72 - 5s - 69ms/step - loss: 0.0098
# Epoch 13/100
#
# Epoch 13: loss improved from 0.00967 to 0.00954, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 65ms/step - loss: 0.0095
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00954
# 72/72 - 4s - 62ms/step - loss: 0.0099
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.00954
# 72/72 - 5s - 64ms/step - loss: 0.0098
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.00954
# 72/72 - 5s - 63ms/step - loss: 0.0100
# Epoch 17/100
#
# Epoch 17: loss improved from 0.00954 to 0.00887, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00887
# 72/72 - 4s - 57ms/step - loss: 0.0096
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0095
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0102
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00887
# 72/72 - 4s - 58ms/step - loss: 0.0138
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00887
# 72/72 - 4s - 59ms/step - loss: 0.0094
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00887
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0089
# Epoch 28/100
#
# Epoch 28: loss improved from 0.00887 to 0.00879, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00879 to 0.00859, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00859
# 72/72 - 5s - 75ms/step - loss: 0.0094
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00859
# 72/72 - 4s - 58ms/step - loss: 0.0090
# Epoch 32/100
#
# Epoch 32: loss improved from 0.00859 to 0.00851, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0114
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0091
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0091
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00851
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00851
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0089
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 41/100
#
# Epoch 41: loss improved from 0.00851 to 0.00840, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00840 to 0.00836, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00836
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00836
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 45/100
#
# Epoch 45: loss improved from 0.00836 to 0.00829, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0083
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00829
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00829 to 0.00812, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0086
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0082
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00812
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0093
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00812
# 72/72 - 5s - 63ms/step - loss: 0.0083
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00812 to 0.00806, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00806
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00806 to 0.00791, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0084
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0079
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0108
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0091
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0081
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0085
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00791
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0086
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0081
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00791 to 0.00789, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0079
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0112
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0094
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00789
# 72/72 - 4s - 59ms/step - loss: 0.0095
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00789
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00789
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0080
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 89/100
#
# Epoch 89: loss improved from 0.00789 to 0.00785, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0079
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00785 to 0.00780, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0078
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0080
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0083
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00780
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00780
# 72/72 - 5s - 63ms/step - loss: 0.0084
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00780 to 0.00772, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0077

# %%
# save_model_path = "models/ACB_model.keras"
# Tải mô hình tốt nhất
final_model = load_model("models/MWG_model.keras")

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
# Chọn dữ liệu cho test_data11
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9685780805188658
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 2.628497358252888
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.523512125553783
# RMSE trên tập train (VNĐ): 5.242126088754189
# Độ chính xác trên tập train (%): 96.39840186275906
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9654658672640679
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.4199601080403954
# Phần trăm sai số tuyệt đối trung bình trên tập test: 2.9019533205921655
# RMSE trên tập test (VNĐ): 1.8430444695071826
# Độ chính xác trên tập test (%): 94.71907028794504
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
