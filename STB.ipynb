# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['STB']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2006-07-17         12.66       77.50            1320510       102909950
# 1     2006-07-20         12.50       76.50             988420        74246125
# 2     2006-07-26         11.19       68.50             311540        21281955
# 3     2006-07-31         10.54       64.50             200780        12987450
# 4     2006-08-07         10.05       61.50             538860        34338810
# ...          ...           ...         ...                ...             ...
# 4598  2024-12-17         34.10       34.10            3703800    125923000000
# 4599  2024-12-13         34.00       34.00            7644600    259500000000
# 4600  2024-12-18         34.20       34.20            4850900    164988000000
# 4601  2024-12-19         33.90       33.90            8676200    293219000000
# 4602  2024-12-20         33.85       33.85            7578900    255290000000
#
#       KLThoaThuan   GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0               0             0     79.00       79.00        77.50
# 1           80980       5873110     72.00       76.50        72.00
# 2               0             0     67.50       68.50        67.50
# 3               0             0     65.00       65.00        64.50
# 4               0             0     65.00       65.00        61.50
# ...           ...           ...       ...         ...          ...
# 4598      4112000  143639200000     34.10       34.20        33.85
# 4599      1800000   63000000000     33.80       34.20        33.55
# 4600      4600000  161000000000     34.10       34.20        33.85
# 4601      6600000  231000000000     33.80       34.00        33.55
# 4602            0             0     33.75       33.95        33.50
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               0.00              0.00
# 1               3.50              4.79
# 2              -1.50             -2.14
# 3               0.00              0.00
# 4              -2.50             -3.91
# ...              ...               ...
# 4598            0.00              0.00
# 4599            0.20              0.59
# 4600            0.10              0.29
# 4601           -0.30             -0.88
# 4602           -0.05             -0.15
#
# [4603 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4603 entries, 0 to 4602
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               4603 non-null   object
#  1   GiaDieuChinh       4603 non-null   float64
#  2   GiaDongCua         4603 non-null   float64
#  3   KhoiLuongKhopLenh  4603 non-null   int64
#  4   GiaTriKhopLenh     4603 non-null   int64
#  5   KLThoaThuan        4603 non-null   int64
#  6   GtThoaThuan        4603 non-null   int64
#  7   GiaMoCua           4603 non-null   float64
#  8   GiaCaoNhat         4603 non-null   float64
#  9   GiaThapNhat        4603 non-null   float64
#  10  ThayDoi_GiaTri     4603 non-null   float64
#  11  ThayDoi_PhanTram   4603 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 431.7+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   4603.000000  4603.000000       4.603000e+03    4.603000e+03
# mean      15.465970    24.739476       6.727634e+06    1.580247e+11
# std        7.221844    20.868648       9.893134e+06    2.616477e+11
# min        4.690000     7.300000       0.000000e+00    0.000000e+00
# 25%       10.610000    13.100000       7.121550e+05    1.255244e+10
# 50%       12.800000    19.000000       2.176840e+06    4.257400e+10
# 75%       18.065000    27.600000       8.903085e+06    1.915486e+11
# max       35.850000   168.000000       1.050898e+08    3.164759e+12
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  4.603000e+03  4.603000e+03  4603.000000  4603.000000  4603.000000
# mean   5.541536e+05  1.176677e+10    24.754758    25.037260    24.473778
# std    3.548415e+06  6.732383e+10    20.930505    21.029523    20.776940
# min    0.000000e+00  0.000000e+00     7.200000     7.540000     7.120000
# 25%    0.000000e+00  0.000000e+00    13.100000    13.300000    12.900000
# 50%    0.000000e+00  0.000000e+00    19.000000    19.200000    18.800000
# 75%    1.258800e+05  2.527022e+09    27.650000    28.050000    27.200000
# max    1.481457e+08  2.338539e+12   170.000000   170.000000   168.000000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     4603.000000       4603.000000
# mean        -0.008275          0.014571
# std          0.547599          2.164929
# min         -6.500000         -9.150000
# 25%         -0.200000         -0.990000
# 50%          0.000000          0.000000
# 75%          0.200000          0.890000
# max          4.500000          9.310000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2006-07-12       78.00
# 2006-07-13       81.50
# 2006-07-14       80.50
# 2006-07-17       77.50
# 2006-07-18       75.50
# ...                ...
# 2024-12-16       34.10
# 2024-12-17       34.10
# 2024-12-18       34.20
# 2024-12-19       33.90
# 2024-12-20       33.85
#
# [4603 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[78.  ],
#        [81.5 ],
#        [80.5 ],
#        ...,
#        [34.2 ],
#        [33.9 ],
#        [33.85]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # LSTM đầu tiên với L2 regularization
    model.add(LSTM(units=128, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    
    # LSTM thứ hai với L2 regularization
    model.add(LSTM(units=64, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.5))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình với learning rate thấp để ổn định huấn luyện
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001))
    
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])  # Điều chỉnh để phù hợp với đầu vào
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/STB_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=30, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.12603, saving model to save_models/STB_model.keras
# 57/57 - 33s - 575ms/step - loss: 0.1260 - val_loss: 0.0793
# Epoch 2/100
#
# Epoch 2: loss improved from 0.12603 to 0.04680, saving model to save_models/STB_model.keras
# 57/57 - 7s - 132ms/step - loss: 0.0468 - val_loss: 0.0391
# Epoch 3/100
#
# Epoch 3: loss improved from 0.04680 to 0.02654, saving model to save_models/STB_model.keras
# 57/57 - 11s - 194ms/step - loss: 0.0265 - val_loss: 0.0288
# Epoch 4/100
#
# Epoch 4: loss improved from 0.02654 to 0.02093, saving model to save_models/STB_model.keras
# 57/57 - 8s - 146ms/step - loss: 0.0209 - val_loss: 0.0312
# Epoch 5/100
#
# Epoch 5: loss improved from 0.02093 to 0.01765, saving model to save_models/STB_model.keras
# 57/57 - 8s - 138ms/step - loss: 0.0176 - val_loss: 0.0245
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01765 to 0.01606, saving model to save_models/STB_model.keras
# 57/57 - 10s - 181ms/step - loss: 0.0161 - val_loss: 0.0208
# Epoch 7/100
#
# Epoch 7: loss improved from 0.01606 to 0.01456, saving model to save_models/STB_model.keras
# 57/57 - 7s - 126ms/step - loss: 0.0146 - val_loss: 0.0200
# Epoch 8/100
#
# Epoch 8: loss improved from 0.01456 to 0.01368, saving model to save_models/STB_model.keras
# 57/57 - 7s - 116ms/step - loss: 0.0137 - val_loss: 0.0191
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01368 to 0.01354, saving model to save_models/STB_model.keras
# 57/57 - 7s - 127ms/step - loss: 0.0135 - val_loss: 0.0186
# Epoch 10/100
#
# Epoch 10: loss did not improve from 0.01354
# 57/57 - 7s - 125ms/step - loss: 0.0139 - val_loss: 0.0183
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.01354
# 57/57 - 7s - 124ms/step - loss: 0.0141 - val_loss: 0.0369
# Epoch 12/100
#
# Epoch 12: loss improved from 0.01354 to 0.01335, saving model to save_models/STB_model.keras
# 57/57 - 6s - 107ms/step - loss: 0.0134 - val_loss: 0.0177
# Epoch 13/100
#
# Epoch 13: loss improved from 0.01335 to 0.01285, saving model to save_models/STB_model.keras
# 57/57 - 7s - 114ms/step - loss: 0.0128 - val_loss: 0.0191
# Epoch 14/100
#
# Epoch 14: loss improved from 0.01285 to 0.01246, saving model to save_models/STB_model.keras
# 57/57 - 7s - 121ms/step - loss: 0.0125 - val_loss: 0.0194
# Epoch 15/100
#
# Epoch 15: loss improved from 0.01246 to 0.01223, saving model to save_models/STB_model.keras
# 57/57 - 7s - 131ms/step - loss: 0.0122 - val_loss: 0.0174
# Epoch 16/100
#
# Epoch 16: loss improved from 0.01223 to 0.01213, saving model to save_models/STB_model.keras
# 57/57 - 8s - 135ms/step - loss: 0.0121 - val_loss: 0.0165
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.01213
# 57/57 - 10s - 174ms/step - loss: 0.0122 - val_loss: 0.0162
# Epoch 18/100
#
# Epoch 18: loss improved from 0.01213 to 0.01149, saving model to save_models/STB_model.keras
# 57/57 - 10s - 170ms/step - loss: 0.0115 - val_loss: 0.0168
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.01149
# 57/57 - 8s - 134ms/step - loss: 0.0123 - val_loss: 0.0273
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01149
# 57/57 - 7s - 129ms/step - loss: 0.0127 - val_loss: 0.0163
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.01149
# 57/57 - 8s - 147ms/step - loss: 0.0128 - val_loss: 0.0188
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01149
# 57/57 - 8s - 134ms/step - loss: 0.0116 - val_loss: 0.0175
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01149
# 57/57 - 7s - 117ms/step - loss: 0.0118 - val_loss: 0.0176
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.01149
# 57/57 - 10s - 173ms/step - loss: 0.0119 - val_loss: 0.0242
# Epoch 25/100
#
# Epoch 25: loss improved from 0.01149 to 0.01145, saving model to save_models/STB_model.keras
# 57/57 - 6s - 101ms/step - loss: 0.0114 - val_loss: 0.0218
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.01145
# 57/57 - 11s - 194ms/step - loss: 0.0123 - val_loss: 0.0184
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01145
# 57/57 - 7s - 123ms/step - loss: 0.0120 - val_loss: 0.0188
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01145
# 57/57 - 7s - 126ms/step - loss: 0.0122 - val_loss: 0.0367
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.01145
# 57/57 - 7s - 129ms/step - loss: 0.0123 - val_loss: 0.0153
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.01145
# 57/57 - 8s - 136ms/step - loss: 0.0116 - val_loss: 0.0160
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01145
# 57/57 - 8s - 133ms/step - loss: 0.0122 - val_loss: 0.0256
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01145
# 57/57 - 7s - 131ms/step - loss: 0.0121 - val_loss: 0.0166
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01145
# 57/57 - 6s - 111ms/step - loss: 0.0128 - val_loss: 0.0155
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01145
# 57/57 - 7s - 126ms/step - loss: 0.0121 - val_loss: 0.0203
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01145
# 57/57 - 7s - 124ms/step - loss: 0.0118 - val_loss: 0.0175
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01145
# 57/57 - 6s - 112ms/step - loss: 0.0118 - val_loss: 0.0195
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01145
# 57/57 - 8s - 143ms/step - loss: 0.0118 - val_loss: 0.0155
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01145
# 57/57 - 9s - 166ms/step - loss: 0.0120 - val_loss: 0.0212
# Epoch 39/100
#
# Epoch 39: loss improved from 0.01145 to 0.01132, saving model to save_models/STB_model.keras
# 57/57 - 7s - 130ms/step - loss: 0.0113 - val_loss: 0.0161
# Epoch 40/100
#
# Epoch 40: loss improved from 0.01132 to 0.01108, saving model to save_models/STB_model.keras
# 57/57 - 8s - 132ms/step - loss: 0.0111 - val_loss: 0.0255
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01108
# 57/57 - 7s - 131ms/step - loss: 0.0118 - val_loss: 0.0168
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01108
# 57/57 - 7s - 116ms/step - loss: 0.0118 - val_loss: 0.0155
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01108
# 57/57 - 11s - 190ms/step - loss: 0.0118 - val_loss: 0.0151
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01108
# 57/57 - 10s - 180ms/step - loss: 0.0114 - val_loss: 0.0176
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01108
# 57/57 - 11s - 187ms/step - loss: 0.0119 - val_loss: 0.0225
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01108
# 57/57 - 7s - 126ms/step - loss: 0.0112 - val_loss: 0.0167
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01108
# 57/57 - 7s - 129ms/step - loss: 0.0116 - val_loss: 0.0192
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01108
# 57/57 - 7s - 129ms/step - loss: 0.0115 - val_loss: 0.0150
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01108
# 57/57 - 10s - 183ms/step - loss: 0.0120 - val_loss: 0.0192
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01108
# 57/57 - 6s - 109ms/step - loss: 0.0119 - val_loss: 0.0153
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01108
# 57/57 - 7s - 117ms/step - loss: 0.0111 - val_loss: 0.0144
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01108
# 57/57 - 7s - 129ms/step - loss: 0.0115 - val_loss: 0.0159
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01108
# 57/57 - 7s - 114ms/step - loss: 0.0115 - val_loss: 0.0159
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01108
# 57/57 - 6s - 110ms/step - loss: 0.0119 - val_loss: 0.0171
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01108
# 57/57 - 6s - 109ms/step - loss: 0.0115 - val_loss: 0.0141
# Epoch 56/100
#
# Epoch 56: loss improved from 0.01108 to 0.01075, saving model to save_models/STB_model.keras
# 57/57 - 6s - 107ms/step - loss: 0.0107 - val_loss: 0.0144
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01075
# 57/57 - 6s - 99ms/step - loss: 0.0112 - val_loss: 0.0140
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01075
# 57/57 - 6s - 99ms/step - loss: 0.0110 - val_loss: 0.0275
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01075
# 57/57 - 5s - 85ms/step - loss: 0.0111 - val_loss: 0.0146
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01075
# 57/57 - 5s - 95ms/step - loss: 0.0113 - val_loss: 0.0141
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01075
# 57/57 - 6s - 105ms/step - loss: 0.0117 - val_loss: 0.0175
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01075
# 57/57 - 6s - 104ms/step - loss: 0.0109 - val_loss: 0.0201
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01075
# 57/57 - 7s - 114ms/step - loss: 0.0109 - val_loss: 0.0206
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01075
# 57/57 - 6s - 109ms/step - loss: 0.0108 - val_loss: 0.0150
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01075
# 57/57 - 6s - 109ms/step - loss: 0.0111 - val_loss: 0.0160
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01075
# 57/57 - 6s - 105ms/step - loss: 0.0109 - val_loss: 0.0205
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01075
# 57/57 - 7s - 121ms/step - loss: 0.0113 - val_loss: 0.0155
# Epoch 68/100
#
# Epoch 68: loss improved from 0.01075 to 0.01074, saving model to save_models/STB_model.keras
# 57/57 - 6s - 98ms/step - loss: 0.0107 - val_loss: 0.0148
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01074
# 57/57 - 5s - 89ms/step - loss: 0.0108 - val_loss: 0.0141
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01074
# 57/57 - 6s - 98ms/step - loss: 0.0108 - val_loss: 0.0136
# Epoch 71/100
#
# Epoch 71: loss improved from 0.01074 to 0.01064, saving model to save_models/STB_model.keras
# 57/57 - 5s - 88ms/step - loss: 0.0106 - val_loss: 0.0197
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01064
# 57/57 - 5s - 84ms/step - loss: 0.0107 - val_loss: 0.0138
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01064
# 57/57 - 5s - 86ms/step - loss: 0.0114 - val_loss: 0.0138
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01064
# 57/57 - 5s - 82ms/step - loss: 0.0109 - val_loss: 0.0156
# Epoch 75/100
#
# Epoch 75: loss improved from 0.01064 to 0.01051, saving model to save_models/STB_model.keras
# 57/57 - 5s - 83ms/step - loss: 0.0105 - val_loss: 0.0142
# Epoch 76/100
#
# Epoch 76: loss improved from 0.01051 to 0.01018, saving model to save_models/STB_model.keras
# 57/57 - 4s - 77ms/step - loss: 0.0102 - val_loss: 0.0144
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01018
# 57/57 - 4s - 76ms/step - loss: 0.0105 - val_loss: 0.0135
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01018
# 57/57 - 4s - 76ms/step - loss: 0.0108 - val_loss: 0.0161
# Epoch 79/100
#
# Epoch 79: loss improved from 0.01018 to 0.01008, saving model to save_models/STB_model.keras
# 57/57 - 5s - 86ms/step - loss: 0.0101 - val_loss: 0.0159
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01008
# 57/57 - 5s - 82ms/step - loss: 0.0111 - val_loss: 0.0156
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01008
# 57/57 - 5s - 81ms/step - loss: 0.0108 - val_loss: 0.0178
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01008
# 57/57 - 5s - 80ms/step - loss: 0.0110 - val_loss: 0.0171
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01008
# 57/57 - 4s - 76ms/step - loss: 0.0107 - val_loss: 0.0134
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01008
# 57/57 - 4s - 78ms/step - loss: 0.0104 - val_loss: 0.0144
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01008
# 57/57 - 4s - 78ms/step - loss: 0.0103 - val_loss: 0.0139
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01008
# 57/57 - 4s - 77ms/step - loss: 0.0105 - val_loss: 0.0141
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01008
# 57/57 - 5s - 83ms/step - loss: 0.0105 - val_loss: 0.0134
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01008
# 57/57 - 5s - 86ms/step - loss: 0.0106 - val_loss: 0.0139
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01008
# 57/57 - 5s - 84ms/step - loss: 0.0102 - val_loss: 0.0147
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01008
# 57/57 - 5s - 83ms/step - loss: 0.0107 - val_loss: 0.0170
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01008
# 57/57 - 5s - 86ms/step - loss: 0.0104 - val_loss: 0.0143
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01008
# 57/57 - 5s - 80ms/step - loss: 0.0101 - val_loss: 0.0142
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01008
# 57/57 - 5s - 89ms/step - loss: 0.0102 - val_loss: 0.0162
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01008
# 57/57 - 5s - 85ms/step - loss: 0.0111 - val_loss: 0.0199
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01008
# 57/57 - 5s - 86ms/step - loss: 0.0111 - val_loss: 0.0155
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01008
# 57/57 - 5s - 83ms/step - loss: 0.0110 - val_loss: 0.0143
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01008
# 57/57 - 5s - 80ms/step - loss: 0.0105 - val_loss: 0.0249
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01008
# 57/57 - 5s - 91ms/step - loss: 0.0103 - val_loss: 0.0148
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01008
# 57/57 - 5s - 80ms/step - loss: 0.0105 - val_loss: 0.0133
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01008
# 57/57 - 5s - 86ms/step - loss: 0.0105 - val_loss: 0.0141
# Restoring model weights from the end of the best epoch: 79.

# %%
# Hàm xây dựng mô hình
def build_model():
    model = Sequential()
    model.add(LSTM(units=128, input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(LSTM(units=64))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# Huấn luyện mô hình
model = build_model()
save_model_path = f"save_models/{collection}_model.keras"
best_model = ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.01953, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 9s - 127ms/step - loss: 0.0195
# Epoch 2/100
#
# Epoch 2: loss improved from 0.01953 to 0.01390, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 67ms/step - loss: 0.0139
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01390 to 0.01147, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 69ms/step - loss: 0.0115
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.01147
# 72/72 - 5s - 64ms/step - loss: 0.0124
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01147 to 0.01087, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0109
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01087 to 0.01084, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 64ms/step - loss: 0.0108
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.01084
# 72/72 - 5s - 66ms/step - loss: 0.0114
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.01084
# 72/72 - 5s - 68ms/step - loss: 0.0109
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01084 to 0.01023, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0102
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01023 to 0.00967, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 68ms/step - loss: 0.0097
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00967
# 72/72 - 5s - 66ms/step - loss: 0.0104
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00967
# 72/72 - 5s - 69ms/step - loss: 0.0098
# Epoch 13/100
#
# Epoch 13: loss improved from 0.00967 to 0.00954, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 65ms/step - loss: 0.0095
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00954
# 72/72 - 4s - 62ms/step - loss: 0.0099
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.00954
# 72/72 - 5s - 64ms/step - loss: 0.0098
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.00954
# 72/72 - 5s - 63ms/step - loss: 0.0100
# Epoch 17/100
#
# Epoch 17: loss improved from 0.00954 to 0.00887, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00887
# 72/72 - 4s - 57ms/step - loss: 0.0096
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0095
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0102
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00887
# 72/72 - 4s - 58ms/step - loss: 0.0138
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00887
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00887
# 72/72 - 4s - 59ms/step - loss: 0.0094
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0091
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00887
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00887
# 72/72 - 4s - 62ms/step - loss: 0.0089
# Epoch 28/100
#
# Epoch 28: loss improved from 0.00887 to 0.00879, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00879 to 0.00859, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00859
# 72/72 - 5s - 75ms/step - loss: 0.0094
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00859
# 72/72 - 4s - 58ms/step - loss: 0.0090
# Epoch 32/100
#
# Epoch 32: loss improved from 0.00859 to 0.00851, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0114
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0091
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0091
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00851
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00851
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00851
# 72/72 - 4s - 60ms/step - loss: 0.0089
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00851
# 72/72 - 4s - 61ms/step - loss: 0.0098
# Epoch 41/100
#
# Epoch 41: loss improved from 0.00851 to 0.00840, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00840 to 0.00836, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00836
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00836
# 72/72 - 4s - 59ms/step - loss: 0.0088
# Epoch 45/100
#
# Epoch 45: loss improved from 0.00836 to 0.00829, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 66ms/step - loss: 0.0083
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00829
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00829 to 0.00812, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0086
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0090
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0087
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0089
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00812
# 72/72 - 4s - 61ms/step - loss: 0.0082
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0082
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00812
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00812
# 72/72 - 4s - 59ms/step - loss: 0.0093
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00812
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00812
# 72/72 - 5s - 63ms/step - loss: 0.0083
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00812 to 0.00806, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0081
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00806
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00806 to 0.00791, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0084
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0088
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0079
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0108
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0091
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00791
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0081
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0085
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00791
# 72/72 - 4s - 62ms/step - loss: 0.0085
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00791
# 72/72 - 5s - 64ms/step - loss: 0.0086
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00791
# 72/72 - 4s - 59ms/step - loss: 0.0081
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00791
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00791 to 0.00789, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0079
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0084
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0112
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0086
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00789
# 72/72 - 4s - 61ms/step - loss: 0.0094
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00789
# 72/72 - 4s - 59ms/step - loss: 0.0095
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00789
# 72/72 - 4s - 58ms/step - loss: 0.0085
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00789
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0080
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00789
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 89/100
#
# Epoch 89: loss improved from 0.00789 to 0.00785, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0079
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00785 to 0.00780, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 5s - 63ms/step - loss: 0.0078
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0084
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0080
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0083
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0079
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00780
# 72/72 - 4s - 62ms/step - loss: 0.0083
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00780
# 72/72 - 5s - 63ms/step - loss: 0.0084
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00780
# 72/72 - 4s - 60ms/step - loss: 0.0081
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00780
# 72/72 - 4s - 61ms/step - loss: 0.0085
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00780 to 0.00772, saving model to save_models/Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'metadata'), 'ACB')_model.keras
# 72/72 - 4s - 62ms/step - loss: 0.0077

# %%
save_model_path = "save_models/STB_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[1500:] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.9896157613974189
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 0.9221853480885206
# Phần trăm sai số tuyệt đối trung bình trên tập train: 3.5461062685666818
# RMSE trên tập train (VNĐ): 2.3171352587221694
# Độ chính xác trên tập train (%): 98.55809878113119
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9050060313593572
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1.0879724287184263
# Phần trăm sai số tuyệt đối trung bình trên tập test: 3.9179976823990126
# RMSE trên tập test (VNĐ): 1.2943247075932196
# Độ chính xác trên tập test (%): 93.83654901146086
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
