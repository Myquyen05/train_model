# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # type: ignore #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # type: ignore #tải mô hình
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.regularizers import l2 # type: ignore

#các lớp để xây dựng mô hình
from keras.models import Sequential # type: ignore #đầu vào
from keras.layers import LSTM # type: ignore #học phụ thuộc
from keras.layers import Dropout # type: ignore #tránh học tủ
from keras.layers import Dense # type: ignore #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score  # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error  # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error, f1_score  # Đo % sai số tuyệt đối trung bình

from pymongo import MongoClient

# %%
# Kết nối đến MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['metadata']  
collection = db['VRE']  

# Chuyển dữ liệu thành DataFrame
df = pd.DataFrame(list(collection.find({}, {"_id": 0})))
df
# Out:
#             Ngay  GiaDieuChinh  GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# 0     2017-11-07         32.15       40.55                  0               0
# 1     2017-11-08         32.15       40.55                  0               0
# 2     2017-11-17         35.36       44.60           10742380    478064000000
# 3     2017-11-20         37.82       47.70            3176670    149945000000
# 4     2017-11-22         40.91       51.60            7455670    389095000000
# ...          ...           ...         ...                ...             ...
# 1776  2024-12-17         17.15       17.15            5731600     98438000000
# 1777  2024-12-13         17.35       17.35            3566800     61732000000
# 1778  2024-12-18         17.10       17.10            4496000     77042000000
# 1779  2024-12-19         17.05       17.05            6408800    109373000000
# 1780  2024-12-20         17.05       17.05            3568200     60859000000
#
#       KLThoaThuan     GtThoaThuan  GiaMoCua  GiaCaoNhat  GiaThapNhat  \
# 0       414939570  16861296817200     40.55       40.55        40.55
# 1               0               0     40.55       40.55        40.55
# 2          530010     23543445000     44.00       45.50        43.30
# 3          150000      7080000000     45.60       47.70        45.00
# 4               0               0     51.50       54.00        50.40
# ...           ...             ...       ...         ...          ...
# 1776            0               0     17.30       17.35        17.10
# 1777      1300000     21125000000     17.30       17.40        17.20
# 1778      1800000     32670000000     17.15       17.20        17.10
# 1779            0               0     17.05       17.25        16.95
# 1780            0               0     17.05       17.15        17.00
#
#       ThayDoi_GiaTri  ThayDoi_PhanTram
# 0               0.00              0.00
# 1               0.00              0.00
# 2               0.60              1.36
# 3               3.10              6.95
# 4               0.60              1.18
# ...              ...               ...
# 1776           -0.15             -0.87
# 1777            0.05              0.29
# 1778           -0.05             -0.29
# 1779           -0.05             -0.29
# 1780            0.00              0.00
#
# [1781 rows x 12 columns]

# %%
# Kiểm tra dữ liệu
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ngay               1781 non-null   object
#  1   GiaDieuChinh       1781 non-null   float64
#  2   GiaDongCua         1781 non-null   float64
#  3   KhoiLuongKhopLenh  1781 non-null   int64
#  4   GiaTriKhopLenh     1781 non-null   int64
#  5   KLThoaThuan        1781 non-null   int64
#  6   GtThoaThuan        1781 non-null   int64
#  7   GiaMoCua           1781 non-null   float64
#  8   GiaCaoNhat         1781 non-null   float64
#  9   GiaThapNhat        1781 non-null   float64
#  10  ThayDoi_GiaTri     1781 non-null   float64
#  11  ThayDoi_PhanTram   1781 non-null   float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 167.1+ KB
#        GiaDieuChinh   GiaDongCua  KhoiLuongKhopLenh  GiaTriKhopLenh  \
# count   1781.000000  1781.000000       1.781000e+03    1.781000e+03
# mean      29.368860    30.720887       4.253535e+06    1.230833e+11
# std        5.310181     7.538048       3.672416e+06    1.014855e+11
# min       16.800000    16.800000       0.000000e+00    0.000000e+00
# 25%       26.500000    26.500000       1.700630e+06    5.312500e+10
# 50%       29.190000    29.350000       3.192200e+06    9.167700e+10
# 75%       32.930000    34.150000       5.645600e+06    1.637920e+11
# max       48.370000    61.000000       3.458230e+07    9.274040e+11
#
#         KLThoaThuan   GtThoaThuan     GiaMoCua   GiaCaoNhat  GiaThapNhat  \
# count  1.781000e+03  1.781000e+03  1781.000000  1781.000000  1781.000000
# mean   7.971469e+05  2.941009e+10    30.735373    31.204155    30.278074
# std    1.031765e+07  4.207755e+11     7.554911     7.704975     7.410834
# min    0.000000e+00  0.000000e+00    17.000000    17.150000    16.700000
# 25%    0.000000e+00  0.000000e+00    26.500000    27.000000    26.100000
# 50%    0.000000e+00  0.000000e+00    29.350000    29.750000    28.850000
# 75%    3.600000e+05  1.139250e+10    34.200000    34.600000    33.850000
# max    4.149396e+08  1.686130e+13    60.100000    61.500000    58.500000
#
#        ThayDoi_GiaTri  ThayDoi_PhanTram
# count     1781.000000       1781.000000
# mean        -0.002673          0.003464
# std          0.751170          2.308886
# min         -3.800000         -7.120000
# 25%         -0.350000         -1.120000
# 50%          0.000000          0.000000
# 75%          0.300000          1.060000
# max          6.750000         19.970000

# %%
# Xử lý thời gian và sắp xếp dữ liệu
df['Ngay'] = pd.to_datetime(df['Ngay'], format='%Y-%m-%d')
df = df.sort_values(by='Ngay')

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Lấy thông tin năm từ cột "Ngày"
df['Nam'] = df['Ngay'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngay'], df['GiaDongCua'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
# Chuyển đổi sang chỉ số thời gian
df1 = pd.DataFrame(df, columns=['Ngay', 'GiaDongCua'])
df1.index = df1['Ngay']
df1.drop('Ngay', axis=1, inplace=True)

# %%
df1
# Out:
#             GiaDongCua
# Ngay
# 2017-11-06       40.55
# 2017-11-07       40.55
# 2017-11-08       40.55
# 2017-11-09       40.55
# 2017-11-10       43.35
# ...                ...
# 2024-12-16       17.30
# 2024-12-17       17.15
# 2024-12-18       17.10
# 2024-12-19       17.05
# 2024-12-20       17.05
#
# [1781 rows x 1 columns]

# %%
# Chia tập dữ liệu
data = df1.values
train_data = data[:int(len(df) * 0.8)]
test_data = data[int(len(df) * 0.8):]

# %%
data
# Out:
# array([[40.55],
#        [40.55],
#        [40.55],
#        ...,
#        [17.1 ],
#        [17.05],
#        [17.05]])

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)

# %%
# Tạo cửa sổ thời gian cho tập train
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_train.append(sc_train[i, 0])  # Giá trị tiếp theo
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Tạo cửa sổ thời gian cho tập test
x_test, y_test = [], []
for i in range(50, len(test_data)):
    x_test.append(sc_train[i - 50:i, 0])  # 50 giá trị trước đó
    y_test.append(sc_train[i, 0])  # Giá trị tiếp theo
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_model(input_shape):
    model = Sequential()
    
    # Giảm số đơn vị trong LSTM và tăng regularization
    model.add(LSTM(units=64, input_shape=input_shape, return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    model.add(LSTM(units=32, kernel_regularizer=l2(0.001)))
    
    # Tăng Dropout để giảm overfitting
    model.add(Dropout(0.3))
    
    # Lớp Dense để đưa ra kết quả dự đoán
    model.add(Dense(1))
    
    # Compile mô hình
    model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001))
    return model

# Xây dựng mô hình
input_shape = (x_train.shape[1], x_train.shape[2])
model = build_model(input_shape)

# Đường dẫn lưu mô hình
save_model_path = "save_models/VRE_model.keras"

# Callbacks: ModelCheckpoint và EarlyStopping
callbacks = [
    ModelCheckpoint(save_model_path, monitor='loss', verbose=2, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='loss', patience=15, restore_best_weights=True, verbose=2)
]

# Huấn luyện mô hình và lưu kết quả vào history
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),  # Thêm tập validation
    epochs=100,
    batch_size=64,
    verbose=2,
    callbacks=callbacks
)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')  # Thêm val_loss
plt.title('Train and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# C:\Users\TRUONG\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.20173, saving model to save_models/VRE_model.keras
# 22/22 - 5s - 209ms/step - loss: 0.2017 - val_loss: 0.1569
# Epoch 2/100
#
# Epoch 2: loss improved from 0.20173 to 0.11636, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 47ms/step - loss: 0.1164 - val_loss: 0.0971
# Epoch 3/100
#
# Epoch 3: loss improved from 0.11636 to 0.09788, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0979 - val_loss: 0.0860
# Epoch 4/100
#
# Epoch 4: loss improved from 0.09788 to 0.08333, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0833 - val_loss: 0.0764
# Epoch 5/100
#
# Epoch 5: loss improved from 0.08333 to 0.07727, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0773 - val_loss: 0.0806
# Epoch 6/100
#
# Epoch 6: loss improved from 0.07727 to 0.07288, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0729 - val_loss: 0.0667
# Epoch 7/100
#
# Epoch 7: loss improved from 0.07288 to 0.06669, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0667 - val_loss: 0.0605
# Epoch 8/100
#
# Epoch 8: loss improved from 0.06669 to 0.06175, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0618 - val_loss: 0.0597
# Epoch 9/100
#
# Epoch 9: loss improved from 0.06175 to 0.06043, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0604 - val_loss: 0.0569
# Epoch 10/100
#
# Epoch 10: loss improved from 0.06043 to 0.05758, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0576 - val_loss: 0.0564
# Epoch 11/100
#
# Epoch 11: loss improved from 0.05758 to 0.05533, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0553 - val_loss: 0.0519
# Epoch 12/100
#
# Epoch 12: loss improved from 0.05533 to 0.05299, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0530 - val_loss: 0.0545
# Epoch 13/100
#
# Epoch 13: loss improved from 0.05299 to 0.05223, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0522 - val_loss: 0.0488
# Epoch 14/100
#
# Epoch 14: loss improved from 0.05223 to 0.04967, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0497 - val_loss: 0.0492
# Epoch 15/100
#
# Epoch 15: loss improved from 0.04967 to 0.04914, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0491 - val_loss: 0.0471
# Epoch 16/100
#
# Epoch 16: loss improved from 0.04914 to 0.04875, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 48ms/step - loss: 0.0488 - val_loss: 0.0539
# Epoch 17/100
#
# Epoch 17: loss improved from 0.04875 to 0.04733, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0473 - val_loss: 0.0447
# Epoch 18/100
#
# Epoch 18: loss improved from 0.04733 to 0.04485, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 47ms/step - loss: 0.0449 - val_loss: 0.0516
# Epoch 19/100
#
# Epoch 19: loss improved from 0.04485 to 0.04383, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0438 - val_loss: 0.0437
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.04383
# 22/22 - 1s - 44ms/step - loss: 0.0450 - val_loss: 0.0446
# Epoch 21/100
#
# Epoch 21: loss improved from 0.04383 to 0.04376, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0438 - val_loss: 0.0453
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.04376
# 22/22 - 1s - 44ms/step - loss: 0.0450 - val_loss: 0.0411
# Epoch 23/100
#
# Epoch 23: loss improved from 0.04376 to 0.04191, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0419 - val_loss: 0.0413
# Epoch 24/100
#
# Epoch 24: loss improved from 0.04191 to 0.04013, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0401 - val_loss: 0.0402
# Epoch 25/100
#
# Epoch 25: loss improved from 0.04013 to 0.03953, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0395 - val_loss: 0.0480
# Epoch 26/100
#
# Epoch 26: loss improved from 0.03953 to 0.03842, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 47ms/step - loss: 0.0384 - val_loss: 0.0455
# Epoch 27/100
#
# Epoch 27: loss improved from 0.03842 to 0.03810, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0381 - val_loss: 0.0391
# Epoch 28/100
#
# Epoch 28: loss improved from 0.03810 to 0.03780, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 47ms/step - loss: 0.0378 - val_loss: 0.0381
# Epoch 29/100
#
# Epoch 29: loss improved from 0.03780 to 0.03675, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0367 - val_loss: 0.0404
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.03675
# 22/22 - 1s - 44ms/step - loss: 0.0374 - val_loss: 0.0373
# Epoch 31/100
#
# Epoch 31: loss improved from 0.03675 to 0.03627, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 44ms/step - loss: 0.0363 - val_loss: 0.0387
# Epoch 32/100
#
# Epoch 32: loss improved from 0.03627 to 0.03506, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 43ms/step - loss: 0.0351 - val_loss: 0.0370
# Epoch 33/100
#
# Epoch 33: loss improved from 0.03506 to 0.03466, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 44ms/step - loss: 0.0347 - val_loss: 0.0363
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.03466
# 22/22 - 1s - 45ms/step - loss: 0.0351 - val_loss: 0.0358
# Epoch 35/100
#
# Epoch 35: loss improved from 0.03466 to 0.03295, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0329 - val_loss: 0.0358
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.03295
# 22/22 - 1s - 44ms/step - loss: 0.0337 - val_loss: 0.0482
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.03295
# 22/22 - 1s - 48ms/step - loss: 0.0336 - val_loss: 0.0362
# Epoch 38/100
#
# Epoch 38: loss improved from 0.03295 to 0.03294, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 50ms/step - loss: 0.0329 - val_loss: 0.0437
# Epoch 39/100
#
# Epoch 39: loss improved from 0.03294 to 0.03113, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 48ms/step - loss: 0.0311 - val_loss: 0.0400
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.03113
# 22/22 - 1s - 45ms/step - loss: 0.0333 - val_loss: 0.0345
# Epoch 41/100
#
# Epoch 41: loss improved from 0.03113 to 0.03063, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0306 - val_loss: 0.0339
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.03063
# 22/22 - 1s - 46ms/step - loss: 0.0312 - val_loss: 0.0337
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.03063
# 22/22 - 1s - 44ms/step - loss: 0.0307 - val_loss: 0.0334
# Epoch 44/100
#
# Epoch 44: loss improved from 0.03063 to 0.03039, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 48ms/step - loss: 0.0304 - val_loss: 0.0331
# Epoch 45/100
#
# Epoch 45: loss improved from 0.03039 to 0.02897, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 49ms/step - loss: 0.0290 - val_loss: 0.0329
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.02897
# 22/22 - 1s - 46ms/step - loss: 0.0293 - val_loss: 0.0332
# Epoch 47/100
#
# Epoch 47: loss improved from 0.02897 to 0.02853, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 44ms/step - loss: 0.0285 - val_loss: 0.0339
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.02853
# 22/22 - 1s - 44ms/step - loss: 0.0300 - val_loss: 0.0365
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.02853
# 22/22 - 1s - 43ms/step - loss: 0.0288 - val_loss: 0.0385
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.02853
# 22/22 - 1s - 44ms/step - loss: 0.0289 - val_loss: 0.0370
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.02853
# 22/22 - 1s - 43ms/step - loss: 0.0290 - val_loss: 0.0322
# Epoch 52/100
#
# Epoch 52: loss improved from 0.02853 to 0.02800, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 44ms/step - loss: 0.0280 - val_loss: 0.0334
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.02800
# 22/22 - 1s - 43ms/step - loss: 0.0291 - val_loss: 0.0315
# Epoch 54/100
#
# Epoch 54: loss improved from 0.02800 to 0.02740, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0274 - val_loss: 0.0390
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.02740
# 22/22 - 1s - 44ms/step - loss: 0.0278 - val_loss: 0.0376
# Epoch 56/100
#
# Epoch 56: loss improved from 0.02740 to 0.02719, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 63ms/step - loss: 0.0272 - val_loss: 0.0317
# Epoch 57/100
#
# Epoch 57: loss improved from 0.02719 to 0.02630, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0263 - val_loss: 0.0311
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.02630
# 22/22 - 1s - 45ms/step - loss: 0.0272 - val_loss: 0.0322
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.02630
# 22/22 - 1s - 44ms/step - loss: 0.0265 - val_loss: 0.0312
# Epoch 60/100
#
# Epoch 60: loss improved from 0.02630 to 0.02623, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0262 - val_loss: 0.0337
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.02623
# 22/22 - 1s - 45ms/step - loss: 0.0270 - val_loss: 0.0309
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.02623
# 22/22 - 1s - 40ms/step - loss: 0.0268 - val_loss: 0.0316
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.02623
# 22/22 - 1s - 44ms/step - loss: 0.0267 - val_loss: 0.0318
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.02623
# 22/22 - 1s - 44ms/step - loss: 0.0267 - val_loss: 0.0298
# Epoch 65/100
#
# Epoch 65: loss improved from 0.02623 to 0.02609, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0261 - val_loss: 0.0316
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.02609
# 22/22 - 1s - 45ms/step - loss: 0.0268 - val_loss: 0.0335
# Epoch 67/100
#
# Epoch 67: loss improved from 0.02609 to 0.02518, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0252 - val_loss: 0.0332
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.02518
# 22/22 - 1s - 43ms/step - loss: 0.0261 - val_loss: 0.0291
# Epoch 69/100
#
# Epoch 69: loss improved from 0.02518 to 0.02501, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 44ms/step - loss: 0.0250 - val_loss: 0.0293
# Epoch 70/100
#
# Epoch 70: loss improved from 0.02501 to 0.02494, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0249 - val_loss: 0.0295
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02494
# 22/22 - 1s - 44ms/step - loss: 0.0257 - val_loss: 0.0286
# Epoch 72/100
#
# Epoch 72: loss improved from 0.02494 to 0.02475, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0248 - val_loss: 0.0299
# Epoch 73/100
#
# Epoch 73: loss improved from 0.02475 to 0.02438, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0244 - val_loss: 0.0283
# Epoch 74/100
#
# Epoch 74: loss improved from 0.02438 to 0.02431, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0243 - val_loss: 0.0281
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.02431
# 22/22 - 1s - 42ms/step - loss: 0.0254 - val_loss: 0.0294
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02431
# 22/22 - 1s - 43ms/step - loss: 0.0246 - val_loss: 0.0287
# Epoch 77/100
#
# Epoch 77: loss improved from 0.02431 to 0.02410, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0241 - val_loss: 0.0279
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.02410
# 22/22 - 1s - 44ms/step - loss: 0.0243 - val_loss: 0.0311
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.02410
# 22/22 - 1s - 45ms/step - loss: 0.0246 - val_loss: 0.0285
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.02410
# 22/22 - 1s - 44ms/step - loss: 0.0243 - val_loss: 0.0283
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.02410
# 22/22 - 1s - 44ms/step - loss: 0.0245 - val_loss: 0.0275
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.02410
# 22/22 - 1s - 44ms/step - loss: 0.0247 - val_loss: 0.0310
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.02410
# 22/22 - 1s - 44ms/step - loss: 0.0250 - val_loss: 0.0274
# Epoch 84/100
#
# Epoch 84: loss improved from 0.02410 to 0.02397, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0240 - val_loss: 0.0275
# Epoch 85/100
#
# Epoch 85: loss improved from 0.02397 to 0.02339, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 44ms/step - loss: 0.0234 - val_loss: 0.0272
# Epoch 86/100
#
# Epoch 86: loss improved from 0.02339 to 0.02334, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0233 - val_loss: 0.0268
# Epoch 87/100
#
# Epoch 87: loss improved from 0.02334 to 0.02284, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0228 - val_loss: 0.0266
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.02284
# 22/22 - 1s - 44ms/step - loss: 0.0240 - val_loss: 0.0269
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.02284
# 22/22 - 1s - 45ms/step - loss: 0.0235 - val_loss: 0.0310
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.02284
# 22/22 - 1s - 43ms/step - loss: 0.0232 - val_loss: 0.0277
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.02284
# 22/22 - 1s - 45ms/step - loss: 0.0241 - val_loss: 0.0262
# Epoch 92/100
#
# Epoch 92: loss improved from 0.02284 to 0.02254, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 46ms/step - loss: 0.0225 - val_loss: 0.0263
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.02254
# 22/22 - 1s - 45ms/step - loss: 0.0234 - val_loss: 0.0266
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.02254
# 22/22 - 1s - 44ms/step - loss: 0.0230 - val_loss: 0.0269
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.02254
# 22/22 - 1s - 44ms/step - loss: 0.0240 - val_loss: 0.0276
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.02254
# 22/22 - 1s - 42ms/step - loss: 0.0233 - val_loss: 0.0282
# Epoch 97/100
#
# Epoch 97: loss improved from 0.02254 to 0.02225, saving model to save_models/VRE_model.keras
# 22/22 - 1s - 45ms/step - loss: 0.0222 - val_loss: 0.0257
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.02225
# 22/22 - 1s - 42ms/step - loss: 0.0231 - val_loss: 0.0257
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.02225
# 22/22 - 1s - 43ms/step - loss: 0.0225 - val_loss: 0.0261
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.02225
# 22/22 - 1s - 44ms/step - loss: 0.0235 - val_loss: 0.0255
# Restoring model weights from the end of the best epoch: 97.

# %%
save_model_path = "models/VRE_model.keras"
# Tải mô hình tốt nhất
final_model = load_model(save_model_path)

# %%
# Dự đoán trên tập train
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
y_train = sc.inverse_transform(y_train.reshape(-1, 1))
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[int(len(df) * 0.8):] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# Chọn dữ liệu cho test_data1
num_test_predictions = len(y_test_predict)
test_data1 = df.iloc[-num_test_predictions:].copy()
plt.figure(figsize=(20, 12))
if 'Ngay' in test_data1.columns:
    plt.plot(test_data1['Ngay'], test_data1['GiaDongCua'], label='Giá thực tế', color='red')
else:
    raise KeyError("Cột 'Ngày' không tồn tại trong test_data1.")

test_data1 = test_data1.copy()
test_data1['Dự đoán'] = y_test_predict.flatten()
plt.plot(test_data1['Ngay'], test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.legend()
plt.show()

# %%
print('--- Kết quả trên tập train ---')
# R2 score
print('Độ phù hợp tập train (R2):', r2_score(y_train, y_train_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):', mean_absolute_error(y_train, y_train_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập train:', mean_absolute_percentage_error(y_train, y_train_predict) * 100)

# RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predict))
print('RMSE trên tập train (VNĐ):', rmse_train)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_train = np.max(y_train) - np.min(y_train)
accuracy_train = 1 - (rmse_train / range_y_train)
print('Độ chính xác trên tập train (%):', accuracy_train * 100)

# F1 Score (Chuyển thành bài toán phân loại)
error_threshold = 10  # Ngưỡng sai số
y_train_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
y_train_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_train, y_train_predict)]
f1_train = f1_score(y_train_class, y_train_pred_class)
print('F1 Score trên tập train:', f1_train)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập train ---
# Độ phù hợp tập train (R2): 0.974778470841221
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 0.7204882881353343
# Phần trăm sai số tuyệt đối trung bình trên tập train: 2.2737995060052323
# RMSE trên tập train (VNĐ): 1.0172614981964838
# Độ chính xác trên tập train (%): 97.65066628592037
# F1 Score trên tập train: 1.0
# ----------------------------------------------------

# %%
y_test = data[-len(y_test_predict):]

# %%
print('--- Kết quả trên tập test ---')
# R2 score
print('Độ phù hợp tập test (R2):', r2_score(y_test, y_test_predict))

# MAE
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):', mean_absolute_error(y_test, y_test_predict))

# MAPE
print('Phần trăm sai số tuyệt đối trung bình trên tập test:', mean_absolute_percentage_error(y_test, y_test_predict) * 100)

# RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
print('RMSE trên tập test (VNĐ):', rmse_test)

# Accuracy (dựa trên RMSE và biên độ giá trị thực tế)
range_y_test = np.max(y_test) - np.min(y_test)
accuracy_test = 1 - (rmse_test / range_y_test)
print('Độ chính xác trên tập test (%):', accuracy_test * 100)

# F1 Score (Chuyển thành bài toán phân loại)
y_test_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
y_test_pred_class = [1 if abs(y - yp) < error_threshold else 0 for y, yp in zip(y_test, y_test_predict)]
f1_test = f1_score(y_test_class, y_test_pred_class)
print('F1 Score trên tập test:', f1_test)
print("----------------------------------------------------")
# Out:
# --- Kết quả trên tập test ---
# Độ phù hợp tập test (R2): 0.9227863822560762
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 0.8880966400231969
# Phần trăm sai số tuyệt đối trung bình trên tập test: 4.167597117463078
# RMSE trên tập test (VNĐ): 1.0308685285858434
# Độ chính xác trên tập test (%): 92.98728892118474
# F1 Score trên tập test: 1.0
# ----------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def create_labels(data):
    return [1 if data[i] > data[i-1] else 0 for i in range(1, len(data))]

# Chuyển đổi giá trị thực tế và dự đoán thành nhãn phân loại
y_train_labels = create_labels(y_train)
y_train_predict_labels = create_labels(y_train_predict.flatten())

y_test_labels = create_labels(y_test)
y_test_predict_labels = create_labels(y_test_predict.flatten())

# Tạo ma trận nhầm lẫn cho tập train
cm_train = confusion_matrix(y_train_labels, y_train_predict_labels)
cm_test = confusion_matrix(y_test_labels, y_test_predict_labels)

# Hiển thị ma trận nhầm lẫn
plt.figure(figsize=(10, 7))

# Ma trận nhầm lẫn cho tập train
plt.subplot(1, 2, 1)
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Train)")

# Ma trận nhầm lẫn cho tập test
plt.subplot(1, 2, 2)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=["Giảm", "Tăng"], yticklabels=["Giảm", "Tăng"])
plt.title("Ma trận nhầm lẫn (Test)")

plt.tight_layout()
plt.show()
